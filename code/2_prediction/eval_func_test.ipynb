# %%
# Do we need to parallelize? Yes.

# %%
from __future__ import division
import numpy as np
import random
import multiprocessing as mp
from collections import Counter
import functools
import datetime
import matplotlib.pyplot as plt
import seaborn
import math
import datetime as dt
import networkx as nx
import operator

# %%
def loadEdgelist(filename):
	# Read in graph
	g = nx.read_edgelist(filename, 
	                     delimiter="\t", 
	                     create_using  = nx.DiGraph(), 
	                     data=True)

	# Convert Weight To Float
	temp = map(lambda (x, y): (x, float(y)), 
			   nx.get_edge_attributes(g, "weight").items())
	nx.set_edge_attributes(g, "weight", dict(temp))

	# Convert Date to datetime
	temp = map(lambda (x, y): (x, dt.datetime.strptime(y, "%Y-%m-%d")), 
			   nx.get_edge_attributes(g, "date").items())
	nx.set_edge_attributes(g, "date", dict(temp))

	return g

def writeEdgelist(g, filename):
    # Convert date to string
    temp = map(lambda (x, y): (x, y.strftime('%Y-%m-%d')), 
               nx.get_edge_attributes(g, "date").items())
    nx.set_edge_attributes(g, "date", dict(temp))
    
    # Write to file
    nx.write_edgelist(g,filename, delimiter="\t", data=True)

preG = loadEdgelist("../1_snapshotting/cumulative_snapshots/enddate_20140228.edgelist")
postG = loadEdgelist("../1_snapshotting/cumulative_snapshots/enddate_20150831.edgelist")

# Enforce Bipartiteness
# Set node attributes. 0 is an investor, 1 is a company.
node_attributes =dict(map(lambda (x,y): (x,1) if y > 0 else (x,0), 
                      preG.in_degree().items()))
nx.set_node_attributes(preG, "bipartite", node_attributes)

# %%
def create_truth(preG, postG):
    if postG postG.edges()
# Out:
# [(u'/organization/rsj-private-equity', u'/organization/cognitive-security'),
#  (u'/organization/rsj-private-equity', u'/organization/beepl'),
#  (u'/organization/petra-partners', u'/organization/new-century-hospice'),
#  (u'/person/kevin-lin', u'/organization/the-ticket-fairy'),
#  (u'/person/emilios-markou', u'/organization/park-around'),
#  (u'/person/dave-leyrer', u'/organization/tapiture'),
#  (u'/person/dave-leyrer', u'/organization/omaze'),
#  (u'/person/oren-etzioni', u'/organization/algorithmia'),
#  (u'/organization/beamonte-investments', u'/organization/arthena'),
#  (u'/organization/beamonte-investments', u'/organization/black-house'),
#  (u'/organization/beamonte-investments', u'/organization/master-kiwi'),
#  (u'/organization/beamonte-investments', u'/organization/kiwii-capital'),
#  (u'/organization/beamonte-investments', u'/organization/nanosatisfi'),
#  (u'/organization/inventures', u'/organization/foruforever'),
#  (u'/organization/inventures', u'/organization/rewarder'),
#  (u'/organization/healthbox', u'/organization/prsm-healthcare'),
#  (u'/organization/healthbox', u'/organization/tute-genomics'),
#  (u'/organization/healthbox', u'/organization/platejoy'),
#  (u'/organization/healthbox', u'/organization/geckocap'),
#  (u'/organization/healthbox', u'/organization/carewire'),
#  (u'/organization/healthbox', u'/organization/3derm-systems'),
#  (u'/organization/healthbox', u'/organization/desktop-genetics'),
#  (u'/organization/healthbox', u'/organization/soma-analytics'),
#  (u'/organization/healthbox', u'/organization/robauto'),
#  (u'/organization/healthbox', u'/organization/fitzeal'),
#  (u'/organization/healthbox', u'/organization/portable-medical-technology'),
#  (u'/organization/healthbox', u'/organization/chatterplug'),
#  (u'/organization/healthbox', u'/organization/caring-in-place'),
#  (u'/organization/healthbox', u'/organization/corengi'),
#  (u'/organization/healthbox', u'/organization/learn-it-live'),
#  (u'/organization/healthbox', u'/organization/abiogenix'),
#  (u'/organization/healthbox', u'/organization/push-wellness'),
#  (u'/organization/healthbox', u'/organization/healthclinicplus'),
#  (u'/organization/healthbox', u'/organization/heartoday-org'),
#  (u'/organization/healthbox', u'/organization/operating-analytics'),
#  (u'/organization/healthbox', u'/organization/mira-rehab'),
#  (u'/organization/healthbox', u'/organization/peerfit-2'),
#  (u'/organization/healthbox', u'/organization/aavya-health'),
#  (u'/organization/healthbox', u'/organization/centrana-health'),
#  (u'/organization/healthbox', u'/organization/swipesense'),
#  (u'/organization/healthbox', u'/organization/clariture'),
#  (u'/organization/healthbox', u'/organization/leanwagon'),
#  (u'/organization/healthbox', u'/organization/carehubs'),
#  (u'/organization/healthbox', u'/organization/casagem'),
#  (u'/organization/healthbox', u'/organization/bonapp-2'),
#  (u'/organization/healthbox', u'/organization/etect'),
#  (u'/organization/healthbox', u'/organization/united-preference'),
#  (u'/organization/healthbox', u'/organization/axial-healthcare'),
#  (u'/organization/healthbox', u'/organization/eclinic-healthcare'),
#  (u'/organization/healthbox', u'/organization/dermlink-inc'),
#  (u'/organization/healthbox', u'/organization/iconic-data'),
#  (u'/organization/healthbox', u'/organization/rostr'),
#  (u'/organization/healthbox', u'/organization/quietyme'),
#  (u'/organization/healthbox', u'/organization/gweepi-medical'),
#  (u'/organization/healthbox', u'/organization/gema-touch'),
#  (u'/organization/healthbox', u'/organization/theravid'),
#  (u'/organization/healthbox', u'/organization/atlas-health-technologies'),
#  (u'/organization/healthbox', u'/organization/carespotter'),
#  (u'/organization/healthbox', u'/organization/cara-health'),
#  (u'/organization/healthbox', u'/organization/epion-health'),
#  (u'/organization/healthbox', u'/organization/true-north-healthcare'),
#  (u'/organization/healthbox', u'/organization/ceuticare'),
#  (u'/organization/healthbox', u'/organization/ludi'),
#  (u'/organization/healthbox', u'/organization/remedify'),
#  (u'/organization/healthbox', u'/organization/hometouch'),
#  (u'/organization/healthbox', u'/organization/yo-fi-wellness'),
#  (u'/organization/ivycap-ventures', u'/organization/aujas-networks'),
#  (u'/organization/ivycap-ventures', u'/organization/purplle'),
#  (u'/organization/ivycap-ventures', u'/organization/sokrati'),
#  (u'/organization/ivycap-ventures', u'/organization/vinculum-solutions'),
#  (u'/organization/ivycap-ventures', u'/organization/leixir'),
#  (u'/organization/ivycap-ventures',
#   u'/organization/rml-information-services-ltd'),
#  (u'/organization/ivycap-ventures', u'/organization/eshakti-com'),
#  (u'/organization/ivycap-ventures', u'/organization/fieldez'),
#  (u'/organization/ivycap-ventures', u'/organization/clovia'),
#  (u'/organization/ivycap-ventures', u'/organization/bluestone-com'),
#  (u'/organization/forticom', u'/organization/nasza-klasa-pl'),
#  (u'/organization/forticom', u'/organization/odnoklassniki'),
#  (u'/person/erik-rannala', u'/organization/mashape'),
#  (u'/person/patric-svanberg', u'/organization/accumulate'),
#  (u'/organization/svb-india-capital-partners',
#   u'/organization/pgp-corporation'),
#  (u'/organization/svb-india-capital-partners', u'/organization/nominum'),
#  (u'/organization/fjme-ventures', u'/organization/jobandtalent'),
#  (u'/organization/fjme-ventures', u'/organization/redbooth'),
#  (u'/organization/afisha-rambler', u'/organization/timepad'),
#  (u'/person/anand-lunia', u'/organization/incights-mobile-solutions'),
#  (u'/person/anand-lunia', u'/organization/giveter'),
#  (u'/organization/access2net', u'/organization/prylos'),
#  (u'/person/b7inc-peter-thorp', u'/organization/zoomdata'),
#  (u'/person/jamie-curtis', u'/organization/urx'),
#  (u'/organization/aldrich-ventures', u'/organization/phishme'),
#  (u'/person/juan-bermudez', u'/organization/nightpro'),
#  (u'/organization/promsvyazbank', u'/organization/cian-group'),
#  (u'/person/gilles-dellaert', u'/organization/seaters'),
#  (u'/person/doug-lichliter', u'/organization/inovar-corporation'),
#  (u'/person/frank-slootman', u'/organization/thoughtspot'),
#  (u'/person/frank-slootman', u'/organization/numerify'),
#  (u'/organization/the-capstreet-group', u'/organization/hart-intercivic'),
#  (u'/person/seth-goldstein', u'/organization/splice'),
#  (u'/person/seth-goldstein', u'/organization/joyride-app'),
#  (u'/person/seth-goldstein', u'/organization/greenhouse-software'),
#  (u'/person/seth-goldstein', u'/organization/gumroad'),
#  (u'/person/seth-goldstein', u'/organization/kiwi-crate'),
#  (u'/person/seth-goldstein', u'/organization/delicious'),
#  (u'/person/seth-goldstein', u'/organization/appjet'),
#  (u'/person/seth-goldstein', u'/organization/valetanywhere'),
#  (u'/person/joe-mansueto-2', u'/organization/built-in'),
#  (u'/person/joe-mansueto-2', u'/organization/wedeliver'),
#  (u'/person/vadim-ugov', u'/organization/slimesandwich'),
#  (u'/organization/jgb-management', u'/organization/bravosolution'),
#  (u'/organization/realnetworks', u'/organization/rhapsody'),
#  (u'/organization/realnetworks', u'/organization/ogplanet'),
#  (u'/person/emre-kurttepeli', u'/organization/sporcum-com'),
#  (u'/person/brendan-synnott', u'/organization/bucketfeet'),
#  (u'/person/oren-michels', u'/organization/shoppad'),
#  (u'/person/oren-michels', u'/organization/uber'),
#  (u'/organization/crehol-meaningful-capital', u'/organization/secoo'),
#  (u'/organization/green-venture-capital', u'/organization/pinnatta'),
#  (u'/organization/2x-consumer-products-growth-partners',
#   u'/organization/orabrush'),
#  (u'/organization/am-only', u'/organization/splice'),
#  (u'/organization/am-only', u'/organization/doppler-labs'),
#  (u'/organization/cyber-agent-investment', u'/organization/mappn'),
#  (u'/organization/cyber-agent-investment', u'/organization/tutorgroup'),
#  (u'/organization/cyber-agent-investment', u'/organization/9tong-com'),
#  (u'/organization/times-internet', u'/organization/delhivery'),
#  (u'/organization/times-internet', u'/organization/zipdial'),
#  (u'/organization/times-internet', u'/organization/uber'),
#  (u'/organization/times-internet', u'/organization/flynx'),
#  (u'/organization/times-internet', u'/organization/take-zero'),
#  (u'/organization/times-internet', u'/organization/zopnow'),
#  (u'/organization/times-internet', u'/organization/coursera'),
#  (u'/organization/times-internet', u'/organization/culture-machine'),
#  (u'/organization/times-internet', u'/organization/bluegape-lifestyle'),
#  (u'/organization/times-internet', u'/organization/jiffstore'),
#  (u'/organization/times-internet', u'/organization/gradestack'),
#  (u'/organization/seagate-technology', u'/organization/cloudscaling'),
#  (u'/organization/seagate-technology', u'/organization/egnyte'),
#  (u'/organization/seagate-technology', u'/organization/reduxio'),
#  (u'/organization/seagate-technology', u'/organization/ripple-labs'),
#  (u'/organization/seagate-technology', u'/organization/easic'),
#  (u'/organization/sanan-private-equity', u'/organization/digital-assent'),
#  (u'/person/denis-engel', u'/organization/buzzero'),
#  (u'/organization/oxford-blackpoint-venture-partners',
#   u'/organization/potbelly-sandwich-works'),
#  (u'/person/david-buttress', u'/organization/minicabster'),
#  (u'/person/eddy-chan', u'/organization/speak-with-me'),
#  (u'/person/jake-zeller', u'/organization/buttercoin'),
#  (u'/person/jake-zeller', u'/organization/gastke'),
#  (u'/person/jake-zeller', u'/organization/tachyus'),
#  (u'/organization/newspring-ventures', u'/organization/bluenog'),
#  (u'/organization/newspring-ventures', u'/organization/nitrosecurity'),
#  (u'/organization/ecco-2', u'/organization/omada'),
#  (u'/person/hemant-bhanoo', u'/organization/play-i'),
#  (u'/organization/the-bergquist-company', u'/organization/nuventix'),
#  (u'/person/ziv-navoth', u'/organization/simplegeo'),
#  (u'/organization/the-tornante-company', u'/organization/diversion'),
#  (u'/organization/the-tornante-company', u'/organization/taskrabbit'),
#  (u'/organization/the-tornante-company', u'/organization/veoh'),
#  (u'/organization/the-tornante-company', u'/organization/omaze'),
#  (u'/organization/the-tornante-company', u'/organization/clique-media-3'),
#  (u'/organization/imperial-college-of-science-technology-medicine',
#   u'/organization/cortexica'),
#  (u'/person/andrew-moss', u'/organization/drync'),
#  (u'/person/andrew-moss', u'/organization/kaching-coupons'),
#  (u'/organization/mg-investment-capital',
#   u'/organization/ayehu-software-technologies'),
#  (u'/organization/genopole', u'/organization/cellvir'),
#  (u'/organization/inventures-group', u'/organization/zimbra'),
#  (u'/organization/inventures-group', u'/organization/proofpoint'),
#  (u'/organization/inventures-group', u'/organization/virtuoz'),
#  (u'/person/carlos-mart\xc3\xadn', u'/organization/cursogram'),
#  (u'/person/hugo-mardomingo', u'/organization/viuing'),
#  (u'/organization/grouse-ridge-capital', u'/organization/nchannel'),
#  (u'/person/chris-howard', u'/organization/secret'),
#  (u'/person/bryan-mason', u'/organization/medium'),
#  (u'/organization/aws-grnderfonds', u'/organization/miracor-medical-systems'),
#  (u'/organization/aws-grnderfonds', u'/organization/roomle'),
#  (u'/organization/aws-grnderfonds', u'/organization/piano-media'),
#  (u'/organization/elliott-associates', u'/organization/tagsys'),
#  (u'/organization/finance-for-business-north-east-creative-content-fund',
#   u'/organization/masher'),
#  (u'/person/chris-allen', u'/organization/fatsoma'),
#  (u'/organization/mey-capital-matrix', u'/organization/ithera-medical'),
#  (u'/organization/new-dominion-angels', u'/organization/arcsys'),
#  (u'/organization/new-dominion-angels', u'/organization/loop88'),
#  (u'/organization/new-dominion-angels', u'/organization/mom-made-foods'),
#  (u'/organization/new-dominion-angels', u'/organization/phthisis-diagnostics'),
#  (u'/organization/new-dominion-angels', u'/organization/seniorliving-net'),
#  (u'/organization/new-dominion-angels', u'/organization/cargosense'),
#  (u'/organization/new-dominion-angels', u'/organization/divvycloud'),
#  (u'/organization/new-dominion-angels', u'/organization/mysbx-2'),
#  (u'/organization/new-dominion-angels', u'/organization/roi'),
#  (u'/organization/new-dominion-angels', u'/organization/trx-systems'),
#  (u'/organization/new-dominion-angels', u'/organization/aquicore'),
#  (u'/organization/new-dominion-angels', u'/organization/ohmygov-inc'),
#  (u'/organization/new-dominion-angels', u'/organization/brain-sentry'),
#  (u'/organization/new-dominion-angels', u'/organization/workproducts'),
#  (u'/organization/new-dominion-angels', u'/organization/yasabe'),
#  (u'/organization/new-dominion-angels',
#   u'/organization/blue-triangle-technologies'),
#  (u'/organization/new-dominion-angels', u'/organization/zagster'),
#  (u'/person/william-ferguson', u'/organization/smartzer'),
#  (u'/person/harald-dirdal', u'/organization/havgul-clean-energy'),
#  (u'/organization/tollgrade-communications', u'/organization/bpl-global'),
#  (u'/person/pascal-cagni', u'/organization/netatmo'),
#  (u'/person/pascal-cagni', u'/organization/cleeng'),
#  (u'/person/pascal-cagni', u'/organization/iskn'),
#  (u'/person/pascal-cagni', u'/organization/rockpack'),
#  (u'/person/pascal-cagni', u'/organization/shopcade'),
#  (u'/organization/notation-capital-2', u'/organization/zipdrug'),
#  (u'/organization/notation-capital-2', u'/organization/versed'),
#  (u'/organization/wells-fargo-bank', u'/organization/t5-data-centers'),
#  (u'/organization/wells-fargo-bank', u'/organization/imatchative'),
#  (u'/organization/wells-fargo-bank',
#   u'/organization/cdc-software-corporation'),
#  (u'/organization/wells-fargo-bank', u'/organization/towerjazz'),
#  (u'/organization/wells-fargo-bank', u'/organization/hillerich-bradsby'),
#  (u'/organization/wells-fargo-bank', u'/organization/evergreen-enterprises'),
#  (u'/organization/wells-fargo-bank', u'/organization/eyeverify'),
#  (u'/organization/wells-fargo-bank', u'/organization/jawbone'),
#  (u'/organization/wells-fargo-bank', u'/organization/fast-pay-partners'),
#  (u'/organization/wells-fargo-bank', u'/organization/symphony-3'),
#  (u'/organization/grupo-genetrix', u'/organization/cellerix'),
#  (u'/person/amr-awadallah', u'/organization/instabug'),
#  (u'/person/amr-awadallah', u'/organization/parastructure'),
#  (u'/person/archie-norman', u'/organization/blur-group'),
#  (u'/organization/conscious-venture-lab', u'/organization/self-spark'),
#  (u'/organization/conscious-venture-lab', u'/organization/going-green-today'),
#  (u'/organization/conscious-venture-lab', u'/organization/shenami'),
#  (u'/organization/conscious-venture-lab', u'/organization/coderloan'),
#  (u'/organization/conscious-venture-lab', u'/organization/spend-consciously'),
#  (u'/organization/conscious-venture-lab', u'/organization/zest-2'),
#  (u'/organization/conscious-venture-lab', u'/organization/shea-radiance'),
#  (u'/organization/conscious-venture-lab', u'/organization/hungry-harvest'),
#  (u'/person/kishore-ganji', u'/organization/intellocut'),
#  (u'/person/kishore-ganji', u'/organization/candi-controls'),
#  (u'/person/kishore-ganji', u'/organization/knightscope-inc'),
#  (u'/person/kishore-ganji', u'/organization/smartypants-vitamins'),
#  (u'/person/kishore-ganji', u'/organization/idubba'),
#  (u'/person/kishore-ganji', u'/organization/avaz'),
#  (u'/person/kishore-ganji', u'/organization/allizhealth'),
#  (u'/person/kishore-ganji', u'/organization/jumio'),
#  (u'/person/kishore-ganji', u'/organization/shephertz-technologies-pvt-ltd'),
#  (u'/person/kishore-ganji', u'/organization/online-prasad'),
#  (u'/person/kishore-ganji', u'/organization/addepar'),
#  (u'/person/kishore-ganji', u'/organization/fortunepay'),
#  (u'/person/jed-stremel', u'/organization/asana'),
#  (u'/person/jed-stremel', u'/organization/vamo'),
#  (u'/person/jed-stremel', u'/organization/practice-fusion'),
#  (u'/organization/navigator-technology-ventures', u'/organization/sionex'),
#  (u'/organization/navigator-technology-ventures',
#   u'/organization/tizor-systems'),
#  (u'/organization/navigator-technology-ventures',
#   u'/organization/food-quality-sensor-international'),
#  (u'/organization/gettyimages', u'/organization/daylife'),
#  (u'/organization/media-investment-gmbh', u'/organization/datapine'),
#  (u'/organization/bsi-sa', u'/organization/perlegen-sciences'),
#  (u'/organization/bsi-sa', u'/organization/globeimmune'),
#  (u'/organization/bsi-sa',
#   u'/organization/visioncare-ophthalmic-technologies'),
#  (u'/organization/enertech-capital', u'/organization/distech-controls'),
#  (u'/organization/enertech-capital',
#   u'/organization/markwater-handling-systems'),
#  (u'/organization/enertech-capital', u'/organization/pcn-technology'),
#  (u'/organization/enertech-capital', u'/organization/blaze-company'),
#  (u'/organization/enertech-capital', u'/organization/n-dimension-solutions'),
#  (u'/organization/enertech-capital', u'/organization/space-time-insight'),
#  (u'/organization/enertech-capital', u'/organization/calstar-products'),
#  (u'/organization/enertech-capital', u'/organization/energysavvy-com'),
#  (u'/organization/enertech-capital', u'/organization/iosil-energy'),
#  (u'/organization/enertech-capital', u'/organization/serious-materials'),
#  (u'/organization/enertech-capital', u'/organization/terralux'),
#  (u'/organization/enertech-capital', u'/organization/geodigital'),
#  (u'/organization/enertech-capital', u'/organization/current'),
#  (u'/organization/enertech-capital', u'/organization/regen-energy'),
#  (u'/organization/enertech-capital', u'/organization/atraverda'),
#  (u'/organization/enertech-capital', u'/organization/intellon-corporation'),
#  (u'/organization/enertech-capital', u'/organization/enbala-power-networks'),
#  (u'/organization/enertech-capital', u'/organization/coalogix'),
#  (u'/organization/enertech-capital', u'/organization/nanosteel'),
#  (u'/organization/enertech-capital', u'/organization/ownenergy'),
#  (u'/organization/enertech-capital', u'/organization/blue-pillar'),
#  (u'/organization/enertech-capital',
#   u'/organization/cablematrix-technologies'),
#  (u'/organization/enertech-capital', u'/organization/invidi-technologies'),
#  (u'/organization/enertech-capital',
#   u'/organization/filterboxx-water-environmental'),
#  (u'/person/sridar-iyengar', u'/organization/buysight'),
#  (u'/organization/daesung-private-equity', u'/organization/hello-market'),
#  (u'/organization/daesung-private-equity', u'/organization/spoqa'),
#  (u'/organization/daesung-private-equity', u'/organization/loadcomplete'),
#  (u'/organization/apax-partners', u'/organization/onespin-solutions'),
#  (u'/organization/apax-partners', u'/organization/sonim-technologies'),
#  (u'/organization/apax-partners', u'/organization/tideway'),
#  (u'/organization/apax-partners', u'/organization/lorantis-ltd'),
#  (u'/organization/apax-partners', u'/organization/innovalight'),
#  (u'/organization/apax-partners', u'/organization/dune-medical-devices'),
#  (u'/organization/apax-partners', u'/organization/preventsys'),
#  (u'/organization/apax-partners', u'/organization/handmark'),
#  (u'/organization/apax-partners', u'/organization/digital-fuel'),
#  (u'/organization/apax-partners', u'/organization/mfoundry'),
#  (u'/organization/apax-partners', u'/organization/frontier-silicon'),
#  (u'/organization/apax-partners', u'/organization/red-m-group'),
#  (u'/organization/apax-partners', u'/organization/corvil'),
#  (u'/organization/apax-partners', u'/organization/wisair'),
#  (u'/organization/apax-partners', u'/organization/mobixell'),
#  (u'/organization/apax-partners', u'/organization/aerovance'),
#  (u'/organization/apax-partners', u'/organization/plex-systems'),
#  (u'/organization/apax-partners', u'/organization/synaptic-digital'),
#  (u'/organization/apax-partners', u'/organization/transera-communications'),
#  (u'/organization/apax-partners', u'/organization/crescendo-networks'),
#  (u'/organization/apax-partners', u'/organization/cadent'),
#  (u'/organization/apax-partners', u'/organization/neurotech'),
#  (u'/organization/apax-partners', u'/organization/vocalcom'),
#  (u'/organization/apax-partners', u'/organization/deontics'),
#  (u'/organization/apax-partners', u'/organization/traxpay'),
#  (u'/organization/apax-partners', u'/organization/canesta'),
#  (u'/organization/apax-partners',
#   u'/organization/solid-information-technology'),
#  (u'/organization/apax-partners', u'/organization/voodoovox'),
#  (u'/organization/apax-partners', u'/organization/raysat'),
#  (u'/organization/apax-partners', u'/organization/king'),
#  (u'/organization/apax-partners', u'/organization/perfect-commerce'),
#  (u'/organization/apax-partners', u'/organization/the-newsmarket'),
#  (u'/organization/apax-partners', u'/organization/dxo-labs'),
#  (u'/organization/ovation-capital', u'/organization/connectiva-systems'),
#  (u'/organization/skyocean-international-holdings',
#   u'/organization/firefly-games'),
#  (u'/organization/gsm-fund', u'/organization/elcelyx-therapeutics'),
#  (u'/person/joe-zawadzki', u'/organization/bomoda'),
#  (u'/person/joe-zawadzki', u'/organization/velos-2'),
#  (u'/person/joe-zawadzki', u'/organization/namely'),
#  (u'/organization/medley-capital-corporation',
#   u'/organization/lighting-science-group'),
#  (u'/organization/rosepaul-investments', u'/organization/quaero-corporation'),
#  (u'/organization/rosepaul-investments', u'/organization/dealflicks'),
#  (u'/person/andrew-mccollum', u'/organization/opbeat'),
#  (u'/person/andrew-mccollum', u'/organization/philo'),
#  (u'/person/andrew-mccollum', u'/organization/plated'),
#  (u'/person/andrew-mccollum', u'/organization/moxxly-inc-'),
#  (u'/person/andrew-mccollum', u'/organization/quil-lt'),
#  (u'/person/andrew-mccollum', u'/organization/sprig-2'),
#  (u'/person/andrew-mccollum', u'/organization/locu'),
#  (u'/person/andrew-mccollum', u'/organization/custommade-ventures'),
#  (u'/organization/romar-capital', u'/organization/popular-pays'),
#  (u'/organization/affentranger-associates', u'/organization/sirs-lab'),
#  (u'/person/andy-klingenstein', u'/organization/trackmaven'),
#  (u'/person/peter-hinssen', u'/organization/sparkcentral'),
#  (u'/person/daniel-laury', u'/organization/zeepro'),
#  (u'/organization/teres-capital-ltd', u'/organization/cad-best'),
#  (u'/organization/teres-capital-ltd', u'/organization/carista-app'),
#  (u'/organization/teres-capital-ltd', u'/organization/flipps'),
#  (u'/person/wendi-deng', u'/organization/twigtale'),
#  (u'/person/wendi-deng', u'/organization/art-sy'),
#  (u'/person/tom-banahan', u'/organization/searchme'),
#  (u'/person/daniel-laurn', u'/organization/46elks'),
#  (u'/organization/tengelmann-ventures', u'/organization/careerfoundry'),
#  (u'/organization/tengelmann-ventures', u'/organization/neonga'),
#  (u'/organization/tengelmann-ventures', u'/organization/lazada-group'),
#  (u'/organization/tengelmann-ventures', u'/organization/preisanalytics'),
#  (u'/organization/tengelmann-ventures', u'/organization/pricepanda'),
#  (u'/organization/tengelmann-ventures', u'/organization/trademob'),
#  (u'/organization/tengelmann-ventures', u'/organization/lamudi-2'),
#  (u'/organization/tengelmann-ventures', u'/organization/springlane-gmbh'),
#  (u'/organization/tengelmann-ventures', u'/organization/linio'),
#  (u'/organization/tengelmann-ventures', u'/organization/shopwings'),
#  (u'/organization/tengelmann-ventures', u'/organization/westwing'),
#  (u'/organization/tengelmann-ventures', u'/organization/zalora'),
#  (u'/organization/tengelmann-ventures', u'/organization/lamoda'),
#  (u'/organization/tengelmann-ventures', u'/organization/whistle-sports'),
#  (u'/organization/tengelmann-ventures', u'/organization/carmudi'),
#  (u'/organization/tengelmann-ventures', u'/organization/zitra-com'),
#  (u'/organization/tengelmann-ventures', u'/organization/supr'),
#  (u'/organization/tengelmann-ventures', u'/organization/sumup'),
#  (u'/organization/tengelmann-ventures', u'/organization/delivery-hero'),
#  (u'/organization/tengelmann-ventures', u'/organization/trustedcompany-com'),
#  (u'/organization/tengelmann-ventures', u'/organization/clickbus'),
#  (u'/organization/tengelmann-ventures', u'/organization/easy-taxi'),
#  (u'/organization/life-sciences-fund-amsterdam',
#   u'/organization/sigmascreening'),
#  (u'/organization/life-sciences-fund-amsterdam',
#   u'/organization/acs-biomarker'),
#  (u'/organization/life-sciences-fund-amsterdam',
#   u'/organization/aimm-therapeutics'),
#  (u'/organization/sbi-ven-capital', u'/organization/origene-technologies'),
#  (u'/organization/sbi-ven-capital', u'/organization/liqvid'),
#  (u'/organization/west-capital-advisors-llc',
#   u'/organization/cardioinsight-technologies'),
#  (u'/organization/west-capital-advisors-llc', u'/organization/sharethis'),
#  (u'/organization/west-capital-advisors-llc', u'/organization/hublogix'),
#  (u'/organization/west-capital-advisors-llc', u'/organization/onshift'),
#  (u'/organization/west-capital-advisors-llc', u'/organization/thinkvine'),
#  (u'/organization/west-capital-advisors-llc',
#   u'/organization/alung-technologies'),
#  (u'/organization/west-capital-advisors-llc', u'/organization/poppin'),
#  (u'/organization/west-capital-advisors-llc', u'/organization/amplifinity'),
#  (u'/organization/west-capital-advisors-llc', u'/organization/bill-com'),
#  (u'/organization/west-capital-advisors-llc',
#   u'/organization/oversight-systems'),
#  (u'/organization/west-capital-advisors-llc', u'/organization/paydiant'),
#  (u'/organization/cinemagic', u'/organization/twitvid'),
#  (u'/organization/tpg-capital', u'/organization/imatchative'),
#  (u'/organization/tpg-capital', u'/organization/progreso-financiero'),
#  (u'/organization/tpg-capital', u'/organization/lenskart-com'),
#  (u'/organization/tpg-capital', u'/organization/chobani'),
#  (u'/organization/tpg-capital', u'/organization/victoria-plumb'),
#  (u'/organization/tpg-capital', u'/organization/onapsis'),
#  (u'/organization/vogel-ventures', u'/organization/inventorum'),
#  (u'/organization/vogel-ventures', u'/organization/meinkauf'),
#  (u'/organization/vogel-ventures', u'/organization/labfolder'),
#  (u'/organization/vogel-ventures', u'/organization/imoney-group'),
#  (u'/person/jeff-housenbold', u'/organization/clover'),
#  (u'/person/vince-passione', u'/organization/buyyourfriendadrink-com'),
#  (u'/person/casey-wasserman', u'/organization/bypass-lane'),
#  (u'/person/casey-wasserman', u'/organization/gametime'),
#  (u'/person/casey-wasserman', u'/organization/doppler-labs'),
#  (u'/person/sean-brecker', u'/organization/karma-labs'),
#  (u'/person/andrea-pederzolli', u'/organization/wineverse'),
#  (u'/person/anand-babu-ab-periasamy', u'/organization/treasure-data'),
#  (u'/organization/iqbility', u'/organization/captain-wise'),
#  (u'/organization/iqbility', u'/organization/mist-io'),
#  (u'/organization/iqbility', u'/organization/e-nios'),
#  (u'/organization/iqbility', u'/organization/offerial'),
#  (u'/person/william-ruh', u'/organization/ncino'),
#  (u'/person/carol-barash', u'/organization/story-to-college'),
#  (u'/organization/allianz-private-equity-partners', u'/organization/relion'),
#  (u'/person/gilman-tolle', u'/organization/bombfell'),
#  (u'/organization/sorenson-capital', u'/organization/pluralsight'),
#  (u'/organization/sorenson-capital', u'/organization/mindshare-technologies'),
#  (u'/organization/sorenson-capital', u'/organization/cradlepoint'),
#  (u'/organization/sorenson-capital', u'/organization/health-catalyst'),
#  (u'/organization/sorenson-capital', u'/organization/accessdata'),
#  (u'/organization/sorenson-capital', u'/organization/realty-mogul'),
#  (u'/organization/sorenson-capital', u'/organization/nexmo'),
#  (u'/person/jay-bhattacharya', u'/organization/capture-media-inc'),
#  (u'/organization/golden-gate-capital', u'/organization/signstorey'),
#  (u'/organization/golden-gate-capital', u'/organization/infor'),
#  (u'/organization/golden-gate-capital', u'/organization/u-s-silica'),
#  (u'/person/friends-and-family-round', u'/organization/lowdownapp-ltd'),
#  (u'/person/friends-and-family-round', u'/organization/fracture'),
#  (u'/organization/reinet-fund', u'/organization/lashou-com'),
#  (u'/organization/reinet-fund', u'/organization/yola'),
#  (u'/organization/reinet-fund', u'/organization/carbon3d'),
#  (u'/organization/vengrowth-capital-partners',
#   u'/organization/spotwave-wireless'),
#  (u'/organization/vengrowth-capital-partners', u'/organization/trigence'),
#  (u'/organization/vengrowth-capital-partners',
#   u'/organization/liquid-computing'),
#  (u'/organization/vengrowth-capital-partners',
#   u'/organization/belair-networks'),
#  (u'/organization/vengrowth-capital-partners', u'/organization/galazar'),
#  (u'/organization/vengrowth-capital-partners', u'/organization/kleer'),
#  (u'/organization/vengrowth-capital-partners',
#   u'/organization/meriton-networks'),
#  (u'/organization/inundata', u'/organization/newswhip'),
#  (u'/person/amreesh-modi', u'/organization/parkwhiz'),
#  (u'/organization/d-e-shaw-co', u'/organization/rocketon'),
#  (u'/organization/d-e-shaw-co', u'/organization/spotify'),
#  (u'/organization/d-e-shaw-co', u'/organization/altierre'),
#  (u'/organization/d-e-shaw-co', u'/organization/tapjoy'),
#  (u'/organization/d-e-shaw-co', u'/organization/natrix-separations'),
#  (u'/organization/d-e-shaw-co', u'/organization/desi-hits'),
#  (u'/organization/d-e-shaw-co', u'/organization/pgp-corporation'),
#  (u'/organization/d-e-shaw-co', u'/organization/meru-networks'),
#  (u'/organization/d-e-shaw-co', u'/organization/infinite-power-solutions'),
#  (u'/organization/d-e-shaw-co', u'/organization/wiquest-communications'),
#  (u'/organization/d-e-shaw-co', u'/organization/silverpop'),
#  (u'/organization/d-e-shaw-co', u'/organization/townhog'),
#  (u'/organization/d-e-shaw-co', u'/organization/dotblu'),
#  (u'/organization/d-e-shaw-co', u'/organization/emotive-communications'),
#  (u'/organization/d-e-shaw-co', u'/organization/cervel-neurotech'),
#  (u'/organization/d-e-shaw-co', u'/organization/veodia'),
#  (u'/organization/d-e-shaw-co', u'/organization/asetek'),
#  (u'/organization/d-e-shaw-co', u'/organization/panterra-networks'),
#  (u'/organization/d-e-shaw-co', u'/organization/experience-project'),
#  (u'/organization/d-e-shaw-co', u'/organization/map-pharmaceuticals'),
#  (u'/person/daniel-knox', u'/organization/experiment'),
#  (u'/person/howard-lindzon', u'/organization/estate-assist'),
#  (u'/person/howard-lindzon', u'/organization/klout'),
#  (u'/person/howard-lindzon', u'/organization/bitly'),
#  (u'/person/howard-lindzon', u'/organization/zentact'),
#  (u'/person/howard-lindzon', u'/organization/truefacet'),
#  (u'/person/howard-lindzon', u'/organization/cogo'),
#  (u'/person/howard-lindzon', u'/organization/ticketfly'),
#  (u'/person/howard-lindzon', u'/organization/mytrade'),
#  (u'/person/howard-lindzon', u'/organization/buddymedia'),
#  (u'/person/howard-lindzon', u'/organization/skyscraper'),
#  (u'/person/howard-lindzon', u'/organization/cursive-labs'),
#  (u'/person/howard-lindzon', u'/organization/foodzie'),
#  (u'/person/howard-lindzon', u'/organization/tweetdeck'),
#  (u'/person/howard-lindzon', u'/organization/equiprent-com'),
#  (u'/person/howard-lindzon', u'/organization/mobiledevhq'),
#  (u'/person/howard-lindzon', u'/organization/onthego-platforms'),
#  (u'/person/howard-lindzon', u'/organization/fanium'),
#  (u'/person/howard-lindzon', u'/organization/dekko'),
#  (u'/person/howard-lindzon', u'/organization/stocktwits'),
#  (u'/person/howard-lindzon', u'/organization/scopely'),
#  (u'/person/howard-lindzon', u'/organization/newhive'),
#  (u'/person/howard-lindzon', u'/organization/retrofit'),
#  (u'/person/howard-lindzon', u'/organization/blog-talk-radio'),
#  (u'/person/howard-lindzon', u'/organization/rebelmouse'),
#  (u'/person/howard-lindzon', u'/organization/embed-ly'),
#  (u'/person/howard-lindzon', u'/organization/videolicious'),
#  (u'/person/howard-lindzon', u'/organization/dailyworth'),
#  (u'/person/howard-lindzon', u'/organization/yieldbot'),
#  (u'/person/howard-lindzon', u'/organization/analyst'),
#  (u'/person/olivier-mathiot', u'/organization/1001pharmacies-com'),
#  (u'/person/olivier-mathiot', u'/organization/happyview'),
#  (u'/person/olivier-mathiot', u'/organization/kontest'),
#  (u'/person/olivier-mathiot', u'/organization/fvrier-46'),
#  (u'/organization/hyderabad-angels', u'/organization/whistletalk'),
#  (u'/organization/hyderabad-angels',
#   u'/organization/nowfloats-technologies-private-limited'),
#  (u'/organization/hyderabad-angels', u'/organization/mylabyogi-com'),
#  (u'/organization/hyderabad-angels',
#   u'/organization/thrillophilia-adventure-tours-pvt-ltd'),
#  (u'/organization/hyderabad-angels', u'/organization/online-prasad'),
#  (u'/organization/hyderabad-angels', u'/organization/edutor'),
#  (u'/organization/hyderabad-angels', u'/organization/zify'),
#  (u'/organization/spire-ventures', u'/organization/spaciousapp'),
#  (u'/person/lee-nackman', u'/organization/espresso-logic'),
#  (u'/organization/templeton-asset-management', u'/organization/huy-vietnam'),
#  (u'/person/bill-price-3', u'/organization/ombu'),
#  (u'/organization/capital-research-management-co',
#   u'/organization/remark-media'),
#  (u'/organization/jamjar-investments', u'/organization/toucanbox'),
#  (u'/organization/jamjar-investments', u'/organization/graze'),
#  (u'/organization/jamjar-investments', u'/organization/chronext-com'),
#  (u'/organization/jamjar-investments', u'/organization/popchips'),
#  (u'/organization/jamjar-investments', u'/organization/blue-bottle-coffee'),
#  (u'/organization/jamjar-investments', u'/organization/tails-com'),
#  (u'/organization/jamjar-investments', u'/organization/gojimo'),
#  (u'/organization/jamjar-investments', u'/organization/deliveroo'),
#  (u'/person/robert-last', u'/organization/boombotix'),
#  (u'/person/hadi-partovi', u'/organization/farmigo'),
#  (u'/person/hadi-partovi', u'/organization/livestar'),
#  (u'/person/hadi-partovi', u'/organization/boku'),
#  (u'/person/hadi-partovi', u'/organization/thinkfuse'),
#  (u'/person/hadi-partovi', u'/organization/indinero'),
#  (u'/person/hadi-partovi', u'/organization/wideorbit'),
#  (u'/person/hadi-partovi', u'/organization/dropbox'),
#  (u'/person/hadi-partovi', u'/organization/jamlegend'),
#  (u'/person/hadi-partovi', u'/organization/bluekai'),
#  (u'/person/hadi-partovi', u'/organization/vamo'),
#  (u'/person/hadi-partovi', u'/organization/practice-fusion'),
#  (u'/person/hadi-partovi', u'/organization/causes'),
#  (u'/person/hadi-partovi', u'/organization/opzi'),
#  (u'/person/hadi-partovi', u'/organization/viglink'),
#  (u'/person/hadi-partovi', u'/organization/viagogo'),
#  (u'/person/hadi-partovi', u'/organization/break-media'),
#  (u'/person/hadi-partovi', u'/organization/indie-bio'),
#  (u'/person/hadi-partovi', u'/organization/familiar'),
#  (u'/person/hadi-partovi', u'/organization/fonality'),
#  (u'/person/hadi-partovi', u'/organization/hampton-creek-foods'),
#  (u'/person/hadi-partovi', u'/organization/fivestars-loyalty'),
#  (u'/person/hadi-partovi', u'/organization/nervana-systems'),
#  (u'/person/hadi-partovi', u'/organization/flixster'),
#  (u'/person/hadi-partovi', u'/organization/clara-foods'),
#  (u'/person/hadi-partovi', u'/organization/change-org'),
#  (u'/person/hadi-partovi', u'/organization/thumbtack'),
#  (u'/person/hadi-partovi', u'/organization/opower'),
#  (u'/organization/orchid-asia-group-management', u'/organization/linekong'),
#  (u'/organization/orchid-asia-group-management',
#   u'/organization/yunnan-landsun-green-industry-group-co-ltd'),
#  (u'/organization/orchid-asia-group-management',
#   u'/organization/china-garment'),
#  (u'/organization/orchid-asia-group-management', u'/organization/cdel'),
#  (u'/organization/orchid-asia-group-management',
#   u'/organization/china-health-media-co-ltd'),
#  (u'/organization/orchid-asia-group-management',
#   u'/organization/united-information-technology-co-ltd'),
#  (u'/organization/orchid-asia-group-management',
#   u'/organization/sichuan-huiji-food-industry-co-ltd'),
#  (u'/organization/orchid-asia-group-management',
#   u'/organization/united-information-technology'),
#  (u'/organization/orchid-asia-group-management',
#   u'/organization/funplus-game'),
#  (u'/organization/orchid-asia-group-management',
#   u'/organization/embedded-internet-solutions'),
#  (u'/person/dmitriy-k', u'/organization/cashsquare'),
#  (u'/organization/sparklabs', u'/organization/blend-systems'),
#  (u'/organization/sparklabs', u'/organization/evain'),
#  (u'/person/yair-goldfinger', u'/organization/knockatv'),
#  (u'/person/yair-goldfinger', u'/organization/keepy'),
#  (u'/person/yair-goldfinger', u'/organization/pins'),
#  (u'/organization/saint-gobain', u'/organization/qivivo'),
#  (u'/organization/ecliptic-labs', u'/organization/performa-sports'),
#  (u'/organization/lauder-partners', u'/organization/promptu-systems'),
#  (u'/organization/lauder-partners', u'/organization/onlive'),
#  (u'/organization/lauder-partners', u'/organization/blip'),
#  (u'/organization/lauder-partners', u'/organization/trusted-insight'),
#  (u'/organization/lauder-partners', u'/organization/shotspotter'),
#  (u'/person/autumn-autrey', u'/organization/openlabel'),
#  (u'/organization/katsura-investments', u'/organization/galazar'),
#  (u'/person/jeremy-latrasse', u'/organization/orion-labs'),
#  (u'/organization/bessemer-venture-partners', u'/organization/intacct'),
#  (u'/organization/bessemer-venture-partners', u'/organization/revver'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/traffix-systems'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/ravello-systems'),
#  (u'/organization/bessemer-venture-partners', u'/organization/qwilt'),
#  (u'/organization/bessemer-venture-partners', u'/organization/verato'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/sirtris-pharmaceuticals'),
#  (u'/organization/bessemer-venture-partners', u'/organization/accuvein'),
#  (u'/organization/bessemer-venture-partners', u'/organization/parallels'),
#  (u'/organization/bessemer-venture-partners', u'/organization/tilera'),
#  (u'/organization/bessemer-venture-partners', u'/organization/revivio'),
#  (u'/organization/bessemer-venture-partners', u'/organization/expect-labs'),
#  (u'/organization/bessemer-venture-partners', u'/organization/zoosk'),
#  (u'/organization/bessemer-venture-partners', u'/organization/wearesupernova'),
#  (u'/organization/bessemer-venture-partners', u'/organization/cpower'),
#  (u'/organization/bessemer-venture-partners', u'/organization/smilebox'),
#  (u'/organization/bessemer-venture-partners', u'/organization/xtime'),
#  (u'/organization/bessemer-venture-partners', u'/organization/sweetlabs'),
#  (u'/organization/bessemer-venture-partners', u'/organization/sendgrid'),
#  (u'/organization/bessemer-venture-partners', u'/organization/eloqua'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/kroll-bond-rating-agency'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/ultrasolar-technology'),
#  (u'/organization/bessemer-venture-partners', u'/organization/olx'),
#  (u'/organization/bessemer-venture-partners', u'/organization/nephroplus'),
#  (u'/organization/bessemer-venture-partners', u'/organization/defense-net'),
#  (u'/organization/bessemer-venture-partners', u'/organization/tigo-energy'),
#  (u'/organization/bessemer-venture-partners', u'/organization/rocket-lab'),
#  (u'/organization/bessemer-venture-partners', u'/organization/shopify'),
#  (u'/organization/bessemer-venture-partners', u'/organization/team8'),
#  (u'/organization/bessemer-venture-partners', u'/organization/apperian'),
#  (u'/organization/bessemer-venture-partners', u'/organization/silversky'),
#  (u'/organization/bessemer-venture-partners', u'/organization/smule'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/simply-measured'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/streambase-systems'),
#  (u'/organization/bessemer-venture-partners', u'/organization/dgplabs'),
#  (u'/organization/bessemer-venture-partners', u'/organization/on-q-ity'),
#  (u'/organization/bessemer-venture-partners', u'/organization/hadapt'),
#  (u'/organization/bessemer-venture-partners', u'/organization/2u'),
#  (u'/organization/bessemer-venture-partners', u'/organization/omsignal'),
#  (u'/organization/bessemer-venture-partners', u'/organization/flex-pharma'),
#  (u'/organization/bessemer-venture-partners', u'/organization/auth0'),
#  (u'/organization/bessemer-venture-partners', u'/organization/vidyard'),
#  (u'/organization/bessemer-venture-partners', u'/organization/selectminds'),
#  (u'/organization/bessemer-venture-partners', u'/organization/nominum'),
#  (u'/organization/bessemer-venture-partners', u'/organization/twilio'),
#  (u'/organization/bessemer-venture-partners', u'/organization/enforta'),
#  (u'/organization/bessemer-venture-partners', u'/organization/vayyar'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/vasona-networks'),
#  (u'/organization/bessemer-venture-partners', u'/organization/therative'),
#  (u'/organization/bessemer-venture-partners', u'/organization/ctera-networks'),
#  (u'/organization/bessemer-venture-partners', u'/organization/playdom'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/allena-pharmaceuticals'),
#  (u'/organization/bessemer-venture-partners', u'/organization/miasole'),
#  (u'/organization/bessemer-venture-partners', u'/organization/nanosatisfi'),
#  (u'/organization/bessemer-venture-partners', u'/organization/hightower'),
#  (u'/organization/bessemer-venture-partners', u'/organization/convertro'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/alnara-pharmaceuticals'),
#  (u'/organization/bessemer-venture-partners', u'/organization/clever'),
#  (u'/organization/bessemer-venture-partners', u'/organization/wireover'),
#  (u'/organization/bessemer-venture-partners', u'/organization/adap-tv'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/cornerstone-ondemand'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/siano-mobile-silicon'),
#  (u'/organization/bessemer-venture-partners', u'/organization/bladelogic'),
#  (u'/organization/bessemer-venture-partners', u'/organization/involver'),
#  (u'/organization/bessemer-venture-partners', u'/organization/return-path'),
#  (u'/organization/bessemer-venture-partners', u'/organization/crowdflower'),
#  (u'/organization/bessemer-venture-partners', u'/organization/brightbytes'),
#  (u'/organization/bessemer-venture-partners', u'/organization/gotv-networks'),
#  (u'/organization/bessemer-venture-partners', u'/organization/box'),
#  (u'/organization/bessemer-venture-partners', u'/organization/wandera'),
#  (u'/organization/bessemer-venture-partners', u'/organization/discoverly'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/raise-marketplace'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/health-essentials'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/goodmail-system'),
#  (u'/organization/bessemer-venture-partners', u'/organization/boxed'),
#  (u'/organization/bessemer-venture-partners', u'/organization/cerulean'),
#  (u'/organization/bessemer-venture-partners', u'/organization/flock'),
#  (u'/organization/bessemer-venture-partners', u'/organization/bizo'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/anunta-technology-management-services'),
#  (u'/organization/bessemer-venture-partners', u'/organization/zopa'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/fractyl-laboratories'),
#  (u'/organization/bessemer-venture-partners', u'/organization/alcresta'),
#  (u'/organization/bessemer-venture-partners', u'/organization/social-tables'),
#  (u'/organization/bessemer-venture-partners', u'/organization/infinio'),
#  (u'/organization/bessemer-venture-partners', u'/organization/clearslide'),
#  (u'/organization/bessemer-venture-partners', u'/organization/reputation-com'),
#  (u'/organization/bessemer-venture-partners', u'/organization/stromedix'),
#  (u'/organization/bessemer-venture-partners', u'/organization/intercom'),
#  (u'/organization/bessemer-venture-partners', u'/organization/dekko'),
#  (u'/organization/bessemer-venture-partners', u'/organization/omgpop'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/elemental-cyber-security'),
#  (u'/organization/bessemer-venture-partners', u'/organization/quidsi'),
#  (u'/organization/bessemer-venture-partners', u'/organization/light'),
#  (u'/organization/bessemer-venture-partners', u'/organization/reglobe'),
#  (u'/organization/bessemer-venture-partners', u'/organization/deliveryagent'),
#  (u'/organization/bessemer-venture-partners', u'/organization/yodle'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/mojave-networks'),
#  (u'/organization/bessemer-venture-partners', u'/organization/kajeet'),
#  (u'/organization/bessemer-venture-partners', u'/organization/homesuite'),
#  (u'/organization/bessemer-venture-partners', u'/organization/xtreme-power'),
#  (u'/organization/bessemer-venture-partners', u'/organization/way-systems'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/clearcare-online'),
#  (u'/organization/bessemer-venture-partners', u'/organization/42floors'),
#  (u'/organization/bessemer-venture-partners', u'/organization/grow-mobile'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/bastille-networks-2'),
#  (u'/organization/bessemer-venture-partners', u'/organization/lifelock'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/avalanche-technology'),
#  (u'/organization/bessemer-venture-partners', u'/organization/quadriserv'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/orient-green-power'),
#  (u'/organization/bessemer-venture-partners', u'/organization/criteo'),
#  (u'/organization/bessemer-venture-partners', u'/organization/twitch'),
#  (u'/organization/bessemer-venture-partners', u'/organization/soluto'),
#  (u'/organization/bessemer-venture-partners', u'/organization/hunch'),
#  (u'/organization/bessemer-venture-partners', u'/organization/knewton'),
#  (u'/organization/bessemer-venture-partners', u'/organization/pure-networks'),
#  (u'/organization/bessemer-venture-partners', u'/organization/britely'),
#  (u'/organization/bessemer-venture-partners', u'/organization/welltok'),
#  (u'/organization/bessemer-venture-partners', u'/organization/insightsquared'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/main-street-hub'),
#  (u'/organization/bessemer-venture-partners', u'/organization/stratoscale'),
#  (u'/organization/bessemer-venture-partners', u'/organization/wix'),
#  (u'/organization/bessemer-venture-partners', u'/organization/colorchip'),
#  (u'/organization/bessemer-venture-partners', u'/organization/newvoicemedia'),
#  (u'/organization/bessemer-venture-partners', u'/organization/servicetitan'),
#  (u'/organization/bessemer-venture-partners', u'/organization/doubledutch'),
#  (u'/organization/bessemer-venture-partners', u'/organization/speakeasy-3'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/access-sports-media-2'),
#  (u'/organization/bessemer-venture-partners', u'/organization/onecloud-labs'),
#  (u'/organization/bessemer-venture-partners', u'/organization/gainsight'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/mind-pirate-inc'),
#  (u'/organization/bessemer-venture-partners', u'/organization/netuitive'),
#  (u'/organization/bessemer-venture-partners', u'/organization/nitrous-io'),
#  (u'/organization/bessemer-venture-partners', u'/organization/pagerduty'),
#  (u'/organization/bessemer-venture-partners', u'/organization/ba-systems'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/thinking-phone-networks'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/pinnacle-engines'),
#  (u'/organization/bessemer-venture-partners', u'/organization/cloudlock'),
#  (u'/organization/bessemer-venture-partners', u'/organization/quantopian'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/activ-financial-systems'),
#  (u'/organization/bessemer-venture-partners', u'/organization/betterment'),
#  (u'/organization/bessemer-venture-partners', u'/organization/kurbo-health'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/berkeley-design-automation'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/hands-on-mobile'),
#  (u'/organization/bessemer-venture-partners', u'/organization/simplyinsured'),
#  (u'/organization/bessemer-venture-partners', u'/organization/scratch-2'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/procore-technologies'),
#  (u'/organization/bessemer-venture-partners', u'/organization/oxagen'),
#  (u'/organization/bessemer-venture-partners',
# ...
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/internet-identity'),
#  (u'/organization/bessemer-venture-partners', u'/organization/mindbody'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/flat-world-knowledge'),
#  (u'/organization/bessemer-venture-partners', u'/organization/netli'),
#  (u'/organization/bessemer-venture-partners', u'/organization/onestop'),
#  (u'/organization/bessemer-venture-partners', u'/organization/snapdeal'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/altair-semiconductor'),
#  (u'/organization/bessemer-venture-partners', u'/organization/mailcloud'),
#  (u'/organization/bessemer-venture-partners', u'/organization/yelp'),
#  (u'/organization/bessemer-venture-partners', u'/organization/cirtas'),
#  (u'/organization/bessemer-venture-partners', u'/organization/virtru'),
#  (u'/organization/bessemer-venture-partners', u'/organization/kovio'),
#  (u'/organization/bessemer-venture-partners', u'/organization/estimote'),
#  (u'/organization/bessemer-venture-partners', u'/organization/livspace'),
#  (u'/organization/bessemer-venture-partners',
#   u'/organization/isight-partners'),
#  (u'/organization/bessemer-venture-partners', u'/organization/nextmedium'),
#  (u'/person/oliver-samwer', u'/organization/mfg'),
#  (u'/organization/anxon-international', u'/organization/3i-systems'),
#  (u'/organization/chimerabio', u'/organization/sistemic'),
#  (u'/organization/chimerabio', u'/organization/ocutec'),
#  (u'/organization/irep-co-ltd', u'/organization/lockon-co-ltd'),
#  (u'/person/ary-chame', u'/organization/guidecentral'),
#  (u'/person/sonja-perkins', u'/organization/gemshare'),
#  (u'/person/sonja-perkins', u'/organization/lover-ly'),
#  (u'/person/sonja-perkins', u'/organization/kichit'),
#  (u'/organization/express-ventures', u'/organization/certona'),
#  (u'/organization/express-ventures', u'/organization/eyespot'),
#  (u'/organization/express-ventures',
#   u'/organization/e-band-communications-corporation'),
#  (u'/organization/nikon', u'/organization/healios-k-k'),
#  (u'/organization/archetype', u'/organization/flydata'),
#  (u'/organization/archetype', u'/organization/abeja-inc-'),
#  (u'/organization/archetype', u'/organization/dennoo'),
#  (u'/organization/odyssey-research', u'/organization/picaboo'),
#  (u'/person/grace-stanat', u'/organization/ghostruck'),
#  (u'/person/grace-stanat', u'/organization/classpass'),
#  (u'/person/gary-levitt', u'/organization/squareone'),
#  (u'/person/gary-levitt', u'/organization/immediately'),
#  (u'/person/paul-bricault', u'/organization/tubular-labs'),
#  (u'/person/paul-bricault', u'/organization/incinerator-studios'),
#  (u'/person/paul-bricault', u'/organization/gamesalad'),
#  (u'/person/paul-bricault', u'/organization/wish'),
#  (u'/person/paul-bricault', u'/organization/idealists'),
#  (u'/person/paul-bricault', u'/organization/bread-labs'),
#  (u'/person/carlos-curioni', u'/organization/guiabolso'),
#  (u'/organization/tyco-international', u'/organization/aperto-networks'),
#  (u'/organization/tyco-international', u'/organization/icontrol'),
#  (u'/person/bob-jacobson', u'/organization/iris-tv'),
#  (u'/person/jeff-glavan', u'/organization/fanpulse'),
#  (u'/person/brian-jenkins', u'/organization/anycloud'),
#  (u'/organization/digital-science', u'/organization/authorea'),
#  (u'/organization/digital-science', u'/organization/berresearch'),
#  (u'/organization/digital-science', u'/organization/writelatex'),
#  (u'/organization/digital-science', u'/organization/tetrascience-inc-'),
#  (u'/organization/acumen-fund', u'/organization/biolite'),
#  (u'/organization/acumen-fund', u'/organization/sewa'),
#  (u'/organization/acumen-fund', u'/organization/water-health-international'),
#  (u'/organization/acumen-fund', u'/organization/esoko'),
#  (u'/organization/acumen-fund', u'/organization/hippocampus-learning-centres'),
#  (u'/organization/acumen-fund', u'/organization/paga'),
#  (u'/organization/acumen-fund', u'/organization/d-light-design'),
#  (u'/organization/china-ease-management', u'/organization/solarvista-media'),
#  (u'/organization/solvay', u'/organization/polyera'),
#  (u'/organization/solvay', u'/organization/plextronics'),
#  (u'/person/matt-higgins', u'/organization/preplay'),
#  (u'/organization/rough-draft-ventures', u'/organization/grove-labs'),
#  (u'/organization/rough-draft-ventures', u'/organization/dash-electric'),
#  (u'/organization/rough-draft-ventures', u'/organization/strut'),
#  (u'/organization/rough-draft-ventures',
#   u'/organization/indico-data-solutions'),
#  (u'/organization/rough-draft-ventures', u'/organization/virgent-realty'),
#  (u'/organization/rough-draft-ventures', u'/organization/technical-machine'),
#  (u'/organization/rough-draft-ventures', u'/organization/dyli'),
#  (u'/organization/rough-draft-ventures',
#   u'/organization/sand-hill-exchange-2'),
#  (u'/organization/rough-draft-ventures', u'/organization/mercaux'),
#  (u'/organization/rough-draft-ventures', u'/organization/tetrascience-inc-'),
#  (u'/organization/rough-draft-ventures', u'/organization/onboardiq'),
#  (u'/organization/rough-draft-ventures', u'/organization/beepi'),
#  (u'/organization/rough-draft-ventures', u'/organization/bowery'),
#  (u'/organization/rough-draft-ventures', u'/organization/deskconnect'),
#  (u'/organization/rough-draft-ventures', u'/organization/lifeguard-games'),
#  (u'/organization/rough-draft-ventures', u'/organization/side'),
#  (u'/organization/rough-draft-ventures', u'/organization/local-lift'),
#  (u'/organization/rough-draft-ventures', u'/organization/watchsend'),
#  (u'/organization/rough-draft-ventures', u'/organization/charitweet'),
#  (u'/organization/rough-draft-ventures', u'/organization/valet-2'),
#  (u'/organization/rough-draft-ventures', u'/organization/downtyme'),
#  (u'/organization/rough-draft-ventures',
#   u'/organization/sonabos-technologies'),
#  (u'/organization/rough-draft-ventures', u'/organization/mark43'),
#  (u'/organization/rough-draft-ventures', u'/organization/vaska-technologies'),
#  (u'/organization/rough-draft-ventures', u'/organization/go-barnacle'),
#  (u'/organization/rough-draft-ventures', u'/organization/instabase'),
#  (u'/organization/rough-draft-ventures', u'/organization/pegasense'),
#  (u'/organization/rough-draft-ventures', u'/organization/valued-investing'),
#  (u'/organization/rough-draft-ventures', u'/organization/knyplex'),
#  (u'/organization/rough-draft-ventures', u'/organization/practicegigs'),
#  (u'/organization/rough-draft-ventures', u'/organization/cymbal'),
#  (u'/organization/rough-draft-ventures', u'/organization/fresco-news'),
#  (u'/organization/rough-draft-ventures', u'/organization/cloudstitch'),
#  (u'/organization/rough-draft-ventures', u'/organization/mobilesuites'),
#  (u'/organization/rough-draft-ventures', u'/organization/smarking'),
#  (u'/organization/rough-draft-ventures', u'/organization/tvision-insights'),
#  (u'/organization/rough-draft-ventures', u'/organization/gifyoutube'),
#  (u'/organization/rough-draft-ventures', u'/organization/nightingale'),
#  (u'/organization/rough-draft-ventures', u'/organization/healo-health'),
#  (u'/organization/rough-draft-ventures', u'/organization/pluto-mail'),
#  (u'/organization/raffles-venture-partner', u'/organization/bemyguest'),
#  (u'/person/vince-thompson', u'/organization/fanbread'),
#  (u'/person/chris-pronger', u'/organization/lockerdome'),
#  (u'/organization/arthur-ventures-llc', u'/organization/rhiza-labs'),
#  (u'/organization/arthur-ventures-llc', u'/organization/intelligent-insites'),
#  (u'/organization/arthur-ventures-llc', u'/organization/avalara'),
#  (u'/organization/arthur-ventures-llc', u'/organization/businesscard2'),
#  (u'/organization/arthur-ventures-llc', u'/organization/zipnosis'),
#  (u'/organization/arthur-ventures-llc', u'/organization/when-i-work'),
#  (u'/organization/arthur-ventures-llc', u'/organization/preventice'),
#  (u'/organization/arthur-ventures-llc', u'/organization/agronomic-technology'),
#  (u'/organization/arthur-ventures-llc', u'/organization/ambassador'),
#  (u'/organization/arthur-ventures-llc', u'/organization/leadpages'),
#  (u'/organization/arthur-ventures-llc', u'/organization/drifty'),
#  (u'/organization/arthur-ventures-llc', u'/organization/infusionsoft'),
#  (u'/organization/arthur-ventures-llc', u'/organization/catalyze'),
#  (u'/organization/arthur-ventures-llc', u'/organization/flipgrid'),
#  (u'/person/jose-manuel-villanueva', u'/organization/groupalia'),
#  (u'/person/john-suliman', u'/organization/binary-thumb'),
#  (u'/organization/access-medical-ventures', u'/organization/cartiheal'),
#  (u'/organization/36kr', u'/organization/chelaile'),
#  (u'/organization/36kr', u'/organization/yikuaiqu'),
#  (u'/organization/36kr', u'/organization/smellme'),
#  (u'/person/rodrigo-carvalho', u'/organization/trendkite'),
#  (u'/organization/sourcenext', u'/organization/money-forward'),
#  (u'/person/gaurav-bhatnagar', u'/organization/theshoppingpro'),
#  (u'/organization/efficacy-capital', u'/organization/arius-research'),
#  (u'/organization/innofinance-oy', u'/organization/max-rumpus'),
#  (u'/organization/plymouth-venture-partners', u'/organization/zebra-mobile'),
#  (u'/organization/plymouth-venture-partners', u'/organization/v-i-o'),
#  (u'/organization/plymouth-venture-partners', u'/organization/clevex'),
#  (u'/organization/plymouth-venture-partners', u'/organization/janeeva'),
#  (u'/organization/plymouth-venture-partners',
#   u'/organization/redpath-integrated-pathology'),
#  (u'/organization/plymouth-venture-partners',
#   u'/organization/futurenet-group'),
#  (u'/organization/plymouth-venture-partners', u'/organization/uico-inc'),
#  (u'/organization/plymouth-venture-partners', u'/organization/docusphere'),
#  (u'/organization/plymouth-venture-partners',
#   u'/organization/certified-security-solutions'),
#  (u'/organization/plymouth-venture-partners',
#   u'/organization/pump-engineering'),
#  (u'/organization/plymouth-venture-partners', u'/organization/xanedu'),
#  (u'/organization/plymouth-venture-partners',
#   u'/organization/incontext-solutions'),
#  (u'/organization/plymouth-venture-partners', u'/organization/idv-solutions'),
#  (u'/organization/plymouth-venture-partners',
#   u'/organization/relume-technologies'),
#  (u'/organization/plymouth-venture-partners', u'/organization/cloudone'),
#  (u'/organization/plymouth-venture-partners',
#   u'/organization/lynx-network-group'),
#  (u'/organization/okangel-sidecar-fund', u'/organization/dermamedics'),
#  (u'/organization/okangel-sidecar-fund',
#   u'/organization/sway-medical-technologies'),
#  (u'/person/gregory-david-roberts', u'/organization/zola-books'),
#  (u'/person/juan-lopez-valcarcel', u'/organization/traitperception'),
#  (u'/organization/dsm-venturing', u'/organization/verdezyne'),
#  (u'/organization/dsm-venturing', u'/organization/interface-biologics'),
#  (u'/organization/dsm-venturing', u'/organization/regentis-biomaterials'),
#  (u'/organization/dsm-venturing', u'/organization/sciona'),
#  (u'/organization/dsm-venturing', u'/organization/upfront-chromatography'),
#  (u'/organization/dsm-venturing', u'/organization/micromuscle'),
#  (u'/organization/dsm-venturing', u'/organization/zeavision'),
#  (u'/organization/dsm-venturing', u'/organization/novomer'),
#  (u'/organization/dsm-venturing',
#   u'/organization/food-quality-sensor-international'),
#  (u'/organization/dsm-venturing', u'/organization/chromadex'),
#  (u'/organization/dsm-venturing', u'/organization/integragen'),
#  (u'/person/timothy-a-springer', u'/organization/selecta-biosciences'),
#  (u'/organization/startlabs-research', u'/organization/casetrek'),
#  (u'/organization/comtex', u'/organization/gdgt'),
#  (u'/organization/centerview-capital', u'/organization/richrelevance'),
#  (u'/organization/hite-capital', u'/organization/mint'),
#  (u'/organization/alkermes', u'/organization/civitas-therapeutics'),
#  (u'/organization/southern-california-gas-company', u'/organization/sopogy'),
#  (u'/organization/southern-california-gas-company',
#   u'/organization/clearedge-power'),
#  (u'/person/lorne-zalesin', u'/organization/seelio'),
#  (u'/organization/asiatech-management', u'/organization/knowlent'),
#  (u'/organization/asiatech-management', u'/organization/oqo'),
#  (u'/organization/asiatech-management', u'/organization/maxlinear'),
#  (u'/organization/asiatech-management',
#   u'/organization/clear-shape-technologies'),
#  (u'/organization/asiatech-management', u'/organization/ciranova'),
#  (u'/organization/asiatech-management', u'/organization/visualon'),
#  (u'/organization/asiatech-management', u'/organization/abazab'),
#  (u'/person/jim-alvarez', u'/organization/crowdly'),
#  (u'/person/georg-berner', u'/organization/janzz'),
#  (u'/organization/baseline-ventures', u'/organization/ownlocal'),
#  (u'/organization/baseline-ventures', u'/organization/bancbox'),
#  (u'/organization/baseline-ventures', u'/organization/nway'),
#  (u'/organization/baseline-ventures', u'/organization/bookfresh'),
#  (u'/organization/baseline-ventures', u'/organization/vook'),
#  (u'/organization/baseline-ventures', u'/organization/datalot-inc'),
#  (u'/organization/baseline-ventures', u'/organization/adara-media'),
#  (u'/organization/baseline-ventures', u'/organization/shape-security'),
#  (u'/organization/baseline-ventures', u'/organization/liftoff-mobile'),
#  (u'/organization/baseline-ventures', u'/organization/yardbarker'),
#  (u'/organization/baseline-ventures', u'/organization/rupture'),
#  (u'/organization/baseline-ventures', u'/organization/machine-zone'),
#  (u'/organization/baseline-ventures', u'/organization/blekko'),
#  (u'/organization/baseline-ventures', u'/organization/fraudwalltechnologies'),
#  (u'/organization/baseline-ventures', u'/organization/weebly'),
#  (u'/organization/baseline-ventures', u'/organization/pickwick-weller'),
#  (u'/organization/baseline-ventures', u'/organization/sharethrough'),
#  (u'/organization/baseline-ventures', u'/organization/worksimple'),
#  (u'/organization/baseline-ventures', u'/organization/aardvark'),
#  (u'/organization/baseline-ventures', u'/organization/trialpay'),
#  (u'/organization/baseline-ventures', u'/organization/reverb-technologies'),
#  (u'/organization/baseline-ventures', u'/organization/versly'),
#  (u'/organization/baseline-ventures', u'/organization/tastemakerx'),
#  (u'/organization/baseline-ventures', u'/organization/digit-4'),
#  (u'/organization/baseline-ventures', u'/organization/anchorintelligence'),
#  (u'/organization/baseline-ventures', u'/organization/crashlytics'),
#  (u'/organization/baseline-ventures', u'/organization/expensify-com'),
#  (u'/organization/baseline-ventures', u'/organization/xobni'),
#  (u'/organization/baseline-ventures', u'/organization/stackmob'),
#  (u'/organization/baseline-ventures', u'/organization/pantheon'),
#  (u'/organization/baseline-ventures', u'/organization/apiary'),
#  (u'/organization/baseline-ventures', u'/organization/smyte'),
#  (u'/organization/baseline-ventures', u'/organization/gild'),
#  (u'/organization/baseline-ventures', u'/organization/sendori'),
#  (u'/organization/baseline-ventures', u'/organization/social-finance'),
#  (u'/organization/baseline-ventures', u'/organization/docverse'),
#  (u'/organization/baseline-ventures', u'/organization/appuri'),
#  (u'/organization/baseline-ventures', u'/organization/instagram'),
#  (u'/organization/baseline-ventures', u'/organization/truste'),
#  (u'/organization/baseline-ventures', u'/organization/librato'),
#  (u'/organization/baseline-ventures', u'/organization/stitch-fix'),
#  (u'/organization/baseline-ventures', u'/organization/uservoice'),
#  (u'/organization/baseline-ventures', u'/organization/picturelife'),
#  (u'/organization/baseline-ventures', u'/organization/avocado-software'),
#  (u'/organization/baseline-ventures', u'/organization/haute-secure'),
#  (u'/organization/baseline-ventures', u'/organization/boombotix'),
#  (u'/organization/baseline-ventures', u'/organization/pagerduty'),
#  (u'/organization/baseline-ventures', u'/organization/mango-health'),
#  (u'/organization/baseline-ventures', u'/organization/tinypulse'),
#  (u'/organization/baseline-ventures', u'/organization/betterfinance'),
#  (u'/organization/baseline-ventures', u'/organization/goinstant'),
#  (u'/organization/baseline-ventures', u'/organization/giftly'),
#  ...]

# %%
# Template for what a scoring function should look like
# Input --> source and destination, reference to graph
# Output --> score (how do we normalize???)
# g is passed by reference, by default, in python
def test_score(investor, company, g):
    return 0.5

# return a random float as the score
def rand_score(investor, company, g):
    return random.random()

# calculate the preferential attachment score (normalized to the max preferential attachment score)
# max(preG.in_degree().values())*max(preG.out_degree().values()) ---> 29,000
def pa_score(investor, company, g):
    investor_degree = g.out_degree(investor)
    company_degree = g.in_degree(company)
    
    if investor_degree == 0: investor_degree = 1
    if company_degree == 0: company_degree = 1
    return investor_degree*company_degree/29000

# %%
preG.nodes()
len(preG[u'/organization/rsj-private-equity'])*len(preG[u'/organization/rsj-private-equity'])
pa_score(u'/organization/sequoia-capital', u'/organization/uber', preG)
# Out:
# 0.35

# %%
# We want to factor our code so that it is efficient for simple multiprocessing
#
# Given a LIST of investors, a SINGLE company, calculate the number of TP/TN/FP/FN
# and return as a counter. This is meant to run inside of eval_prec_recall.
def company_score_pred_eval(company, investors, truth, score_function, threshold, g):
    result = Counter()
    neighbors = g.predecessors(company)
    
    for investor in investors:
        # Do no prediction on existing links
        if investor in g.neighbors:
            continue
            
        # Calculate the score_function score
        score = score_function(investor, company, g)

        # Make a prediction based on the threshold
        link_predicted = (score > threshold)

        # Record if it was a true/false pos or true/false neg
        if link_predicted:
            if (investor, company) in truth:
                result['tp'] += 1
            else:
                result['fp'] += 1
        else:
            if (investor, company) not in truth:
                result['tn'] += 1
            else:
                result['fn'] += 1
    
    return result

# %%
# Out:
# 15514

# %%
# Test Company Score/Pred/Eval
random_truth = set(map(lambda x: (random.randint(1,2000), random.randint(2001, 4000)), range(1,10000)))
company_score_pred_eval(2001, range(1, 2000), random_truth, rand_score, 0.5, [])
# Out:
# Counter({'fn': 2, 'fp': 1020, 'tn': 976, 'tp': 1})

# %%
#### SINGLE THRESHOLD VERSION WITH MULTIPROCESSING
# It's inefficient to calculate and store all of the scores
# between all possible links
#
# truth is a set-like object containing all links (investor, company)
# created in the validation period
#
# score_function: a function that calculates a normalized
# score given investor, company, g
#
# threshold is a float above which values will be predicted positive
#
# g is the underlying graph
#
# RETURNS the confusion matrix.
def multi_eval_prec_recall(truth, score_function, threshold, g):
    # initialize multiprocessing pool
    pool = mp.Pool(processes=4)
        
    # initialize counters
    full_results = Counter({'tp':0, 'tn':0, 'fp':0, 'fn':0})
    
    # initialize list of companies and investors
    investors = map(lambda x: x[0],
                    filter(lambda x: x[1] == 0,
                    nx.get_node_attributes(g, "bipartite").items()))
    companies = map(lambda x: x[0],
                    filter(lambda x: x[1] == 1,
                    nx.get_node_attributes(g, "bipartite").items()))
    
    # Generate a function that is a function of just company, from MP
    evaluator = functools.partial(company_score_pred_eval, 
                                  truth=truth,
                                  score_function=score_function, 
                                  threshold=threshold,
                                  g=g,
                                  investors=investors)
    
    # iterate over all companies
    query = pool.imap(evaluator, companies, math.ceil(len(investors)/16))
    
    full_results = reduce(lambda x, y: x + y, query)

    pool.close()
    pool.join()

    return full_results

# %%
def calc_prec(confusion):
    (tp, tn, fp, fn) = (confusion["tp"], confusion["tn"], confusion["fp"], confusion["fn"])
    
    # calculate precision
    if (tp+fp) > 0:
        precision = tp/(tp+fp)
    else:
        precision = np.NaN
    
    return precision

def calc_recall(confusion):
    (tp, tn, fp, fn) = (confusion["tp"], confusion["tn"], confusion["fp"], confusion["fn"])
    
    # calculate recall
    if (tp+fn) > 0:
        recall = tp/(tp+fn)
    else:
        recall = np.NaN
    
    return recall

def calc_tpr(confusion):
    (tp, tn, fp, fn) = (confusion["tp"], confusion["tn"], confusion["fp"], confusion["fn"])
    
    # calculate tpr
    if (tp+fp) > 0:
        tpr = tp/(tp+fp)
    else:
        tpr = np.NaN
    
    return tpr

def calc_fpr(confusion):
    (tp, tn, fp, fn) = (confusion["tp"], confusion["tn"], confusion["fp"], confusion["fn"])
    
    # calculate tpr
    if (tp+fp) > 0:
        fpr = fp/(tn+fp)
    else:
        fpr = np.NaN
    
    return fpr

# %%
multi_eval_prec_recall(,rand_score, 0.1, preG)

# %%
# Test Eval/Prec/Recall 
random_truth = set(map(lambda x: (random.randint(1,2000), random.randint(2001, 4000)), range(1,1000)))
# %time multi_eval_prec_recall(random_truth, rand_score, 0.8, [])
# Out:
# CPU times: user 44 ms, sys: 16 ms, total: 60 ms
# Wall time: 1.32 s
# Counter({'fn': 785, 'fp': 798874, 'tn': 3196128, 'tp': 214})

# %%
def calc_multiple_results(truth, score_function, g, steps):
    print "START: ", datetime.datetime.now()
    results = []
    for threshold in map(lambda x: x/steps, range(1,steps)):
        results.append(multi_eval_prec_recall(truth, score_function, threshold, g))
        print threshold, datetime.datetime.now()

    print "END: ", datetime.datetime.now()
    
    return results

def calc_roc_data(results):
    tpr = [calc_tpr(result) for result in results]
    fpr = [calc_fpr(result) for result in results]
    
    return (tpr, fpr)

# %%
random_truth = set(map(lambda x: (random.randint(1,2000), random.randint(2001, 4000)), range(1,100000)))
results = calc_multiple_results(random_truth, rand_score, [], 20)
(tpr, fpr) = calc_roc_data(results)
# Out:
# START:  2015-12-05 20:58:22.437239
# 0.05 2015-12-05 20:58:24.882007
# 0.1 2015-12-05 20:58:27.413016
# 0.15 2015-12-05 20:58:30.005226
# 0.2 2015-12-05 20:58:32.585362
# 0.25 2015-12-05 20:58:35.139750
# 0.3 2015-12-05 20:58:37.707011
# 0.35 2015-12-05 20:58:40.280961
# 0.4 2015-12-05 20:58:43.332311
# 0.45 2015-12-05 20:58:45.954972
# 0.5 2015-12-05 20:58:48.785807
# 0.55 2015-12-05 20:58:52.106923
# 0.6 2015-12-05 20:58:55.712045
# 0.65 2015-12-05 20:58:59.416429
# 0.7 2015-12-05 20:59:02.748872
# 0.75 2015-12-05 20:59:05.995034
# 0.8 2015-12-05 20:59:09.512731
# 0.85 2015-12-05 20:59:12.033199
# 0.9 2015-12-05 20:59:14.431902
# 0.95 2015-12-05 20:59:16.768902
# END:  2015-12-05 20:59:16.768971

# %%
plt.plot(fpr, tpr, label = "Random Prediction")

plt.title("ROC Curves")
plt.xlim([0,1])
#plt.ylim([0,1])
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.legend()
plt.show()

# %%
    # CONSIDER USE PRUNING TO REDUCE NUMBER OF COMPUTATIONS FOR CERTAIN TYPES OF COMPUTATIONS
