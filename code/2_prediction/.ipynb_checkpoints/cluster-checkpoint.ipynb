# %%
import pandas as pd
import glob
import datetime as dt
import networkx as nx
import operator
import random

# %%
def loadEdgelist(filename):
	# Readin graph
	g = nx.read_edgelist(filename, 
	                     delimiter="\t", 
	                     create_using  = nx.DiGraph(), 
	                     data=True)

	# Convert Weight To Float
	temp = map(lambda (x, y): (x, float(y)), 
			   nx.get_edge_attributes(g, "weight").items())
	nx.set_edge_attributes(g, "weight", dict(temp))

	# Convert Date to datetime
	temp = map(lambda (x, y): (x, dt.datetime.strptime(y, "%Y-%m-%d")), 
			   nx.get_edge_attributes(g, "date").items())
	nx.set_edge_attributes(g, "date", dict(temp))

	return g

def writeEdgelist(g, filename):
    # Convert date to string
    temp = map(lambda (x, y): (x, y.strftime('%Y-%m-%d')), 
               nx.get_edge_attributes(g, "date").items())
    nx.set_edge_attributes(g, "date", dict(temp))
    
    # Write to file
    nx.write_edgelist(g,filename, delimiter="\t", data=True)

# %%
df = pd.DataFrame()
for file in glob.glob("/home/charles/siliconvalleyanalysis/code/2_prediction/temp/*"):
    df = pd.concat([df, pd.read_csv(file)], ignore_index=True)

# %%
df[df.company == "/organization/uber"]
# Out:
#                                            investor             company  \
# 6654   /organization/kleiner-perkins-caufield-byers  /organization/uber
# 6668                        /organization/blackrock  /organization/uber
# 6671                  /organization/summit-partners  /organization/uber
# 6690                   /organization/menlo-ventures  /organization/uber
# 6692            /organization/wellington-management  /organization/uber
# 6695                  /organization/google-ventures  /organization/uber
# 6708             /organization/fidelity-investments  /organization/uber
# 21248                       /organization/microsoft  /organization/uber
# 21254      /organization/bennett-coleman-and-co-ltd  /organization/uber
# 22287         /organization/tata-opportunities-fund  /organization/uber
# 22302                    /organization/tata-capital  /organization/uber
# 23303      /organization/qatar-investment-authority  /organization/uber
# 23312       /organization/new-enterprise-associates  /organization/uber
# 23337        /organization/valiant-capital-partners  /organization/uber
# 23345               /organization/lone-pine-capital  /organization/uber
# 23358                 /organization/sherpa-ventures  /organization/uber
# 24026                           /organization/baidu  /organization/uber
# 25978                   /organization/goldman-sachs  /organization/uber
# 27641              /organization/foundation-capital  /organization/uber
# 27672          /organization/accelerate-it-ventures  /organization/uber
# 27740                  /organization/times-internet  /organization/uber
#
#            weight        date
# 6654    150000000  2014-06-06
# 6668    150000000  2014-06-06
# 6671    150000000  2014-06-06
# 6690    150000000  2014-06-06
# 6692    150000000  2014-06-06
# 6695    150000000  2014-06-06
# 6708    150000000  2014-06-06
# 21248   500000000  2015-07-31
# 21254   500000000  2015-07-31
# 22287    50000000  2015-08-19
# 22302    50000000  2015-08-19
# 23303   240000000  2014-12-04
# 23312   240000000  2014-12-04
# 23337   240000000  2014-12-04
# 23345   240000000  2014-12-04
# 23358   240000000  2014-12-04
# 24026   600000000  2014-12-16
# 25978  1600000000  2015-01-21
# 27641   333333333  2015-02-18
# 27672   333333333  2015-02-18
# 27740   333333333  2015-02-18

# %%
# new_edges = {}
# for i in df[["investor", "company"]].values.tolist():
#     start_node = i[0]
#     end_node = i[1]
    
#     if start_node not in new_edges:
#         new_edges[start_node] = set([end_node])
#     else:
#         new_edges[start_node].add(end_node)

# %%
new_edges_s = {}
for i in df[["investor", "company"]].values.tolist():
    start_node = i[0]
    end_node = i[1]

    if end_node not in new_edges_s:
        new_edges_s[end_node] = set([start_node])
    else:
        new_edges_s[end_node].add(start_node)

# %%
new_edges_s["/organization/uber"]
# Out:
# {'/organization/accelerate-it-ventures',
#  '/organization/baidu',
#  '/organization/bennett-coleman-and-co-ltd',
#  '/organization/blackrock',
#  '/organization/fidelity-investments',
#  '/organization/foundation-capital',
#  '/organization/goldman-sachs',
#  '/organization/google-ventures',
#  '/organization/kleiner-perkins-caufield-byers',
#  '/organization/lone-pine-capital',
#  '/organization/menlo-ventures',
#  '/organization/microsoft',
#  '/organization/new-enterprise-associates',
#  '/organization/qatar-investment-authority',
#  '/organization/sherpa-ventures',
#  '/organization/summit-partners',
#  '/organization/tata-capital',
#  '/organization/tata-opportunities-fund',
#  '/organization/times-internet',
#  '/organization/valiant-capital-partners',
#  '/organization/wellington-management'}

# %%
m = {}
for key in new_edges_s:
    print key, len(new_edges_s[key])
    m[key] = len(new_edges_s[key])
# Out:
# /organization/intendime 1
# /organization/loop-commerce 13
# /organization/drizly 6
# /organization/cyrus-biotechnology 2
# /organization/iron-io 3
# /organization/sinbads-supply-chain 1
# /organization/akippa 1
# /organization/qzzr 4
# /organization/framer 2
# /organization/medlanes 2
# /organization/solar-tower-technologies 1
# /organization/smart-vision-labs 4
# /organization/tongbanjie 3
# /organization/peachme 1
# /organization/eatlo 3
# /organization/booker-software 4
# /organization/form-devices 1
# /organization/qdiscovery 2
# /organization/basharsoft 4
# /organization/telefactor-robotics-com 1
# /organization/satvacart 1
# /organization/cape-wind 3
# /organization/avuba 2
# /organization/blackwood-seven 3
# /organization/the-vr-company 2
# /organization/arthesis-covers 1
# /organization/rant-media-network-llc 6
# /organization/prevoty 2
# /organization/healthexpense-inc- 6
# /organization/brainquake 1
# /organization/vetpronto 1
# /organization/etaskr 1
# /organization/transenterix 2
# /organization/gigwalk 6
# /organization/sokrati 1
# /organization/acesobee 1
# /organization/enterprise-therapeutics 2
# /organization/farmnote 4
# /organization/oxie 1
# /organization/nanogriptech 1
# /organization/i-meter 1
# /organization/edcast-inc 9
# /organization/digital-specialty-chemicals 1
# /organization/r-ve 2
# /organization/freewire-technologies 1
# /organization/revel-systems 4
# /organization/picbuy 1
# /organization/kown 1
# /organization/jfrog-ltd 2
# /organization/bica-studios 1
# /organization/curevac 1
# /organization/gateway-interactive 1
# /organization/partywithme 1
# /organization/cinarra-systems 3
# /organization/glucoiq 1
# /organization/scup 1
# /organization/tespack 1
# /organization/mulesoft 14
# /organization/soundcloud 1
# /organization/tolero-pharmaceuticals 1
# /organization/opendns 11
# /organization/specless 1
# /organization/gatsby-2 1
# /organization/vida-3 5
# /organization/harvest-exchange 4
# /organization/automatic-com 11
# /organization/happier-inc 2
# /organization/milo-networks 1
# /organization/vytmn 9
# /organization/endostim 1
# /organization/bridg-2 1
# /organization/pull 1
# /organization/onekreate 1
# /organization/devilfish-poker-ltd 1
# /organization/supportpay 8
# /organization/theatro 1
# /organization/itineris 3
# /organization/mersana-therapeutics 5
# /organization/stitch-2 2
# /organization/addresshealth 1
# /organization/next-issue-media 1
# /organization/video-blocks 1
# /organization/personal-capital 7
# /organization/pedius 3
# /organization/sn-mobile-technology 2
# /organization/magnomics 1
# /organization/ruiyi 8
# /organization/electric-objects 14
# /organization/capture-educational-consulting-services 3
# /organization/ekaya-com 8
# /organization/cuelearn 1
# /organization/optica 1
# /organization/tradingview 1
# /organization/smartsheet 4
# /organization/campaign-monitor 1
# /organization/quieru-com 1
# /organization/salespredict 2
# /organization/orchestro 3
# /organization/agilone 5
# /organization/women-com 1
# /organization/upplication 1
# /organization/invision-2 4
# /organization/context-relevant 9
# /organization/vantage-sports 5
# /organization/ebrandvalue 2
# /organization/brickx---the-brick-exchange 1
# /organization/metamaterial-technologies-inc- 2
# /organization/burning-glass-technologies 1
# /organization/electric-imp 4
# /organization/twindom 1
# /organization/bswift 1
# /organization/aura-biosciences 5
# /organization/yetang 2
# /organization/farmers-business-network 3
# /organization/manthan-systems 1
# /organization/acorns-grow 7
# /organization/mesh-korea 6
# /organization/hco-serviÃ§os-logÃ­sticos-s-a 1
# /organization/novelda-as 3
# /organization/rocketclub 1
# /organization/bex-io 1
# /organization/carreira-beauty 1
# /organization/social-code 1
# /organization/esolidar 1
# /organization/clothing-sites 1
# /organization/nomacorc 1
# /organization/moneymeets 1
# /organization/fem 4
# /organization/runnit 1
# /organization/avelas-biosciences 3
# /organization/enso 1
# /organization/gigawatt 1
# /organization/3ten8 7
# /organization/prothom-industries 1
# /organization/trendlee 1
# /organization/trucktrack 1
# /organization/marketenterprise-co--ltd- 1
# /organization/aegea-medical 6
# /organization/justfabulous 6
# /organization/ziffi 1
# /organization/pani-networks 1
# /organization/surveysnap 1
# /organization/twt-digital 2
# /organization/iwopi 1
# /organization/simplus 7
# /organization/coin 7
# /organization/hawhire 1
# /organization/niffler 1
# /organization/networked-insights 3
# /organization/dermira 8
# /organization/adizio 4
# /organization/podaris 1
# /organization/nuubo 4
# /organization/yo 6
# /organization/metricwire 1
# /organization/twist-biosciences 11
# /organization/marcopolo-learning 1
# /organization/systran 1
# /organization/reh 1
# /organization/carsgen 1
# /organization/crowdability 2
# /organization/sailplay 1
# /organization/arkivum 3
# /organization/dropoff-inc 4
# /organization/pantheon 5
# /organization/visionchina-media-inc 1
# /organization/haochushi 2
# /organization/stylebee 1
# /organization/ditto-labs 5
# /organization/ycharts 7
# /organization/fusionops 2
# /organization/soonjeong-game 1
# /organization/oceana 1
# /organization/lexoo 1
# /organization/loungebuddy 9
# /organization/anypresence 4
# /organization/skillsurvey 2
# /organization/weaverlabs 2
# /organization/epona-biotech-2 1
# /organization/re2 2
# /organization/jivi 13
# /organization/quaero-corporation 3
# /organization/navabi 3
# /organization/racoonsoft 2
# /organization/the-credit-junction 1
# /organization/enercast 1
# /organization/imvision-software-technologies 2
# /organization/consortiex 2
# /organization/healthprize-technologies 1
# /organization/100health 3
# /organization/clinipace-worldwide 7
# /organization/agiliance 1
# /organization/examsoft-worldwide 2
# /organization/lendmed 2
# /organization/partender 3
# /organization/deep-identity 1
# /organization/tumotorizado-com 1
# /organization/pepperdata 9
# /organization/taquilla 1
# /organization/seesearch 1
# /organization/zymochem 1
# /organization/proonto 1
# /organization/lovethelook 1
# /organization/getat 5
# /organization/moovenda-2 1
# /organization/unflete-com 1
# /organization/completeset 3
# /organization/guahao 1
# /organization/kahuna 12
# /organization/evereve 2
# /organization/qpid-health 2
# /organization/ktplay 1
# /organization/droidcloud 1
# /organization/progreso-financiero 2
# /organization/joberate 3
# /organization/payrange 6
# /organization/kuhcoon 1
# /organization/famely 1
# /organization/that-device-company-ltd 3
# /organization/zarthcode 1
# /organization/raydiance 4
# /organization/cloudwear 1
# /organization/splashscore 3
# /organization/nix-hydra-games 1
# /organization/reviews42 3
# /organization/axÃ¨gaz 1
# /organization/eat-club 1
# /organization/peloton-technology 10
# /organization/orthalign 2
# /organization/wut 6
# /organization/rsam 1
# /organization/greenmantra-technologies 2
# /organization/swipe-to 2
# /organization/fluvip 2
# /organization/smartkem 3
# /organization/zhenpu-education 1
# /organization/pepfeed 1
# /organization/narrativedx 5
# /organization/coventure 2
# /organization/blablacar 4
# /organization/xceedium 1
# /organization/ghostruck 4
# /organization/crossbar 8
# /organization/one-animation 2
# /organization/capsos-medical 1
# /organization/water-to-go-company 1
# /organization/guidecity 1
# /organization/avizorex-pharma 1
# /organization/yext 4
# /organization/raise-marketplace 5
# /organization/ifbyphone 8
# /organization/vonage 5
# /organization/boxed 20
# /organization/adphorus 1
# /organization/flexus-biosciences 3
# /organization/enumeral-biomedical 2
# /organization/crowdtangle 8
# /organization/himily 1
# /organization/sequent-medical 4
# /organization/canara 1
# /organization/genymobile-inc 3
# /organization/viuing 13
# /organization/grabtaxi 9
# /organization/mmuze 3
# /organization/agenda-beleza 1
# /organization/odilo 1
# /organization/irofit 3
# /organization/genophen 1
# /organization/gan-systems 5
# /organization/epistates 1
# /organization/canary 8
# /organization/best-option-trading 1
# /organization/krux 7
# /organization/delta-id 1
# /organization/tuvalabs 5
# /organization/baofeng-mojing 4
# /organization/puteko 1
# /organization/3d-by-flow 1
# /organization/snapwire 1
# /organization/storytime-studios 5
# /organization/turn 1
# /organization/augumenta 1
# /organization/renovatio-it-solutions 1
# /organization/geenapp-internet 5
# /organization/leading-mark 4
# /organization/public-insight-corporation 1
# /organization/flashpoint-partners 4
# /organization/indooratlas 4
# /organization/oilproject 1
# /organization/discotech 1
# /organization/postergully 7
# /organization/seed-blooming 1
# /organization/fuzmo 1
# /organization/taodangpu 3
# /organization/pilottv 1
# /organization/wirex-cube-systems 3
# /organization/solenica 2
# /organization/veeqo 1
# /organization/uguru 1
# /organization/narrative 4
# /organization/orvibo 2
# /organization/patientpay 1
# /organization/wahanda 5
# /organization/iristrace 10
# /organization/shopdeca 1
# /organization/videregen 2
# /organization/fingi 2
# /organization/bayes-impact 1
# /organization/standing-ovation 2
# /organization/experifun 2
# /organization/ab-tasty 2
# /organization/jet 17
# /organization/homelane 2
# /organization/zeek-2 3
# /organization/lob 5
# /organization/biomonde 2
# /organization/pontamedia 1
# /organization/scrumpt 1
# /organization/chrome-river-technologies 1
# /organization/elasticsearch 3
# /organization/equidate 3
# /organization/spayee 1
# /organization/mapr-technologies 7
# /organization/studytube 1
# /organization/alianza 3
# /organization/musement 4
# /organization/nvdrones 3
# /organization/accupass 3
# /organization/zirx 6
# /organization/achica 2
# /organization/appdynamics 9
# /organization/creatorbox 2
# /organization/the-royalty-exchange 1
# /organization/chic-by-choice 4
# /organization/blueline-grid 1
# /organization/juxta-labs 1
# /organization/kinduct 1
# /organization/process-street 1
# /organization/mens-style-lab 2
# /organization/grandata 1
# /organization/2mee 1
# /organization/watchfinder 2
# /organization/updater 4
# /organization/lomaki 1
# /organization/mitu-2 2
# /organization/astroscale 6
# /organization/scout-rfp 5
# /organization/smart-ad-2 1
# /organization/tapgenes 1
# /organization/causemo 7
# /organization/spikes-inc 3
# /organization/surf-air 11
# /organization/limestone-labs 1
# /organization/carepredict 1
# /organization/myriada-systems 1
# /organization/hijup-com 4
# /organization/termine24-gmbh 2
# /organization/freshtemp 2
# /organization/intigua 3
# /organization/shareit 1
# /organization/makerskit 5
# /organization/maps 1
# /organization/edgar 1
# /organization/oxaion 1
# /organization/toytalk 5
# /organization/parktag 8
# /organization/mapd 3
# /organization/dentys 1
# /organization/savo 3
# /organization/meituan-com 4
# /organization/flatiron-school 5
# /organization/veniti 2
# /organization/arsenal-medical-inc 3
# /organization/wifibanlv 1
# /organization/smartroost 4
# /organization/inivata 3
# /organization/dextrophobia-rooms 1
# /organization/whentomanage 4
# /organization/fazland 1
# /organization/jobdoh 2
# /organization/captive-media 2
# /organization/jetsetgo 1
# /organization/commercialtribe 4
# /organization/advanced-cell-diagnostics 5
# /organization/hopon--inc- 1
# /organization/mido-play 1
# /organization/laurelandwolf 8
# /organization/dezyre 3
# /organization/mind-palette 1
# /organization/tablo-publishing 3
# /organization/silent-circle 2
# /organization/simplivity 6
# /organization/the-paper-store 1
# /organization/colombio 1
# /organization/kunerango 1
# /organization/open-telematic-platform 1
# /organization/springloaded-technology 2
# /organization/girnarsoft 3
# /organization/acufocus 6
# /organization/spotlight-ticket-management 3
# /organization/ravabe 1
# /organization/artbinder 10
# /organization/quantico-trends 1
# /organization/oppex 3
# /organization/talentiq 2
# /organization/lendix 3
# /organization/coverhound 5
# /organization/bloglovin 5
# /organization/romeo-delivers 1
# /organization/crux 4
# /organization/global-biodiagnostics 2
# /organization/next-university 1
# /organization/wolt 2
# /organization/lendio 7
# /organization/capshare 4
# /organization/pachyderm 13
# /organization/cartagenia 2
# /organization/sansan 5
# /organization/advanced-cooling-therapy 3
# /organization/bellhops 10
# /organization/mitu-network 5
# /organization/shiftlabs 2
# /organization/fanzo 1
# /organization/pegasus-solar 1
# /organization/chope-group 6
# /organization/reddo-mobility 2
# /organization/satago-net 6
# /organization/bitfinder 8
# /organization/sky-futures 1
# /organization/litcharts 1
# /organization/aquamost 1
# /organization/blue-medora 3
# /organization/matchmove-pay 1
# /organization/knot-standard 1
# /organization/indicative 13
# /organization/zazzy 5
# /organization/vmray-gmbh 1
# /organization/tidy-2 1
# /organization/omprompt 2
# /organization/windward-naval 2
# /organization/bluesmart 6
# /organization/security-scorecard 3
# /organization/wedidit 1
# /organization/sprout-social 2
# /organization/spoken-communications 2
# /organization/metrilo 2
# /organization/joyent 5
# /organization/smile-family 2
# /organization/spredfast 1
# /organization/oxehealth 1
# /organization/swipeloyalty 1
# /organization/superior-solar-design 1
# /organization/24tidy 1
# /organization/storefront 11
# /organization/aurovine-ltd 1
# /organization/makelight-interactive 1
# /organization/hirecanvas 1
# /organization/wisebanyan 5
# /organization/connehito-inc- 2
# /organization/wimi5 1
# /organization/theravectys 1
# /organization/ncite-neuromedia 1
# /organization/cono-c 1
# /organization/enhancv 1
# /organization/glamsquad 4
# /organization/tailify 1
# /organization/assetz-capital 1
# /organization/balanced 3
# /organization/simple-wearables 3
# /organization/otonomos 1
# /organization/winding 1
# /organization/visisonics 1
# /organization/seismic-software 2
# /organization/piqora 4
# /organization/areametrics 7
# /organization/chownow 1
# /organization/local-plant-source 1
# /organization/mashgin 1
# /organization/posigen-solar-solutions 1
# /organization/ubermedia 2
# /organization/vcnc 2
# /organization/natera 6
# /organization/tag-commander 3
# /organization/chanrx-corp 4
# /organization/searen 1
# /organization/nimble-wireless 1
# /organization/brite-semiconductor 2
# /organization/minutekey 1
# /organization/bugeater-labs 1
# /organization/synerscope 1
# /organization/immunity-project 1
# /organization/panoramic-power 2
# /organization/vmturbo 4
# /organization/doz 5
# /organization/eyeyon 2
# /organization/bentonow 5
# /organization/predictionio 8
# /organization/vionlabs 1
# /organization/insightsquared 4
# /organization/funzing 1
# /organization/clearwater-clinical-limited 3
# /organization/juventas-therapeutics 2
# /organization/soldsie 9
# /organization/kustomnote 1
# /organization/neuros-medical 3
# /organization/datagravity 1
# /organization/wodby 5
# /organization/kymab 4
# /organization/sapho 6
# /organization/assembly 4
# /organization/stockspot 3
# /organization/qubole 1
# /organization/applepie-capital 5
# /organization/device42 2
# /organization/rapid7 2
# /organization/casehub 1
# /organization/trucksfirst 1
# /organization/neos-therapeutics 5
# /organization/wonder-2 4
# /organization/review-trackers 5
# /organization/glowforge 4
# /organization/solepower 1
# /organization/swish-analytics 1
# /organization/delouge 1
# /organization/propstack 2
# /organization/couchbase 7
# /organization/cognia 3
# /organization/synpromics-ltd 1
# /organization/pivoice 1
# /organization/mulu 1
# /organization/checkmarx 1
# /organization/splitforce 5
# /organization/revcascade 1
# /organization/oceanbrowser 1
# /organization/superpedestrian 4
# /organization/fiverr 4
# /organization/plutus 1
# /organization/inselly 2
# /organization/ortho-kinematics 2
# /organization/better-bean 2
# /organization/three-scale 1
# /organization/thermondo 5
# /organization/metrikea 1
# /organization/safehis 1
# /organization/if-this-then-that 2
# /organization/dattch 5
# /organization/swapbox 5
# /organization/digitalguardian 3
# /organization/mop-entertainment 1
# /organization/rekode-education 2
# /organization/digsy 4
# /organization/zergnet 4
# /organization/funds-india 3
# /organization/aviso-inc 6
# /organization/taxime 1
# /organization/page-vault-inc 5
# /organization/coupang 9
# /organization/livspace 3
# /organization/culinary-agents 5
# /organization/forus 1
# /organization/xiaoying 1
# /organization/bemyguest 4
# /organization/thngy 5
# /organization/hera-therapeutics 2
# /organization/legendary-entertainment 1
# /organization/cognitics 1
# /organization/poi 1
# /organization/aprendum 3
# /organization/stellaservice 7
# /organization/videonetics-technologies 1
# /organization/flexiroam 1
# /organization/smove 4
# /organization/maillift 1
# /organization/jobbatical 7
# /organization/onedio 1
# /organization/bartesian 1
# /organization/real-estate-direct 1
# /organization/appiterate-com 3
# /organization/zeepro 3
# /organization/unconstrained-robotics 1
# /organization/aras 1
# /organization/dual-aperture-international-inc- 3
# /organization/mediamath 4
# /organization/paladion 1
# /organization/sweet-note-bakery 1
# /organization/candy-jar 1
# /organization/fitting-room-social 1
# /organization/full-color-games 3
# /organization/perseus-telecom 1
# /organization/medallia 1
# /organization/cidara-therapeutics 11
# /organization/host-analytics 5
# /organization/scribblelive 5
# /organization/forendo-pharma 2
# /organization/aduro-biotech 4
# /organization/freshmonk 2
# /organization/smartvid-io 2
# /organization/beigene 5
# /organization/layer3-tv 2
# /organization/vook 1
# /organization/izettle 8
# /organization/bounce-technology--inc- 2
# /organization/scorista-ru 1
# /organization/lar21 1
# /organization/waterline-data-science 2
# /organization/ajungo 1
# /organization/drum-roll 1
# /organization/caspian-impact-investments 1
# /organization/crossover-health-management-services 1
# /organization/signifyd 7
# /organization/ncube 1
# /organization/smileworks-inc- 2
# /organization/sharetribe 2
# /organization/bento 4
# /organization/neuroptics 2
# /organization/medefer 1
# /organization/showbox 4
# /organization/myoptique-group 2
# /organization/bandpage 4
# /organization/synereca-pharmaceuticals 4
# /organization/aviacode 1
# /organization/boond 3
# /organization/jobvite 4
# /organization/maven-clinic 7
# /organization/zizooboats-gmbh 1
# /organization/buddy 1
# /organization/secure-islands-technologies 1
# /organization/reward-gateway 1
# /organization/klipfolio 6
# /organization/feedvisor 4
# /organization/ventrix-2 1
# /organization/smarter-remarketer 2
# /organization/vira-therapeutics 3
# /organization/amoeba 1
# /organization/ensilo 2
# /organization/fund-that-flip 1
# /organization/rebagg 9
# /organization/school-places 3
# /organization/vitagene 1
# /organization/opertech-bio-inc- 2
# /organization/benny 2
# /organization/thymes 1
# /organization/seen 12
# /organization/seeo 3
# /organization/isoplexis 3
# /organization/eyeem 6
# /organization/visiquate 1
# /organization/moka5 3
# /organization/grownout 2
# /organization/tappy-pte--ltd- 2
# /organization/totspot-2 4
# /organization/liftoff-mobile 6
# /organization/semperis 1
# /organization/stox 1
# /organization/b2x-care-solutions 1
# /organization/bookbarn-international 1
# /organization/bavarian-nordic 1
# /organization/fakedice 1
# /organization/symphony-3 13
# /organization/adma-biologics 1
# /organization/cignifi 2
# /organization/starbroker 1
# /organization/grey-orange-brand-private-limited 2
# /organization/trendyta 1
# /organization/karaokesmart-co 1
# /organization/pluriomics 2
# /organization/theranexus 1
# /organization/taste-analytics 4
# /organization/all-day-media 11
# /organization/backpack 1
# /organization/myopowers-medical-technologies 3
# /organization/seres-health 5
# /organization/cadfaster 3
# /organization/talkpush 1
# /organization/navigating-cancer 3
# /organization/fuel-station 1
# /organization/alzheon 1
# /organization/inmoji 1
# /organization/upstream-commerce 1
# /organization/simplemail 3
# /organization/foodieforall 1
# /organization/aledade 2
# /organization/sitwith 1
# /organization/schoo 5
# /organization/cleartax 2
# /organization/geartranslations 2
# /organization/clique-media-3 9
# /organization/lighthouse-pools 1
# /organization/heliox 1
# /organization/ocean-executive 1
# /organization/club-point 1
# /organization/soundhawk-corporation 2
# /organization/ace-learning-company-inc 3
# /organization/eccrine-systems 1
# /organization/hellosponsor 1
# /organization/drync 4
# /organization/automile-ab 2
# /organization/omeros 2
# /organization/attero-recycling 4
# /organization/bettercompany 11
# /organization/51zhangdan 1
# /organization/ciphercloud 4
# /organization/wineverse 3
# /organization/modern-meadow 6
# /organization/tricida 4
# /organization/zeel 3
# /organization/hellocafe 5
# /organization/iam-robotics 1
# /organization/lifebond 4
# /organization/remerge-2 5
# /organization/dice 8
# /organization/merge-labs-inc 1
# /organization/karmic-labs 3
# /organization/restoration-robotics 4
# /organization/quantico-energy-solutions 2
# /organization/touchbistro 4
# /organization/cytovale 1
# /organization/portfolia 3
# /organization/videostream 1
# /organization/playtabase 2
# /organization/playcanvas 2
# /organization/scratch-2 5
# /organization/sendcloud 2
# /organization/maestro-healthcare-technology 2
# /organization/vivify-health 2
# /organization/beatbox-beverages 1
# /organization/orankl 1
# /organization/augury-systems 7
# /organization/principia-biopharma 6
# /organization/revup-2 1
# /organization/gatheredtable 2
# /organization/clickbus 4
# /organization/anycloud 1
# /organization/livefyre 6
# /organization/cubehub 1
# /organization/passkit 1
# /organization/orphazyme 4
# /organization/offersavvy 2
# /organization/crowdynews 2
# /organization/mentio 1
# /organization/thinker-thing 1
# /organization/qloo 7
# /organization/e-cÃbica 1
# /organization/playthe-net 2
# /organization/gearbrake 3
# /organization/learncore 1
# /organization/snowball-finance 2
# /organization/synup 1
# /organization/palantir-technologies 2
# /organization/moneydesktop 9
# /organization/dapulse 2
# /organization/nashangban 3
# /organization/topfan 3
# /organization/deltamethod 1
# /organization/pool-my-ride 1
# /organization/playfab-inc 24
# /organization/asyncode 1
# /organization/isothrive 1
# /organization/wikifolio 5
# /organization/adatao 3
# /organization/wegilant 4
# /organization/virginia-commonwealth-university 1
# /organization/mallzee-com 9
# /organization/atyr-pharma 1
# /organization/linkqlo 2
# /organization/recovr 1
# /organization/smart-drone-3 1
# /organization/nextwin-srl 1
# /organization/appspotr 2
# /organization/balanced-labs 4
# /organization/coinify-inc 3
# /organization/tokia-lt 1
# /organization/iotera 8
# /organization/amplisense 1
# /organization/reply-com 1
# /organization/lilikoi 1
# /organization/bellicum-pharmaceuticals 8
# /organization/appsflyer 6
# /organization/dwellable-2 3
# /organization/ossia 3
# /organization/chefs-feed 4
# /organization/groupon-india 1
# /organization/neoreach 5
# /organization/orange-money-dba-ezbob 1
# /organization/quikr-india 9
# /organization/finanzchef24 3
# /organization/blueoak-resources 1
# /organization/fullcontact 4
# /organization/pigeonly 1
# /organization/scriptrock 4
# /organization/magictab 1
# /organization/sherpany 1
# /organization/kyndi 1
# /organization/juesheng-com 1
# /organization/mobileready 1
# /organization/beeswax 4
# /organization/edgewave-inc 2
# /organization/my-dealer-service 2
# /organization/amberads 1
# /organization/6sense 4
# /organization/cropx 4
# /organization/silicone-arts-laboratories 2
# /organization/velostrata 2
# /organization/interleukin-genetics 3
# /organization/novabiotics 1
# /organization/rollio 2
# /organization/wallix 1
# /organization/arcadia-biosciences 4
# /organization/replica-labs 1
# /organization/jogg 1
# /organization/skylit-medical 1
# /organization/homehero 5
# /organization/truclinic 1
# /organization/01games-technology 1
# /organization/sovi 1
# /organization/kolltan-pharmaceuticals 5
# /organization/zype 1
# /organization/twenty20-2 5
# /organization/proterra 14
# /organization/plytix 1
# /organization/coleccionarte 1
# /organization/melinta 3
# /organization/365scores 4
# /organization/exergyn 1
# /organization/convergent-dental 2
# /organization/cursostotales-com 1
# /organization/le-cicogne 2
# /organization/lily-robotics 6
# /organization/acs-clothing 1
# /organization/ncino 6
# /organization/miramix 1
# /organization/integrated-diagnostics 4
# /organization/strike-2 1
# /organization/hightower 13
# /organization/ietty 2
# /organization/bucketfeet 4
# /organization/bitsbox 1
# /organization/springbot 3
# /organization/mark43 5
# /organization/4th-office 3
# /organization/hotels-ng 2
# /organization/crowdfunder-co-uk 1
# /organization/mileiq 4
# /organization/vapotherm 8
# /organization/dta-latam 1
# /organization/bluetector 5
# /organization/snapcar 2
# /organization/vaivolta 1
# /organization/poprageous 1
# /organization/tailster 2
# /organization/mobvista 1
# /organization/hackerrank 6
# /organization/it-s-skin 1
# /organization/metamarkets 8
# /organization/memsql 2
# /organization/overnear 2
# /organization/disruption-corporation-2 1
# /organization/smart-lanes 1
# /organization/scale-computing 6
# /organization/marrone-bio-innovations 1
# /organization/cambridge-epigenetix 3
# /organization/airstream-app 2
# /organization/lieberman-research-worldwide 1
# /organization/alignable 5
# /organization/holvi 1
# /organization/switch-automation 1
# /organization/riversilica 1
# /organization/drafted 6
# /organization/oh-my-glasses 2
# /organization/shine-medical-technologies 1
# /organization/adaptive-biotechnologies 5
# /organization/proletariat 3
# /organization/valetanywhere 20
# /organization/riffsy 7
# /organization/policybazaar 5
# /organization/edsix-brain-lab-private-limited 2
# /organization/agentdesks 1
# /organization/ecovision 1
# /organization/evisors 2
# /organization/strap 7
# /organization/yesgraph 1
# /organization/babbel 4
# /organization/flow-state-media 2
# /organization/tiempo-listo 1
# /organization/masar 1
# /organization/unchained-labs 3
# /organization/1jiajie 2
# /organization/indico-data-solutions 15
# /organization/7summits 1
# /organization/chouxbox 1
# /organization/dosesystem 1
# /organization/gametime 12
# /organization/bithound 2
# /organization/cermati 2
# /organization/bowery 4
# /organization/wing-ma-am 1
# /organization/gaatu 2
# /organization/minimally-invasive-devices 2
# /organization/acupera 2
# /organization/theresumator 5
# /organization/retailersaver-com 1
# /organization/ihealth-lab-inc 1
# /organization/viva-labs 2
# /organization/splitwise 6
# /organization/argil-data-corp 1
# /organization/zerto 5
# /organization/pack-purchase 2
# /organization/sinode-systems 1
# /organization/picapica 1
# /organization/younow 1
# /organization/ginkgo-bioworks 12
# /organization/trip4real 4
# /organization/kabam 2
# /organization/monteris-medical 3
# /organization/vedantu-innovations 2
# /organization/dagne-dover 3
# /organization/mitigram 1
# /organization/hauteday 1
# /organization/rotageek-limited 1
# /organization/pureprint 1
# /organization/vivit 2
# /organization/limk 4
# /organization/x-ai 8
# /organization/gamechanger-media 3
# /organization/postman 1
# /organization/memorado 4
# /organization/qwikcilver-solutions 3
# /organization/reschedule 1
# /organization/fashioncomm 1
# /organization/capital-vision-services 2
# /organization/aasaanjobs-com 2
# /organization/lahore-university-of-management-sciences 1
# /organization/pollfish 6
# /organization/cuiker 2
# /organization/quickplay-media 3
# /organization/tinytap 1
# /organization/creative-gig 1
# /organization/airbitz 6
# /organization/the-button-corporation 2
# /organization/parkey 1
# /organization/99taxis 4
# /organization/healthify 1
# /organization/arcadia-data 3
# /organization/airtable 18
# /organization/allgreenup 1
# /organization/inovar-corporation 4
# /organization/adspired-technologies 1
# /organization/zepo-technologies-pvt-ltd 2
# /organization/blueprint-medicines 8
# /organization/fondeadora 1
# /organization/sight-sense 1
# /organization/powr-of-you 2
# /organization/rubikloud 2
# /organization/optio-labs 1
# /organization/chishenma 1
# /organization/caravan 3
# /organization/erecruit 1
# /organization/videotelling 1
# /organization/piper 1
# /organization/aventones 1
# /organization/nexus-ewater 4
# /organization/toilet-paper-and 1
# /organization/brad-s-raw-foods 3
# /organization/qll 5
# /organization/devhd 2
# /organization/industrial-generosity 3
# /organization/beta-o2-technologies 1
# /organization/red-monster-games 1
# /organization/embibe 2
# /organization/neo-technology 5
# /organization/dronedeploy 6
# /organization/germin8 1
# /organization/liveli 1
# /organization/envoy 15
# /organization/leaddesk 2
# /organization/outset-medical 6
# /organization/openfin 5
# /organization/execonline 4
# /organization/youyiche-holdings 1
# /organization/fleep 7
# /organization/mixgenius 7
# /organization/xiachufang 4
# /organization/syngen 2
# /organization/mycoon 3
# /organization/simplereach 6
# /organization/wellfount 1
# /organization/lizhi 4
# /organization/matrixx-software 1
# /organization/flipboard 1
# /organization/tokenone 4
# /organization/marklogic 6
# /organization/agilum-healthcare-intelligence 2
# /organization/estate-assist 8
# /organization/ness-clothing 1
# /organization/piq 2
# /organization/telesense 1
# /organization/sulekha-com 2
# /organization/blue-river-technology 3
# /organization/duo-security 5
# /organization/navdy 15
# /organization/badge 3
# /organization/mobilehelp 1
# /organization/more-health 1
# /organization/enrou 2
# /organization/forsight-labs 4
# /organization/alienvault 5
# /organization/giftpass 2
# /organization/optaim 1
# /organization/acast 1
# /organization/tikona-digital-networks 4
# /organization/body-labs 2
# /organization/tyba 2
# /organization/nosto 4
# /organization/notable-labs-2 1
# /organization/allakos 5
# /organization/enjoy 4
# /organization/koibanx 1
# /organization/travelnuts 1
# /organization/synoste-oy 6
# /organization/k-teco 1
# /organization/yatra-online 3
# /organization/glentel 1
# /organization/chef 5
# /organization/dcs-plus 1
# /organization/pathbrite 2
# /organization/fourthirtythree 1
# /organization/switchmate 1
# /organization/andapt 1
# /organization/beme-2 2
# /organization/lightsail-education 3
# /organization/butterfleye-inc 1
# /organization/tapzen 1
# /organization/shapeshift 2
# /organization/rhythm-pharmaceuticals 8
# /organization/brazil-plus 1
# /organization/paypay-2 8
# /organization/affirm 6
# /organization/hotelsaroundyou 1
# /organization/voiq 1
# /organization/mirna-therapeutics 11
# /organization/bitlit 4
# /organization/bilna-pte 1
# /organization/bhakti-chai 1
# /organization/away-2 11
# /organization/dasheroo 5
# /organization/rushmorefm 1
# /organization/stryd 1
# /organization/viraltag 1
# /organization/radiumone 5
# /organization/ran 2
# /organization/windgap-medical 2
# /organization/the-dodo 4
# /organization/mysupportassistant 1
# /organization/roniin 5
# /organization/hundredrooms 4
# /organization/cryptocurrency-research-group 1
# /organization/traklight 1
# /organization/raindance-technologies 2
# /organization/sporting-mouth 1
# /organization/cargo-io 5
# /organization/unata 2
# /organization/17zuoye 4
# /organization/gaifong-app 1
# /organization/eduk 3
# /organization/quandoo 7
# /organization/uni2 1
# /organization/abcelex-technologies 1
# /organization/cloud-pharmaceuticals 1
# /organization/zagster 4
# /organization/orderwithme 7
# /organization/imusician 3
# /organization/boingo-wireless 2
# /organization/filo-find-locate 1
# /organization/buyfi 2
# /organization/weboo 2
# /organization/platform9-systems-inc 2
# /organization/doodle-maths 1
# /organization/expertfile 3
# /organization/masteryprep 1
# /organization/cavendish-kinetics 3
# /organization/tonetag 1
# /organization/deliveryagent 1
# /organization/skim-it 1
# /organization/pointright 1
# /organization/democracy-com 2
# /organization/yonder 3
# /organization/synlogic 3
# /organization/71lbs 1
# /organization/le-tote 9
# /organization/airtame 1
# /organization/karisma-kidz 1
# /organization/coprix-media-bg 1
# /organization/equilume 1
# /organization/lulio 1
# /organization/naf-naf-grill 1
# /organization/greenqloud 2
# /organization/aurora-brands 1
# /organization/kwaga 1
# /organization/appyparking 3
# /organization/chronicles-of-earth 1
# /organization/laredo-energy 2
# /organization/emulate 2
# /organization/bd4travel 3
# /organization/hitpoint 3
# /organization/reddit 16
# /organization/cantaloupe-systems 1
# /organization/aliada-mx 3
# /organization/wilson-therapeutics 4
# /organization/incarda-therapeutics 1
# /organization/degreed 1
# /organization/specifiedby 2
# /organization/crmnext 1
# /organization/inksedge 7
# /organization/dynamic-yield 5
# /organization/liquidplanner 1
# /organization/e-ye-brain 1
# /organization/gadgets-360 6
# /organization/macrofab 1
# /organization/playsight 5
# /organization/akatsuki-3 2
# /organization/eucl3d 2
# /organization/tango-card 6
# /organization/mamagoto 2
# /organization/enterome 3
# /organization/stagelink 1
# /organization/pango 1
# /organization/rotor 1
# /organization/pipeline 1
# /organization/virtus-data-centres 2
# /organization/iposen 1
# /organization/algolux 2
# /organization/enbala-power-networks 3
# /organization/the-currency-cloud 7
# /organization/mr-barkley-ug-vertragslotse 3
# /organization/latincomics 1
# /organization/budo-finder 1
# /organization/trillian-mobile-ab 1
# /organization/visual-unity 1
# /organization/grubmarket-inc 8
# /organization/splice-machine 4
# /organization/globesherpa 1
# /organization/oy- 1
# /organization/alise-devices 1
# /organization/artsetters 2
# /organization/platfora 7
# /organization/oscar 14
# /organization/easyproperty 1
# /organization/etoro 3
# /organization/dispatch 1
# /organization/luminal 4
# /organization/omnidrone 3
# /organization/infinidat 1
# /organization/field-agent 1
# /organization/carr 2
# /organization/netblazr 1
# /organization/magic 1
# /organization/predpol 1
# /organization/whoop-inc 1
# /organization/protectwise 4
# /organization/gelexir-healthcare 2
# /organization/enigma-technologies 6
# /organization/wooju 1
# /organization/linked-finance 1
# /organization/canva 7
# /organization/nova-lignum 1
# /organization/perceptiv-labs 2
# /organization/rickshaw 1
# /organization/codepicnic 1
# /organization/cardiodx 2
# /organization/kontakt 1
# /organization/prosky-inc- 4
# /organization/noonbora 1
# /organization/pluto-tv 12
# /organization/school-fashion 1
# /organization/paratus-clinical 1
# /organization/countrywide-healthcare-supplies 1
# /organization/akvolution 3
# /organization/wallapop 1
# /organization/xero 2
# /organization/gogo-fit 1
# /organization/neurolutions 3
# /organization/the-new-craftsmen 1
# /organization/leankor 1
# /organization/berry-kitchen 2
# /organization/brandmaker 2
# /organization/greenease 1
# /organization/chequed-com 2
# /organization/g-plus-games 3
# /organization/scribd 5
# /organization/huakang-mobile-health 3
# /organization/smiletime 5
# /organization/premise 4
# /organization/switch-co 6
# /organization/meetlima 1
# /organization/moi-corporation 2
# /organization/purveyour 1
# /organization/rockyou 2
# /organization/increasecard 2
# /organization/10x-genomics 3
# /organization/calendly 1
# /organization/neuronetics 8
# /organization/gogobot 2
# /organization/outdoor-insite 2
# /organization/pluto-mail 1
# /organization/reinfer-io 1
# /organization/mydentist 3
# /organization/sirum 1
# /organization/liveintent 4
# /organization/drbridge 1
# /organization/propelad-com 4
# /organization/trippeo 2
# /organization/plaid-inc 3
# /organization/orderlord 2
# /organization/invoice2go 2
# /organization/huy-vietnam 5
# /organization/spring-inc 10
# /organization/cryotherapeutics 3
# /organization/quantum-biosystems 5
# /organization/trustev 4
# /organization/swyft 5
# /organization/netdocuments 1
# /organization/deep-glint 1
# /organization/uzabase 7
# /organization/stackengine 2
# /organization/appticles 1
# /organization/shippable 4
# /organization/zamgoat 1
# /organization/attachingit 1
# /organization/soupologie 1
# /organization/floqast 3
# /organization/measurabl 2
# /organization/incontext-solutions 3
# /organization/shelfie 1
# /organization/zizerones 1
# /organization/hygea-holdings 1
# /organization/innervate 1
# /organization/espiral-2 2
# /organization/shift-messenger 8
# /organization/oyo-rooms 6
# /organization/infoaxe 5
# /organization/egress-software-technologies 1
# /organization/coco-apps 1
# /organization/purelifi 3
# /organization/cursogram 5
# /organization/curiyo 8
# /organization/adforrm 1
# /organization/tapad 9
# /organization/homestay-com 1
# /organization/brightinfo 1
# /organization/izenda 2
# /organization/penistone-road 1
# /organization/legal-shine 1
# /organization/matricore 1
# /organization/appoet-2 1
# /organization/luxola 5
# /organization/thumbtack 4
# /organization/kira-s-sweets 1
# /organization/blackbay 1
# /organization/mezzobit 1
# /organization/innoviti 2
# /organization/intelligent-insites 1
# /organization/mashable 9
# /organization/idea-market 1
# /organization/adello-group 1
# /organization/fedger-io 1
# /organization/vouchr 1
# /organization/translationexchange 1
# /organization/balance-therapeutics 3
# /organization/allocadia 3
# /organization/meetrics 2
# /organization/adhusky 3
# /organization/wave-accounting 3
# /organization/novan 1
# /organization/timeline-labs-tll 1
# /organization/papayer 6
# /organization/immediately 22
# /organization/dronamics 1
# /organization/eagle-eye-networks 2
# /organization/the-little-black-book 5
# /organization/nanolike 2
# /organization/optimizely 3
# /organization/prohance 1
# /organization/cadre-2 6
# /organization/n-plusn 1
# /organization/picocandy 1
# /organization/phase 1
# /organization/wozlla 1
# /organization/kolonial-cz 1
# /organization/abiobot 1
# /organization/mujin 1
# /organization/shark-punch 4
# /organization/spoton-it 7
# /organization/b-guard 1
# /organization/neurophage-pharmaceuticals 2
# /organization/senta 1
# /organization/tegile-systems 7
# /organization/appformix 1
# /organization/bitlendingclub 1
# /organization/primerevenue 1
# /organization/tecsport-games 1
# /organization/honeycomb-corporation 1
# /organization/lamabang 5
# /organization/epic-sciences 6
# /organization/riff-digital-inc 1
# /organization/zawatt 1
# /organization/raise-labs-inc 7
# /organization/chemayi 2
# /organization/mobikon-asia 1
# /organization/sancilio-and-company 1
# /organization/biondvax 1
# /organization/multisense 1
# /organization/codasip 1
# /organization/viamet-pharmaceuticals 6
# /organization/tackl 1
# /organization/kite-pharma 1
# /organization/tapatalk 3
# /organization/tackk 5
# /organization/newsela 5
# /organization/simplyinsured 9
# /organization/diarymonitor 1
# /organization/hop-2 1
# /organization/creo-medical 2
# /organization/newelse-inc- 1
# /organization/harukaedu 1
# /organization/gowell 2
# /organization/diassess 1
# /organization/armedangels 1
# /organization/fanli-website 3
# /organization/480-biomedical 1
# /organization/phosimmune 2
# /organization/equitynet 1
# /organization/boardvitals 1
# /organization/traincamp-me 2
# /organization/wizenworld 1
# /organization/summitig 2
# /organization/kindred-prints 1
# /organization/doktuz 1
# /organization/fuel3d 3
# /organization/zeuscontrols 1
# /organization/lendup 1
# /organization/21vianet 3
# /organization/xeros 2
# /organization/vizalytics-technology 1
# /organization/roominate 4
# /organization/etect 1
# /organization/outbrain 1
# /organization/bibblio 5
# /organization/minoryx-therapeutics 1
# /organization/fastree3d 3
# /organization/firstcry-com 5
# /organization/revionics 1
# /organization/vc-mobile-entertainment-inc- 3
# /organization/present-tv 1
# /organization/ifood 1
# /organization/familonet 3
# /organization/swift-navigation-inc 5
# /organization/avenida 2
# /organization/bioloom 1
# /organization/quettra 10
# /organization/statmuse 1
# /organization/silk-therapeutics 1
# /organization/tsepak-technologies 3
# /organization/gaudena 1
# /organization/promisepay 5
# /organization/fooboo 2
# /organization/impok 1
# /organization/sprig-2 9
# /organization/reela-inc- 1
# /organization/lookout 11
# /organization/bedrock-data 4
# /organization/cardiogen-sciences 1
# /organization/useriq 3
# /organization/liquid-m 1
# /organization/countertack 9
# /organization/skully-helmets 9
# /organization/rhapsody 1
# /organization/fantasyhub 1
# /organization/kezar-life-sciences 6
# /organization/tidal-wave-technology 1
# /organization/beyond-games 1
# /organization/mcube-inc 8
# /organization/phunware 7
# /organization/mowdo 4
# /organization/medicinia-atividades-de-internet-ltda 2
# /organization/lumen-learning 7
# /organization/deal-wheel-inc 1
# /organization/reformation 5
# /organization/checkr 19
# /organization/netbrain-technologies 1
# /organization/roswell-park-cancer-institute 1
# /organization/cgon 1
# /organization/honest-dollar 6
# /organization/cointent 6
# /organization/exablox 5
# /organization/ascentis 1
# /organization/linkitz 2
# /organization/room 5
# /organization/beibei 5
# /organization/jobandtalent 6
# /organization/phononic-devices 2
# /organization/themidgame 1
# /organization/keona-health 1
# /organization/seriously 5
# /organization/vinli 5
# /organization/flowline 1
# /organization/breaker 1
# /organization/pint-please 1
# /organization/townrush 1
# /organization/giftstarter 2
# /organization/clear-cut-medical 1
# /organization/cirro 1
# /organization/workable-hr 3
# /organization/crosscloud 1
# /organization/fruitday-com 3
# /organization/mokimobility 6
# /organization/caviar 3
# /organization/mobilize-2 1
# /organization/meinkauf 5
# /organization/birddog 2
# /organization/bvi-networks 11
# /organization/select 1
# /organization/deem 2
# /organization/saleswarp 1
# /organization/machinemetrics 2
# /organization/roar-for-good 1
# /organization/bigteams 3
# /organization/ojay-greene 1
# /organization/lightspace-technologies 1
# /organization/art-loft 1
# /organization/results-com 1
# /organization/talenta 2
# /organization/electric-cloud 5
# /organization/scifluor-life-sciences 3
# /organization/trackingpoint 3
# /organization/bio2chp 1
# /organization/zero-one-network-international-limited 1
# /organization/trylately 1
# /organization/femaledaily-network 3
# /organization/even 13
# /organization/scaled-inference 1
# /organization/lamahui 2
# /organization/cognea 1
# /organization/solexant 4
# /organization/breather 3
# /organization/redowl-analytics 9
# /organization/viridom 2
# /organization/dingo 1
# /organization/streamup 2
# /organization/kairos-watches 1
# /organization/code-climate 5
# /organization/bit-kitchen 8
# /organization/opsclarity 1
# /organization/green-chef 4
# /organization/playsimple 1
# /organization/fleksy 6
# /organization/flexcell-2 1
# /organization/hearing-plus 1
# /organization/kiko-labs 1
# /organization/shopkeep-com 8
# /organization/brittmore-group 1
# /organization/grupo-intercros 1
# /organization/zeotap 6
# /organization/safemotos 1
# /organization/open-learning 2
# /organization/geili-giving 1
# /organization/apptio 1
# /organization/water-planet 1
# /organization/lua-technologies 5
# /organization/ppzuche-com 6
# /organization/corephotonics 6
# /organization/resolution-games 5
# /organization/appirio 2
# /organization/compareit4me 1
# /organization/raising-it 3
# /organization/roku 2
# /organization/buying-butler 1
# /organization/onelogin 3
# /organization/smore 4
# /organization/tydy 3
# /organization/laricina-energy 2
# /organization/letstransport 4
# /organization/business-texter 1
# /organization/silverline-global 1
# /organization/rostima 1
# /organization/elysia 3
# /organization/edaixi 5
# /organization/qualia3d 16
# /organization/next-gauge 2
# /organization/servicetitan 1
# /organization/piecemaker-technologies 1
# /organization/itaro 4
# /organization/lekki-peninsula-affordable-schools 1
# /organization/pundit 2
# /organization/stem-centrx 4
# /organization/vantage-analytics 4
# /organization/batuta 1
# /organization/easysys 2
# /organization/elite-pharmaceuticals 1
# /organization/taxjar 3
# /organization/bankguard 1
# /organization/immunophotonics 3
# /organization/iversity 3
# /organization/standard-analytics-io 2
# /organization/telogis 2
# /organization/smatoos 3
# /organization/connora-technologies 1
# /organization/barnebys 5
# /organization/style-jukebox 1
# /organization/commerce-signals 1
# /organization/hassle-com 2
# /organization/talena 3
# /organization/familink 1
# /organization/schedule-it 1
# /organization/indus-insights 2
# /organization/brazen-careerist 4
# /organization/blue-triangle-technologies 5
# /organization/managemyspa 1
# /organization/weareholidays 3
# /organization/the-luxury-closet 5
# /organization/readbug 1
# /organization/pockee-coupon 1
# /organization/mytips 1
# /organization/proenza-schouer 1
# /organization/the-realreal 9
# /organization/cargomatic 19
# /organization/ly-com 1
# /organization/makeomnia-limited 1
# /organization/nuvia 2
# /organization/ethoca 1
# /organization/behaviosec 2
# /organization/glammedia 1
# /organization/fengguo-network 1
# /organization/usetime 1
# /organization/clutter 4
# /organization/iris-mobile 1
# /organization/u-grok-it 4
# /organization/revmetrix 6
# /organization/healthline-networks 1
# /organization/sustainable-power 1
# /organization/sagely 1
# /organization/hinge 11
# /organization/atscale 4
# /organization/renovate-america 4
# /organization/first-insight 1
# /organization/covacsis 3
# /organization/insikt-inc- 10
# /organization/grabicon--lincoln 1
# /organization/ping-identity-corporation 9
# /organization/listrunner 1
# /organization/cryptzone 2
# /organization/massblurb 3
# /organization/swol 1
# /organization/thinair 5
# /organization/globein 2
# /organization/healthcare-ttu 1
# /organization/simple-fill-inc 1
# /organization/lisnr-llc 5
# /organization/trekksoft 2
# /organization/growth-geeks 1
# /organization/babychakra 2
# /organization/unified-office 2
# /organization/wheelright 1
# /organization/packlink 2
# /organization/airway-therapeutics 3
# /organization/gobutler 12
# /organization/ztory 3
# /organization/alung-technologies 2
# /organization/gradberry 7
# /organization/au-financiers 3
# /organization/new-matter 4
# /organization/boxbee 10
# /organization/uknow-com 1
# /organization/flat-world-knowledge 1
# /organization/frx-polymers 4
# /organization/vbrand 4
# /organization/good-data 8
# /organization/leadpages 3
# /organization/rapid-vocabulary 1
# /organization/mensajeros-urbanos 1
# /organization/700bike 3
# /organization/wirescan 1
# /organization/vertical-communications-2 1
# /organization/clearcount-medical-solutions 1
# /organization/trackmaven 3
# /organization/okcoin 4
# /organization/mencanta-3 1
# /organization/motif-investing 8
# /organization/shanghai-ane-logistics 1
# /organization/unity-technologies 1
# /organization/triptease 2
# /organization/kuli-kuli 4
# /organization/sequenta 1
# /organization/off-grid-electric 5
# /organization/bevspot 2
# /organization/mobilerealtyapps-com 2
# /organization/elevaate 2
# /organization/grasswire 4
# /organization/figgu 1
# /organization/human-longevity 4
# /organization/selfscore 4
# /organization/paragon-bioservices 2
# /organization/purewine 1
# /organization/roadrunnr 3
# /organization/fluency-2 1
# /organization/rational-robotics 3
# /organization/credit-benchmark 2
# /organization/irocke 1
# /organization/democracyos 1
# /organization/longaccess 1
# /organization/incir-com 3
# /organization/fligoo 3
# /organization/tink 2
# /organization/nubimetrics 2
# /organization/noninvasix 1
# /organization/n30-pharmaceuticals 5
# /organization/bigxgh-com 1
# /organization/olist 1
# /organization/ekoio-labs 1
# /organization/alcorn-state-university 1
# /organization/twilio 7
# /organization/oddup 1
# /organization/jott-messenger 5
# /organization/moula 2
# /organization/targetingmantra 3
# /organization/cloudone 3
# /organization/bitpay 8
# /organization/quaam 1
# /organization/ovid-therapeutics 8
# /organization/infinity-augmented-reality 2
# /organization/hunteron 3
# /organization/livestories 3
# /organization/modern-movement 1
# /organization/senet 4
# /organization/videoamp 7
# /organization/cozy-cloud 2
# /organization/kiwii-capital 1
# /organization/new-story-charity 1
# /organization/porphyrio 2
# /organization/curagami 1
# /organization/xoeye-technologies 4
# /organization/the-porter 2
# /organization/vericant 2
# /organization/lophius-biosciences 3
# /organization/vinces-company 1
# /organization/shiftmobility 1
# /organization/share-practice 5
# /organization/purplle 2
# /organization/blurb 1
# /organization/blink-4 3
# /organization/edison-pharmaceuticals 1
# /organization/kts-global 1
# /organization/taboola 8
# /organization/bincode-entertainment 1
# /organization/redeem 2
# /organization/cylance 6
# /organization/recoleta-digital-media 1
# /organization/albert-dot-io 4
# /organization/skymind 1
# /organization/compoze 1
# /organization/trendkite 2
# /organization/cristal-therapeutics 5
# /organization/blinq-4 1
# /organization/stayclassy-org 10
# /organization/local-food-lab 1
# /organization/lightpoint-medical 3
# /organization/ondore 1
# /organization/rescue-forensics 1
# /organization/rockit-online 3
# /organization/moblabs 2
# /organization/roomle 2
# /organization/exagen-diagnostics 4
# /organization/next-caller 7
# /organization/aye-finance 2
# /organization/hello-giggles 3
# /organization/skyrobotics 3
# /organization/klarismo 4
# /organization/wellnow-urgent-care-holdings 1
# /organization/pretty-padded-room 1
# /organization/moneypool 1
# /organization/gtxh 1
# /organization/thrive-bioscience 12
# /organization/pickingo 2
# /organization/arcycle-software 1
# /organization/eperi-gmbh 1
# /organization/monexo-innovations-limited 1
# /organization/escadrille--inc- 1
# /organization/emitless 1
# /organization/enfold-inc 1
# /organization/dataiku 2
# /organization/intrinsic-lifesciences 1
# /organization/mad-street-den 2
# /organization/dynamixyz 1
# /organization/lendkey-technologies-inc 1
# /organization/greenlight-planet 1
# /organization/cloudblocks 3
# /organization/peach-2 1
# /organization/cloud-technology-partners 2
# /organization/restored-hearing-ltd 1
# /organization/ra-pharmaceuticals 9
# /organization/flux-neutrinity 4
# /organization/thuzio-inc 2
# /organization/troopto 1
# /organization/dejero-labs 1
# /organization/grofers-trusted-delivery-partner 2
# /organization/xanedu 2
# /organization/ocutec 3
# /organization/rally-fit 1
# /organization/hayneedle 1
# /organization/renew-power 2
# /organization/mobilesuites 2
# /organization/vip-cinema-seating 1
# /organization/o4it 1
# /organization/crowsnest-labs 1
# /organization/radio-physics-solutions 1
# /organization/memo-therapeutics 3
# ...
# /organization/postrelease 6
# /organization/paper-battery-company 1
# /organization/adbrain 3
# /organization/navitor-pharmaceuticals 4
# /organization/definitive-healthcare 1
# /organization/pacific-ethanol 1
# /organization/skarÃ¸-is 1
# /organization/capital-float 3
# /organization/treasure-data 3
# /organization/dumdum-photo 1
# /organization/tresensa 5
# /organization/aula 1
# /organization/vascular-pathways 4
# /organization/iyzi-payments 7
# /organization/fastacash 6
# /organization/allovue 4
# /organization/curve 1
# /organization/danceon 1
# /organization/noredink 4
# /organization/metacloud 6
# /organization/renova-tu-vestidor 2
# /organization/belita 4
# /organization/see-forge 2
# /organization/wideo 3
# /organization/match-point-partners 1
# /organization/true-software-scandinavia 6
# /organization/wave-broadband 3
# /organization/xamcheck 1
# /organization/tech-in-asia 9
# /organization/hyper-2 5
# /organization/kaminario 7
# /organization/dietox 2
# /organization/remoto 1
# /organization/saltdna 2
# /organization/agrilicious-org 1
# /organization/listo-financial 2
# /organization/quandl 1
# /organization/knowlarity-communications 2
# /organization/oviceversa 2
# /organization/poached-jobs 1
# /organization/coworking-spaces 3
# /organization/sailogy 2
# /organization/avekshaa-technologies 2
# /organization/conspire 1
# /organization/crickets-circle 3
# /organization/ultrinia 1
# /organization/drive-sg 1
# /organization/craftsvilla 4
# /organization/chloe-isabel 5
# /organization/grand-round-table 1
# /organization/curiosity 5
# /organization/semfox-gmbh 5
# /organization/lkc 1
# /organization/wso2 4
# /organization/hackajob 1
# /organization/green-biologics 7
# /organization/arduboy 1
# /organization/booknow 4
# /organization/superprofs 2
# /organization/odesk 6
# /organization/little-river-healthcare 1
# /organization/philz-coffee 16
# /organization/adzuna 3
# /organization/edi-io 1
# /organization/tango-management-consulting 1
# /organization/forgame 1
# /organization/reminiz 1
# /organization/b-parts 1
# /organization/appwiz 2
# /organization/whizztek-s-a 2
# /organization/starmobile 1
# /organization/tebla 1
# /organization/indow-windows 1
# /organization/datumize 1
# /organization/exara 1
# /organization/miroculus 1
# /organization/cloudsway 1
# /organization/medwell-ventures 2
# /organization/wiffinity 1
# /organization/threat-quotient 1
# /organization/46elks 3
# /organization/amagi-media-labs 1
# /organization/supplybetter 1
# /organization/achieveit-online 1
# /organization/quid 7
# /organization/zeplin 1
# /organization/maiyas-beverages-and-foods 1
# /organization/snap-fin-ventures 4
# /organization/creads 1
# /organization/pillow 10
# /organization/archivesocial 1
# /organization/harrys 9
# /organization/megvii-inc 3
# /organization/livealpha 1
# /organization/razorgator 1
# /organization/apio-systems 2
# /organization/voradius 1
# /organization/merkatic 1
# /organization/ixia 4
# /organization/instructure 4
# /organization/farmdrop 1
# /organization/bitaccess 4
# /organization/catwalk15 1
# /organization/phantom-cyber 5
# /organization/shareable-social-2 1
# /organization/takeaway-com 2
# /organization/adora 2
# /organization/simworx 1
# /organization/netia-sa 1
# /organization/sketchdeck 1
# /organization/pandomedia 1
# /organization/extole 5
# /organization/flurry 1
# /organization/can-capital 1
# /organization/linguese 1
# /organization/the-guardian 1
# /organization/intelligent-ultrasound 1
# /organization/instabridge 1
# /organization/bay-environmental-technology 1
# /organization/mirantis 7
# /organization/copatient 3
# /organization/limeade 2
# /organization/weft 5
# /organization/smart-medical-systems 1
# /organization/issuu 2
# /organization/fancred 4
# /organization/ambri 4
# /organization/drchrono 4
# /organization/lionheart-innovations 2
# /organization/voxel8 4
# /organization/mfm-master-financial-management 1
# /organization/physihome 1
# /organization/bannerman 5
# /organization/comprehend-systems 5
# /organization/signifikance 1
# /organization/purediscovery-corporation 1
# /organization/american-aerospace 1
# /organization/parsely 1
# /organization/everspin-technologies 2
# /organization/konectera 1
# /organization/jukedeck 2
# /organization/valencell 4
# /organization/blued 1
# /organization/pactcoffee 5
# /organization/chunyu 4
# /organization/investx-capital 5
# /organization/greenshield 1
# /organization/point-com 1
# /organization/carbon38 1
# /organization/matterfab 5
# /organization/conergy 1
# /organization/luxe-valet 29
# /organization/creopop 6
# /organization/zipline-medical 4
# /organization/threatmetrix 6
# /organization/honor-2 9
# /organization/habet 1
# /organization/sketchfab 5
# /organization/anews 3
# /organization/simpolfy 2
# /organization/bionym 7
# /organization/atrp-solutions 1
# /organization/bridj 5
# /organization/deliveroo 6
# /organization/surefield 1
# /organization/coupe-inc- 1
# /organization/sportamba-2 2
# /organization/spini 1
# /organization/deltax 1
# /organization/teskalabs 2
# /organization/funizen 1
# /organization/triprebel 1
# /organization/zeta-interactive 2
# /organization/travel-later-inc 1
# /organization/gorefi 21
# /organization/flydata 3
# /organization/lawgo 2
# /organization/intelliment-security 2
# /organization/teleskin 1
# /organization/uptaxi 1
# /organization/namogoo 5
# /organization/bmc-software 1
# /organization/netlex 5
# /organization/wpx-faserkeramik 1
# /organization/forcare 1
# /organization/avaz 4
# /organization/syncurity 1
# /organization/ramot 1
# /organization/videobot 1
# /organization/egenera-inc 1
# /organization/talking-data 1
# /organization/revert-io 5
# /organization/music-messenger 15
# /organization/hybridcluster 3
# /organization/fisoc 3
# /organization/sentec 1
# /organization/sense-ly 4
# /organization/lastline 4
# /organization/mobilepaks 3
# /organization/io-solar 1
# /organization/caredox 5
# /organization/urban-massage 4
# /organization/tailoritaly 1
# /organization/skylable 1
# /organization/rescale 8
# /organization/inbilin 2
# /organization/clickky 1
# /organization/seneco 1
# /organization/pact-apparel 1
# /organization/detroit-water-project 1
# /organization/careguide 43
# /organization/bee-cave-games 2
# /organization/mappedin 1
# /organization/airmedia-2 5
# /organization/proserv-group 1
# /organization/changex 3
# /organization/basho-technologies 1
# /organization/gipstech 1
# /organization/personal 1
# /organization/beamr 2
# /organization/housekeep 1
# /organization/narsys-mobile 1
# /organization/kitsplit 2
# /organization/aspire 1
# /organization/kimeta 1
# /organization/sim-partners 2
# /organization/lendinghome 4
# /organization/intradiem 2
# /organization/boxever 2
# /organization/redbiotec 1
# /organization/housing-com 4
# /organization/hupu 1
# /organization/thalchemy 3
# /organization/private-practice 1
# /organization/pasta-chips 1
# /organization/opened 1
# /organization/3scan 4
# /organization/gorsh 1
# /organization/iq-taxi 1
# /organization/koibox 1
# /organization/wello-2 1
# /organization/ways-to-wellness 1
# /organization/hemenkiralik-com 1
# /organization/move-guides 3
# /organization/powderhook 1
# /organization/aventura 5
# /organization/sensbeat 4
# /organization/ecwid 2
# /organization/magency-digital 2
# /organization/alpinereplay 3
# /organization/ginger-io 3
# /organization/freightos 4
# /organization/flipkart 14
# /organization/glamcorner 1
# /organization/renren-kuaidi 2
# /organization/meitu 8
# /organization/tutton 1
# /organization/netbeez 1
# /organization/nbd-nanotechnologies-inc 2
# /organization/coub 1
# /organization/intelligent-positioning 1
# /organization/flikn 1
# /organization/guildery 4
# /organization/unnyhog 2
# /organization/trialbee 1
# /organization/sparefoot 3
# /organization/scytl 5
# /organization/neoantigenics 1
# /organization/cafex-communications 3
# /organization/savyswap 1
# /organization/sywork 1
# /organization/a-tale-unfolds 1
# /organization/everywear-games 2
# /organization/thermiaesthetics 2
# /organization/mongodb-inc 5
# /organization/sravel 1
# /organization/adrise 4
# /organization/fancy 2
# /organization/sticky 3
# /organization/aplazame 5
# /organization/mavatar 10
# /organization/leadspace 3
# /organization/revivn 1
# /organization/gauss-surgical 3
# /organization/redis-labs 3
# /organization/booster-fuels 2
# /organization/cacco-inc 2
# /organization/change-org 21
# /organization/home24 2
# /organization/antaco 1
# /organization/horbury-group 1
# /organization/vizera-labs 1
# /organization/oneflare 4
# /organization/career-dean 1
# /organization/built-in 6
# /organization/borrowing-magnolia 1
# /organization/barunsoft 1
# /organization/brammo 2
# /organization/id-me 3
# /organization/from-scratch 2
# /organization/woowup 2
# /organization/socialsafe 1
# /organization/urbanstems 3
# /organization/open-data-institute 1
# /organization/pana 5
# /organization/introhive 6
# /organization/sotoasobi 1
# /organization/civil-maps 6
# /organization/autopilot 5
# /organization/holographic-projection-for-architecture 1
# /organization/prescribe-well 1
# /organization/aihuishou 3
# /organization/kitlocate 1
# /organization/sitespect 1
# /organization/practicegigs 2
# /organization/neokami-2 3
# /organization/altratech 3
# /organization/womai-net 2
# /organization/qwalytics 1
# /organization/cobrain 1
# /organization/alkemis-games 1
# /organization/zapya 1
# /organization/quickzip-sheet 1
# /organization/mark-one 4
# /organization/rategain 1
# /organization/haystagg 4
# /organization/moneystream 2
# /organization/datastreamx 1
# /organization/newleaf-symbiotics 4
# /organization/ny-slice 1
# /organization/snowball 6
# /organization/prosensa 1
# /organization/clearent 1
# /organization/puridify 2
# /organization/knowledge-to-practice 1
# /organization/amplifinity 4
# /organization/rifiniti 6
# /organization/logrhythm 3
# /organization/sportlogiq 4
# /organization/milestone-technologies 2
# /organization/luckypennie 1
# /organization/whatt 2
# /organization/silicon-cloud 1
# /organization/cardiva-medical 1
# /organization/ceracarbon 1
# /organization/budgetbakers-com 1
# /organization/plotable-ltd-product-simplus-io 1
# /organization/funding-circle 9
# /organization/calsol 1
# /organization/prestiamoci 1
# /organization/eshop-ventures 4
# /organization/humble-grape 1
# /organization/beaconfit 1
# /organization/sharecare 1
# /organization/crowd-sourced-story 1
# /organization/chargeitspot 5
# /organization/stylesage 6
# /organization/proversity 1
# /organization/pingwhen 1
# /organization/vivid-technologies 4
# /organization/flair-3 2
# /organization/yoozon 1
# /organization/gracious-eloise 6
# /organization/stitch-labs 2
# /organization/spingo-com 12
# /organization/pokitdok 6
# /organization/jbf 1
# /organization/cityscan 1
# /organization/erelevance-corporation 1
# /organization/iconixx-software 2
# /organization/sight-visit 1
# /organization/orderbird-ag 3
# /organization/bloomnation 7
# /organization/creamfinance 1
# /organization/vuzix 1
# /organization/qdatum 1
# /organization/zai-lab 6
# /organization/keycoopt 1
# /organization/high-alpha 3
# /organization/glide 3
# /organization/meetscom 1
# /organization/flightcar 7
# /organization/zoojoo-be 2
# /organization/nice 6
# /organization/exchange-corporation-k-k 6
# /organization/growish 4
# /organization/tutanda 1
# /organization/carena 4
# /organization/idaciti-inc 1
# /organization/klikin 2
# /organization/the-mighty 1
# /organization/vicomi 3
# /organization/clypd 7
# /organization/pulsate 4
# /organization/lawn-love 20
# /organization/tradair 3
# /organization/colucid-pharmaceuticals 8
# /organization/wanted-lab 1
# /organization/flowonix 3
# /organization/olset 11
# /organization/unomy 1
# /organization/everplans 4
# /organization/snapplify 1
# /organization/hoodin 2
# /organization/sciencelogic 3
# /organization/definigen 2
# /organization/storyroll 1
# /organization/snapyeti 1
# /organization/customermatrix 2
# /organization/speakaboos 3
# /organization/aiming 4
# /organization/photofy 2
# /organization/heatmaper 1
# /organization/flipps 5
# /organization/eunetworks-group-limited 2
# /organization/senionlab 1
# /organization/eco-armour 1
# /organization/mofang 2
# /organization/aquantia 1
# /organization/rootstock-software 1
# /organization/culqi 1
# /organization/awhere 2
# /organization/clay-io 1
# /organization/taplet 3
# /organization/bycler 1
# /organization/lion-games 3
# /organization/blitsy 7
# /organization/clear-software 2
# /organization/ecrebo 1
# /organization/stateless-networks 5
# /organization/happify 2
# /organization/buzzmove 5
# /organization/wetransfer 2
# /organization/ebr-systems 6
# /organization/ice-angel-id 1
# /organization/talent-io 7
# /organization/gymtrack 4
# /organization/living-indie 1
# /organization/guardant-health 7
# /organization/prynt 2
# /organization/bitnet-technologies 12
# /organization/efilecabinet 2
# /organization/pernixdata 10
# /organization/ambassador-uni 1
# /organization/sentinel 6
# /organization/ainstec-financial-reconciliation 2
# /organization/imcompany 6
# /organization/finsecur 2
# /organization/storycorps 1
# /organization/mejuri 1
# /organization/solopro 8
# /organization/new-planet-technologies 1
# /organization/cosmederm-bioscience 1
# /organization/zephyr-health 3
# /organization/tritrue 2
# /organization/storytoys 1
# /organization/kerridge-commercial-systems 1
# /organization/hopscotch-4 7
# /organization/beach-bum 1
# /organization/blacksnow-dk 1
# /organization/product-hunt 19
# /organization/inzen-studio 3
# /organization/blendle 2
# /organization/idri-infectious-disease-research-institute 1
# /organization/furie-operating-alaska 1
# /organization/chumbak 2
# /organization/filmijob 1
# /organization/ecurv 1
# /organization/outfittery 4
# /organization/seratis 1
# /organization/youngcurrent 1
# /organization/trueaccord 8
# /organization/tia-technology-as 1
# /organization/wealth-x 1
# /organization/anchanto 4
# /organization/robocv 5
# /organization/therabron 1
# /organization/uberlabs 1
# /organization/upout 1
# /organization/doublie 3
# /organization/simpletuition 1
# /organization/mhelpdesk 1
# /organization/machinify 3
# /organization/resens 1
# /organization/reterro-inc- 1
# /organization/trusper 4
# /organization/ping-2 1
# /organization/revolution-medicines 1
# /organization/revolut 2
# /organization/haima-ticketing 1
# /organization/quobyte-inc 2
# /organization/mesalva 1
# /organization/cloudcoreo 1
# /organization/ppro-financial-ltd 1
# /organization/quotadeck-com-odesk-elance-for-salespeople 2
# /organization/bookbub 4
# /organization/orphidia-2 1
# /organization/admobilize 1
# /organization/rightcare-solutions 1
# /organization/nexthealth-technologies 5
# /organization/lockbox-2 1
# /organization/burstiq 1
# /organization/pulmorphix 1
# /organization/financialforce-com 3
# /organization/surfair 1
# /organization/heartoday-org 1
# /organization/findyr 2
# /organization/qstream 3
# /organization/persimmon-technologies 2
# /organization/beanstalk-tax 3
# /organization/nagisa-inc 1
# /organization/gameplan-learning 1
# /organization/spaceflight 3
# /organization/atox-bio 3
# /organization/iron-drone-inc 1
# /organization/samba-mobile 2
# /organization/cycle-money 1
# /organization/teraki 1
# /organization/yogatrail 4
# /organization/flatout-technologies 4
# /organization/alphatec-spine 1
# /organization/notice-software 5
# /organization/angani-limited 3
# /organization/punchtab 1
# /organization/heroic-ly 1
# /organization/perfectus-biomed 1
# /organization/sr-pago 2
# /organization/harir 1
# /organization/placefull 1
# /organization/doordash 8
# /organization/mightysignal 10
# /organization/riva 2
# /organization/novix-media-adsparx 3
# /organization/vatler 1
# /organization/tachyus 9
# /organization/mountary 1
# /organization/shot-stats 1
# /organization/nickis-com 1
# /organization/cipher-surgical 1
# /organization/dash-radio-inc 10
# /organization/iti-health 1
# /organization/inari-medical 2
# /organization/guangzhou-huan-company 1
# /organization/next-thing 1
# /organization/shapr 1
# /organization/acumen-2 1
# /organization/kalibrr 2
# /organization/genius-com 3
# /organization/actionsprout 4
# /organization/weplann 1
# /organization/smartvue 4
# /organization/perblue 1
# /organization/musti-ja-mirri-group 1
# /organization/frank-oak 9
# /organization/okan-inc- 2
# /organization/qwbcg 1
# /organization/fashion-project 8
# /organization/hopscotch-2 4
# /organization/walksource 18
# /organization/grameen-financial-services 1
# /organization/orori 1
# /organization/tutorgroup 1
# /organization/formisimo 2
# /organization/code-fresh 1
# /organization/decisio-health 1
# /organization/acre-2 1
# /organization/transifex 5
# /organization/asm-organic-recyclates 1
# /organization/wandisco 1
# /organization/events-com 3
# /organization/eureka-restaurant-group 1
# /organization/power-africa 1
# /organization/nara-logics 2
# /organization/sofatutor 4
# /organization/connected2-me 7
# /organization/juicies 1
# /organization/purse-io 8
# /organization/lytics 3
# /organization/techpoint-2 1

# %%
preG = loadEdgelist("../1_snapshotting/cumulative_snapshots/enddate_20140228.edgelist")
# Set node attributes. 0 is an investor, 1 is a company.
node_attributes =dict(map(lambda (x,y): (x,1) if y > 0 else (x,0), 
                      preG.in_degree().items()))
nx.set_node_attributes(preG, "bipartite", node_attributes)

# %%
# startup_degree = filter(lambda (n, d): node_attributes[n] == 1,
#                         preG.degree().items())
# sorted_degree_list = sorted(startup_degree, 
#                             key=operator.itemgetter(1), reverse=True)

# %%
investor_degree = filter(lambda (n, d): node_attributes[n] == 0,
                        preG.out_degree().items())
sorted_investor_degree_list = sorted(investor_degree, 
                            key=operator.itemgetter(1), reverse=True)

# %%
sorted_investor_degree_list[0:254]
# Out:
# [(u'/organization/goldman-sachs', 3259178984.0),
#  (u'/organization/u-s-department-of-energy', 2496298333.0),
#  (u'/organization/sequoia-capital', 2030354338.0),
#  (u'/organization/kleiner-perkins-caufield-byers', 2002657884.0),
#  (u'/organization/new-enterprise-associates', 1849830928.0),
#  (u'/organization/google', 1794319046.0),
#  (u'/organization/intel-capital', 1738903618.0),
#  (u'/organization/accel-partners', 1509631569.0),
#  (u'/organization/ta-associates', 1499729666.0),
#  (u'/organization/warburg-pincus', 1284074626.0),
#  (u'/organization/insight-venture-partners', 1183010778.0),
#  (u'/organization/digital-sky-technologies-fo', 1127877199.0),
#  (u'/organization/summit-partners', 1094343293.0),
#  (u'/organization/venrock', 1039630234.0),
#  (u'/organization/oak-investment-partners', 1020506703.0),
#  (u'/organization/saif-partners', 939267102.0),
#  (u'/organization/microsoft', 909056748.0),
#  (u'/organization/ge-capital', 906828559.0),
#  (u'/organization/index-ventures', 891035851.0),
#  (u'/organization/3i-group', 887165396.0),
#  (u'/organization/technology-crossover-ventures', 886673282.0),
#  (u'/organization/idg-capital-partners', 858395684.0),
#  (u'/organization/silicon-valley-bank', 847700193.0),
#  (u'/organization/draper-fisher-jurvetson', 846188488.0),
#  (u'/organization/benchmark', 840555445.0),
#  (u'/organization/carlyle-group', 805431891.0),
#  (u'/organization/battery-ventures', 779186006.0),
#  (u'/organization/russian-direct-investment-fund', 776833333.0),
#  (u'/organization/oak-hill-capital-partners', 769379232.0),
#  (u'/organization/bessemer-venture-partners', 768624973.0),
#  (u'/organization/tencent', 763676896.0),
#  (u'/organization/softbank-capital', 748971674.0),
#  (u'/organization/khosla-ventures', 726316913.0),
#  (u'/organization/morgan-stanley', 713726824.0),
#  (u'/organization/north-bridge-venture-partners', 704284691.0),
#  (u'/organization/greylock', 701756497.0),
#  (u'/organization/redpoint-ventures', 677223070.0),
#  (u'/organization/bain-capital-ventures', 669674994.0),
#  (u'/organization/general-catalyst-partners', 664970008.0),
#  (u'/organization/matrix-partners', 650869984.0),
#  (u'/organization/norwest-venture-partners', 647351275.0),
#  (u'/organization/riverstone-holdings', 646272727.0),
#  (u'/organization/lightspeed-venture-partners', 646098435.0),
#  (u'/organization/highland-capital-partners', 641602619.0),
#  (u'/organization/polaris-partners', 636801707.0),
#  (u'/organization/andreessen-horowitz', 634515823.0),
#  (u'/organization/general-atlantic', 625768657.0),
#  (u'/organization/austin-ventures', 608389376.0),
#  (u'/organization/institutional-venture-partners', 607737337.0),
#  (u'/organization/ekf', 600000000.0),
#  (u'/organization/dcm', 593507620.0),
#  (u'/organization/spectrum-equity-investors', 581666666.0),
#  (u'/organization/inter-atlantic-group', 557691000.0),
#  (u'/organization/temasek', 557083239.0),
#  (u'/organization/kkr', 551160000.0),
#  (u'/organization/vantagepoint-capital-partners', 548742464.0),
#  (u'/organization/libertymedia', 546250000.0),
#  (u'/organization/us-venture-partners', 541352086.0),
#  (u'/organization/alibaba', 539000000.0),
#  (u'/organization/orbimed-advisors', 526119545.0),
#  (u'/organization/gi-partners', 525000000.0),
#  (u'/organization/menlo-ventures', 500962830.0),
#  (u'/organization/francisco-partners', 478000000.0),
#  (u'/organization/dag-ventures', 465622053.0),
#  (u'/organization/eso-fund', 464225747.0),
#  (u'/organization/jpmorgan-chase-co', 458712120.0),
#  (u'/organization/t-rowe-price', 451344684.0),
#  (u'/organization/centerbridge-partners', 441250000.0),
#  (u'/organization/access-industries', 429008476.0),
#  (u'/organization/canaan-partners', 422986177.0),
#  (u'/organization/credit-suisse', 421927734.0),
#  (u'/organization/silver-lake-partners', 419916666.0),
#  (u'/organization/hercules-technology-growth-capital', 402010951.0),
#  (u'/organization/elevation-partners', 401407142.0),
#  (u'/organization/u-s-bancorp', 399500000.0),
#  (u'/organization/foundation-capital', 394550726.0),
#  (u'/organization/sv-angel', 385999263.0),
#  (u'/organization/flagship-ventures', 381050050.0),
#  (u'/organization/tencent-industry-win-win-fund', 369623245.0),
#  (u'/organization/third-rock-ventures', 369051187.0),
#  (u'/organization/rho-capital-ventures', 368838166.0),
#  (u'/organization/advent-international', 368734240.0),
#  (u'/organization/abry-partners', 368333333.0),
#  (u'/organization/meritech-capital-partners', 366213563.0),
#  (u'/organization/deerfield-management', 364519961.0),
#  (u'/organization/mohr-davidow-ventures', 361020877.0),
#  (u'/organization/founders-fund', 360724703.0),
#  (u'/organization/google-ventures', 360344514.0),
#  (u'/organization/mayfield-fund', 359778960.0),
#  (u'/organization/interwest-partners', 356281356.0),
#  (u'/organization/paladin-capital-group', 355822543.0),
#  (u'/organization/ignition-partners', 355201802.0),
#  (u'/organization/charles-river-ventures', 353522157.0),
#  (u'/organization/qiming-venture-partners', 348032715.0),
#  (u'/organization/atlas-venture', 347928928.0),
#  (u'/organization/balderton-capital', 346370909.0),
#  (u'/organization/delphi-ventures', 344220392.0),
#  (u'/organization/essex-woodlands-health-ventures', 343441357.0),
#  (u'/organization/shenzhen-capital-group', 333131365.0),
#  (u'/organization/trident-capital', 328964812.0),
#  (u'/organization/fidelity-ventures', 324494096.0),
#  (u'/organization/llr-partners', 320684819.0),
#  (u'/organization/bank-of-america', 320226188.0),
#  (u'/organization/j-p-morgan-securities-inc', 316053756.0),
#  (u'/organization/adams-street-partners', 314117449.0),
#  (u'/organization/morgenthaler-ventures', 314023358.0),
#  (u'/organization/quadrangle', 311666666.0),
#  (u'/organization/qualcomm-ventures', 309824029.0),
#  (u'/organization/sigma-partners', 305968368.0),
#  (u'/organization/providence-equity-partners', 305000000.0),
#  (u'/organization/jmi-equity', 304323331.0),
#  (u'/organization/scottish-equity-partners', 302889528.0),
#  (u'/organization/dfj-growth', 299023192.0),
#  (u'/organization/novo-a-s', 297635529.0),
#  (u'/organization/trinity-ventures', 292266370.0),
#  (u'/organization/vulcan-capital', 291694837.0),
#  (u'/organization/cdh-investments', 289080619.0),
#  (u'/organization/great-hill-partners', 289000000.0),
#  (u'/organization/arch-venture-partners', 288523925.0),
#  (u'/organization/ardian', 287772828.0),
#  (u'/organization/tiger-global', 282133428.0),
#  (u'/organization/ggv-capital', 280783329.0),
#  (u'/organization/investor-growth-capital', 280243236.0),
#  (u'/organization/cross-creek-capital', 280030954.0),
#  (u'/organization/ftv-capital', 279812499.0),
#  (u'/organization/domain-associates', 276321730.0),
#  (u'/organization/bluerun-ventures', 275356765.0),
#  (u'/organization/business-growth-fund', 274079177.0),
#  (u'/organization/abs-capital-partners', 274059999.0),
#  (u'/organization/mpm-capital', 273749690.0),
#  (u'/organization/cisco', 271611061.0),
#  (u'/organization/pitango-venture-capital', 270884672.0),
#  (u'/organization/j-p-morgan', 270750000.0),
#  (u'/organization/ge-energy-financial-services', 270724999.0),
#  (u'/organization/bain-capital-2', 270441665.0),
#  (u'/organization/general-electric', 270202380.0),
#  (u'/organization/alta-partners', 268524281.0),
#  (u'/organization/first-round-capital', 267270750.0),
#  (u'/organization/natural-gas-partners', 266564010.0),
#  (u'/organization/salesforce-ventures', 266219222.0),
#  (u'/organization/fondo-italiano-di-investimento', 266132000.0),
#  (u'/organization/actis', 262833333.0),
#  (u'/organization/sofinnova-partners', 262591559.0),
#  (u'/organization/cabiedes-partners', 262114621.0),
#  (u'/organization/maverick-capital', 261217522.0),
#  (u'/organization/intel', 259923847.0),
#  (u'/organization/wells-fargo-bank', 257166666.0),
#  (u'/organization/spark-capital', 255859394.0),
#  (u'/organization/sofinnova-ventures', 254969759.0),
#  (u'/organization/versant-ventures', 251388533.0),
#  (u'/organization/european-investment-bank', 250187640.0),
#  (u'/organization/vista-equity-partners', 250000000.0),
#  (u'/organization/pag-asia-capital', 250000000.0),
#  (u'/organization/brighthouse-inc', 250000000.0),
#  (u'/organization/wellington-partners', 247933536.0),
#  (u'/organization/bdc-venture-capital', 247845319.0),
#  (u'/organization/cmea-capital', 246600273.0),
#  (u'/organization/advanced-equities', 246498570.0),
#  (u'/organization/ontario-teachers-pension-plan', 245849386.0),
#  (u'/organization/capitalsource', 244333333.0),
#  (u'/organization/globespan-capital-partners', 243463999.0),
#  (u'/organization/august-capital', 242815911.0),
#  (u'/organization/tpg-growth', 242729568.0),
#  (u'/organization/columbia-capital', 241984847.0),
#  (u'/organization/crosslink-capital', 238571356.0),
#  (u'/organization/alloy-ventures', 238563134.0),
#  (u'/organization/golub-capital', 237571428.0),
#  (u'/organization/sutter-hill-ventures', 235547623.0),
#  (u'/organization/forest-laboratories', 235000000.0),
#  (u'/organization/cit-group', 234783333.0),
#  (u'/organization/matrix-partners-china', 234741573.0),
#  (u'/organization/scale-venture-partners', 234609991.0),
#  (u'/organization/mitsui-ventures', 233578327.0),
#  (u'/organization/invesco-perpetual', 233474980.0),
#  (u'/organization/advanced-technology-ventures', 232701304.0),
#  (u'/organization/sv-life-sciences', 232561863.0),
#  (u'/organization/alibaba-capital-partners', 231211355.0),
#  (u'/organization/sierra-ventures', 230103182.0),
#  (u'/organization/sapphire-ventures', 230093499.0),
#  (u'/organization/johnson-johnson-development-corporation', 229149184.0),
#  (u'/organization/rre-ventures', 228643390.0),
#  (u'/organization/comerica-bank', 225432855.0),
#  (u'/organization/hony-capital', 224641288.0),
#  (u'/organization/in-q-tel', 224371964.0),
#  (u'/organization/allen-and-company', 223430886.0),
#  (u'/organization/altamont-capital-partners', 222000000.0),
#  (u'/organization/danish-pension-fund', 220000000.0),
#  (u'/organization/keybank', 219333333.0),
#  (u'/organization/crunchfund', 218251606.0),
#  (u'/organization/oxford-finance-corporation', 218116592.0),
#  (u'/organization/nokia-growth-partners', 218096675.0),
#  (u'/organization/gsr-ventures-management', 217783950.0),
#  (u'/organization/pinnacle-ventures', 216226118.0),
#  (u'/organization/viola-credit', 215058690.0),
#  (u'/organization/kennet-venture-partners', 213837813.0),
#  (u'/organization/shasta-ventures', 210992509.0),
#  (u'/organization/sig-china', 210015571.0),
#  (u'/organization/suning', 210000000.0),
#  (u'/organization/northgate-capital', 208049710.0),
#  (u'/organization/bay-partners', 207325561.0),
#  (u'/organization/edison-ventures', 206620180.0),
#  (u'/organization/novartis-venture-fund', 204066057.0),
#  (u'/organization/morningside-group', 203471537.0),
#  (u'/organization/fidelity-investments', 201916665.0),
#  (u'/organization/celgene', 201761904.0),
#  (u'/organization/qed-investors', 201506563.0),
#  (u'/organization/comcast', 200916666.0),
#  (u'/organization/lvmh', 200420000.0),
#  (u'/organization/wellcome-trust', 200325736.0),
#  (u'/organization/permira', 200000000.0),
#  (u'/organization/foxconn-international-holdings', 200000000.0),
#  (u'/organization/felicis-ventures', 199446358.0),
#  (u'/organization/baidu', 198804219.0),
#  (u'/organization/the-social-capital-partnership', 196374229.0),
#  (u'/organization/deutsche-bank', 196189721.0),
#  (u'/organization/clarus-ventures', 195923785.0),
#  (u'/organization/rustic-canyon-partners', 194487121.0),
#  (u'/organization/updata-partners', 194459522.0),
#  (u'/organization/eagle-river-holdings', 194000000.0),
#  (u'/organization/timewarner', 193691666.0),
#  (u'/organization/western-technology-investment', 193038504.0),
#  (u'/organization/international-finance-corporation', 192729285.0),
#  (u'/organization/investment-ab-kinnevik', 192440275.0),
#  (u'/organization/flybridge-capital', 192357621.0),
#  (u'/organization/triplepoint-capital', 191702100.0),
#  (u'/organization/samsung-ventures', 191640096.0),
#  (u'/organization/idinvest-partners', 188383167.0),
#  (u'/organization/gso-capital-partners', 187234516.0),
#  (u'/organization/atomico', 186608391.0),
#  (u'/organization/bay-city-capital', 186462936.0),
#  (u'/organization/gimv', 186080438.0),
#  (u'/organization/glaxosmithkline', 186030783.0),
#  (u'/organization/iconiq-capital', 185400000.0),
#  (u'/organization/overseas-private-investment-corp', 185000000.0),
#  (u'/organization/square-1-bank', 184466664.0),
#  (u'/organization/iconventures', 181880941.0),
#  (u'/organization/auriga-partners', 181828464.0),
#  (u'/organization/comcast-interactive-capital', 181613960.0),
#  (u'/organization/partech-international', 181559107.0),
#  (u'/organization/texas-pacific-group', 179456740.0),
#  (u'/organization/split-rock-partners', 178941442.0),
#  (u'/organization/national-institutes-of-health', 178219000.0),
#  (u'/organization/lehman-brothers', 178005988.0),
#  (u'/organization/safeguard-scientifics', 177485115.0),
#  (u'/organization/new-leaf-venture-partners', 175325841.0),
#  (u'/organization/sevin-rosen-funds', 174926632.0),
#  (u'/organization/apex-venture-partners', 173264521.0),
#  (u'/organization/abingworth-management', 172688344.0),
#  (u'/organization/birchmere-ventures', 172029111.0),
#  (u'/organization/greenspring-associates', 170962855.0),
#  (u'/organization/rbc-capital-markets', 170625000.0),
#  (u'/organization/frazier-healthcare-ventures', 170060214.0),
#  (u'/organization/european-union', 168718450.0),
#  (u'/organization/artiman-ventures', 167657726.0)]

# %%
sorted(m.items(), key=operator.itemgetter(1), reverse=True)
# Out:
# [('/organization/wayra', 254),
#  ('/organization/500-startups', 252),
#  ('/organization/y-combinator', 220),
#  ('/organization/sequoia-capital', 174),
#  ('/organization/techstars', 167),
#  ('/organization/new-enterprise-associates', 146),
#  ('/organization/accel-partners', 135),
#  ('/organization/cyberport-hong-kong', 124),
#  ('/organization/kima-ventures', 118),
#  ('/organization/intel-capital', 115),
#  ('/organization/microsoft-ventures', 112),
#  ('/organization/start-up-chile', 110),
#  ('/organization/plug-and-play-ventures', 105),
#  ('/organization/startupbootcamp', 102),
#  ('/organization/andreessen-horowitz', 101),
#  ('/organization/kleiner-perkins-caufield-byers', 100),
#  ('/organization/silicon-valley-bank', 99),
#  ('/organization/queensbridge-venture-partners', 95),
#  ('/organization/google-ventures', 95),
#  ('/organization/khosla-ventures', 93),
#  ('/organization/slow-ventures', 87),
#  ('/organization/sv-angel', 86),
#  ('/organization/first-round-capital', 85),
#  ('/organization/great-oaks-venture-capital', 84),
#  ('/organization/index-ventures', 84),
#  ('/organization/bessemer-venture-partners', 81),
#  ('/organization/general-catalyst-partners', 77),
#  ('/organization/nxtp-labs', 75),
#  ('/organization/high-tech-gruenderfonds', 71),
#  ('/organization/lerer-ventures', 71),
#  ('/organization/lightspeed-venture-partners', 70),
#  ('/organization/social-starts', 70),
#  ('/organization/tiger-global', 70),
#  ('/organization/eleven', 69),
#  ('/organization/fundersclub', 68),
#  ('/organization/atlas-venture', 67),
#  ('/organization/greycroft-partners', 63),
#  ('/organization/true-ventures', 62),
#  ('/organization/foundation-capital', 61),
#  ('/organization/crowdcube', 61),
#  ('/organization/goldman-sachs', 59),
#  ('/organization/redpoint-ventures', 59),
#  ('/organization/rre-ventures', 59),
#  ('/organization/ben-franklin-technology-partners-of-southeastern-pennsylvania',
#   57),
#  ('/organization/seedrs', 56),
#  ('/organization/qualcomm-ventures', 56),
#  ('/organization/greylock', 55),
#  ('/organization/matrix-partners', 54),
#  ('/organization/norwest-venture-partners', 54),
#  ('/organization/innovation-works', 53),
#  ('/organization/battery-ventures', 52),
#  ('/organization/ame-cloud-ventures', 52),
#  ('/organization/streamlined-ventures', 52),
#  ('/organization/sherpa-ventures', 52),
#  ('/person/fabrice-grinda', 52),
#  ('/organization/east-ventures', 51),
#  ('/organization/salesforce-ventures', 50),
#  ('/organization/data-collective', 50),
#  ('/organization/idg-capital-partners', 50),
#  ('/organization/seedcamp', 50),
#  ('/organization/foundry-group', 48),
#  ('/organization/crunchfund', 48),
#  ('/organization/spark-capital', 48),
#  ('/organization/draper-fisher-jurvetson', 46),
#  ('/organization/insight-venture-partners', 46),
#  ('/organization/wellington-management', 46),
#  ('/organization/felicis-ventures', 46),
#  ('/organization/angels-den', 46),
#  ('/organization/vayner-rse', 45),
#  ('/organization/canaan-partners', 45),
#  ('/organization/founders-fund', 44),
#  ('/organization/bain-capital-ventures', 44),
#  ('/organization/formation8', 44),
#  ('/organization/ggv-capital', 44),
#  ('/organization/boxgroup', 43),
#  ('/organization/venrock', 43),
#  ('/organization/capstone-partners-korea', 41),
#  ('/organization/crosslink-capital', 41),
#  ('/organization/tencent', 41),
#  ('/organization/softtech-vc', 41),
#  ('/organization/menlo-ventures', 40),
#  ('/organization/correlation-ventures', 38),
#  ('/person/kevin-colleran', 38),
#  ('/organization/haxlr8r', 38),
#  ('/organization/saif-partners', 38),
#  ('/organization/softbank-capital', 37),
#  ('/organization/trinity-ventures', 37),
#  ('/organization/the-social-capital-partnership', 37),
#  ('/organization/mayfield-fund', 36),
#  ('/organization/benchmark', 36),
#  ('/organization/shasta-ventures', 36),
#  ('/organization/charles-river-ventures', 36),
#  ('/organization/bloomberg-beta', 36),
#  ('/organization/sosv', 35),
#  ('/organization/orbimed-advisors', 35),
#  ('/organization/dcm', 34),
#  ('/organization/polaris-partners', 34),
#  ('/organization/vegastechfund', 34),
#  ('/organization/samsung-ventures', 33),
#  ('/organization/firstmark-capital', 33),
#  ('/organization/upfront-ventures', 33),
#  ('/organization/e-ventures', 33),
#  ('/organization/institutional-venture-partners', 33),
#  ('/organization/metamorphic-ventures-llc', 32),
#  ('/person/timothy-draper', 32),
#  ('/organization/er-accelerator', 32),
#  ('/organization/rough-draft-ventures', 31),
#  ('/organization/alibaba', 31),
#  ('/organization/thrive-capital', 31),
#  ('/organization/western-technology-investment', 31),
#  ('/organization/structure-capital', 30),
#  ('/organization/comcast-interactive-capital', 30),
#  ('/organization/accelerace', 30),
#  ('/organization/union-square-ventures', 30),
#  ('/organization/ta-venture', 30),
#  ('/organization/floodgate', 30),
#  ('/organization/chinaccelerator', 30),
#  ('/organization/albion-ventures', 30),
#  ('/organization/madrona-venture-group', 30),
#  ('/organization/sparklabs-global-ventures', 30),
#  ('/organization/point-nine-capital', 29),
#  ('/organization/club-italia-investimenti', 29),
#  ('/organization/startx', 29),
#  ('/organization/ra-capital-management', 29),
#  ('/organization/highland-capital-partners', 29),
#  ('/organization/third-wave-digital', 29),
#  ('/organization/dreamit-ventures', 28),
#  ('/organization/crypto-currency-partners', 28),
#  ('/organization/august-capital', 28),
#  ('/organization/horizons-ventures', 28),
#  ('/person/brendan-wallace', 28),
#  ('/organization/helion-venture-partners', 28),
#  ('/organization/sharespost-investment-management', 28),
#  ('/organization/bpifrance', 28),
#  ('/organization/octopus-ventures', 28),
#  ('/organization/bdc-venture-capital', 28),
#  ('/organization/teec-angel-fund', 27),
#  ('/organization/aslanoba-capital', 27),
#  ('/organization/partech-international', 27),
#  ('/person/alexis-ohanian', 27),
#  ('/organization/angelpad', 27),
#  ('/organization/ge-ventures', 26),
#  ('/organization/ourcrowd', 26),
#  ('/organization/dn-capital', 26),
#  ('/organization/parkwalk-advisors', 26),
#  ('/organization/cit-gap-funds', 26),
#  ('/organization/rothenberg-ventures', 26),
#  ('/organization/portugal-ventures', 26),
#  ('/organization/interwest-partners', 26),
#  ('/organization/sapphire-ventures', 26),
#  ('/organization/novartis-venture-fund', 26),
#  ('/organization/tenaya-capital', 26),
#  ('/organization/pritzker-group-venture-capital', 26),
#  ('/organization/technology-crossover-ventures', 25),
#  ('/organization/galvanize', 25),
#  ('/person/scott-banister', 25),
#  ('/organization/ff-venture-capital', 25),
#  ('/organization/siemer-ventures', 25),
#  ('/organization/scout-ventures', 25),
#  ('/organization/nexus-venture-partners', 25),
#  ('/organization/balderton-capital', 25),
#  ('/organization/fenox-venture-capital', 25),
#  ('/organization/kapor-capital', 25),
#  ('/organization/seedinvest', 25),
#  ('/organization/marker', 25),
#  ('/person/jose-marin-2', 25),
#  ('/organization/blumberg-capital', 25),
#  ('/person/marc-benioff', 25),
#  ('/organization/omidyar-network', 25),
#  ('/organization/maryland-venture-fund', 25),
#  ('/organization/cyberagent', 25),
#  ('/organization/northgate-capital', 25),
#  ('/organization/founder-collective', 24),
#  ('/organization/blue-startups', 24),
#  ('/organization/j-hunt-holdings', 24),
#  ('/organization/square-1-bank', 24),
#  ('/organization/collaborative-fund', 24),
#  ('/organization/german-startups-group', 24),
#  ('/organization/amplify-la', 24),
#  ('/organization/altos-ventures', 24),
#  ('/organization/temasek', 24),
#  ('/organization/enterprise-ireland', 24),
#  ('/organization/lowercase-capital', 24),
#  ('/organization/idg-ventures-usa', 24),
#  ('/organization/alliance-of-angels', 23),
#  ('/organization/mesa-ventures', 23),
#  ('/organization/imprimatur-capital', 23),
#  ('/organization/microsoft-ventures-accelerator-seattle', 23),
#  ('/organization/greylock-partners-israel', 23),
#  ('/organization/scale-venture-partners', 23),
#  ('/organization/oxford-finance-corporation', 23),
#  ('/organization/real-ventures', 23),
#  ('/organization/northzone-ventures', 23),
#  ('/organization/portland-seed-fund', 23),
#  ('/organization/sunstone-capital', 23),
#  ('/organization/mci-management', 23),
#  ('/organization/kalaari-capital', 23),
#  ('/organization/serra-ventures', 23),
#  ('/organization/siemens-venture-capital', 23),
#  ('/organization/maveron', 23),
#  ('/organization/bullet-time-ventures', 23),
#  ('/organization/scottish-investment-bank', 22),
#  ('/organization/wellington-partners', 22),
#  ('/organization/global-brain-corporation', 22),
#  ('/organization/sutter-hill-ventures', 22),
#  ('/organization/rocket-internet', 22),
#  ('/organization/ignition-partners', 22),
#  ('/organization/t-rowe-price', 22),
#  ('/organization/sofinnova-ventures', 22),
#  ('/organization/innovation-endeavors', 22),
#  ('/organization/qualcomm', 22),
#  ('/organization/avalon-ventures', 22),
#  ('/organization/morningside-group', 21),
#  ('/organization/nokia-growth-partners', 21),
#  ('/organization/peak-ventures', 21),
#  ('/person/bobby-yazdani', 21),
#  ('/organization/idg-ventures-india', 21),
#  ('/organization/finnvera-venture-capital', 21),
#  ('/organization/jfdi-asia', 21),
#  ('/organization/inovia-capital', 21),
#  ('/organization/eniac-ventures', 21),
#  ('/organization/rock-springs-capital', 21),
#  ('/organization/lanzadera-accelerator', 21),
#  ('/organization/fidelity-biosciences', 21),
#  ('/person/paul-buchheit', 21),
#  ('/organization/business-growth-fund', 21),
#  ('/organization/advancit-capital', 21),
#  ('/organization/north-bridge-venture-partners', 21),
#  ('/organization/expansion-venture-capital', 21),
#  ('/organization/lux-capital', 21),
#  ('/organization/dag-ventures', 20),
#  ('/organization/idinvest-partners', 20),
#  ('/person/semil-shah', 20),
#  ('/organization/national-institutes-of-health', 20),
#  ('/organization/pitango-venture-capital', 20),
#  ('/organization/trinity-capital-investment', 20),
#  ('/organization/acceleprise-san-francisco', 20),
#  ('/organization/oak-investment-partners', 20),
#  ('/organization/tenoneten-ventures', 20),
#  ('/organization/kkr', 20),
#  ('/organization/tmcx-accelerator', 20),
#  ('/organization/signatures-capital', 20),
#  ('/organization/co-lab-2', 20),
#  ('/organization/vilcap-investments', 20),
#  ('/organization/us-venture-partners', 20),
#  ('/organization/draper-associates-2', 20),
#  ('/organization/emergence-capital-partners', 20),
#  ('/organization/alven-capital', 20),
#  ('/organization/connecticut-innovations', 19),
#  ('/organization/baseline-ventures', 19),
#  ('/organization/softbank-ventures-korea', 19),
#  ('/organization/legendstar', 19),
#  ('/organization/winklevoss-capital', 19),
#  ('/organization/disney-accelerator', 19),
#  ('/organization/carmel-ventures', 19),
#  ('/organization/verizon-ventures', 19),
#  ('/organization/chicago-ventures', 19),
#  ('/organization/commonangels', 19),
#  ('/organization/bridges-ventures', 19),
#  ('/organization/warburg-pincus', 19),
#  ('/organization/o-reilly-alphatech-ventures', 19),
#  ('/organization/qiming-venture-partners', 19),
#  ('/organization/iconiq-capital', 19),
#  ('/organization/bertelsmann-digital-media-investments', 19),
#  ('/organization/fledge', 19),
#  ('/organization/blume-ventures', 19),
#  ('/organization/food-x', 19),
#  ('/organization/cultivation-capital', 19),
#  ('/organization/forerunner-ventures', 19),
#  ('/organization/gree-ventures', 19),
#  ('/organization/emerge-venture-lab', 19),
#  ('/organization/synbio-axlr8r', 19),
#  ('/organization/earlybird-venture-capital', 19),
#  ('/organization/barclays-accelerator', 19),
#  ('/organization/double-m-partners', 19),
#  ('/organization/techcolumbus-2', 18),
#  ('/organization/creandum', 18),
#  ('/organization/iris-capital', 18),
#  ('/organization/lightbank', 18),
#  ('/organization/azure-capital-partners', 18),
#  ('/organization/kec-ventures', 18),
#  ('/organization/version-one-ventures', 18),
#  ('/organization/sr-one', 18),
#  ('/organization/hercules-technology-growth-capital', 18),
#  ('/organization/lventures', 18),
#  ('/organization/arch-venture-partners', 18),
#  ('/organization/mercury-fund', 18),
#  ('/organization/resolute-vc', 18),
#  ('/person/garry-tan', 18),
#  ('/organization/fidelity-investments', 18),
#  ('/organization/ribbit-capital', 17),
#  ('/person/rajan-anandan', 17),
#  ('/organization/digital-garage', 17),
#  ('/organization/axel-springer-plug-and-play-accelerator', 17),
#  ('/organization/hillhouse-capital', 17),
#  ('/organization/china-rock-capital', 17),
#  ('/organization/matrix-partners-china', 17),
#  ('/organization/notion-capital', 17),
#  ('/organization/boldstart-ventures', 17),
#  ('/organization/two-sigma-ventures', 17),
#  ('/person/peter-thiel', 17),
#  ('/organization/the-r-group-llc', 17),
#  ('/organization/cisco', 17),
#  ('/organization/mohr-davidow-ventures', 17),
#  ('/organization/international-finance-corporation', 17),
#  ('/organization/promus-ventures', 17),
#  ('/organization/accelerator-centre', 17),
#  ('/person/mark-cuban', 17),
#  ('/organization/passion-capital', 17),
#  ('/organization/harrison-metal', 17),
#  ('/organization/inventure-oy', 17),
#  ('/organization/hyde-park-venture-partners', 17),
#  ('/organization/route-66-ventures', 17),
#  ('/organization/406-ventures', 17),
#  ('/organization/grotech-ventures', 17),
#  ('/organization/safeguard-scientifics', 17),
#  ('/organization/drummond-road-capital', 17),
#  ('/organization/cli-ventures', 17),
#  ('/organization/baidu', 17),
#  ('/organization/homebrew-ventures', 16),
#  ('/organization/adams-street-partners', 16),
#  ('/organization/cherubic-ventures', 16),
#  ('/organization/newfund-management', 16),
#  ('/organization/dev', 16),
#  ('/organization/wi-harper-group', 16),
#  ('/organization/korea-investment-partners', 16),
#  ('/organization/toba-capital', 16),
#  ('/organization/fuel-capital', 16),
#  ('/organization/flint-capital', 16),
#  ('/organization/flybridge-capital', 16),
#  ('/organization/founderfuel', 16),
#  ('/organization/redpoint-eventures', 16),
#  ('/organization/fresco-capital-advisors', 16),
#  ('/person/rick-marini', 16),
#  ('/organization/versant-ventures', 16),
#  ('/organization/epic-ventures', 16),
#  ('/organization/peterson-ventures', 16),
#  ('/organization/beringea', 16),
#  ('/organization/commerce-ventures', 16),
#  ('/organization/maiden-lane-ventures', 16),
#  ('/person/allen-debevoise-2', 16),
#  ('/organization/xange-private-equity', 16),
#  ('/organization/altair', 16),
#  ('/organization/domain-associates', 16),
#  ('/organization/storm-ventures', 16),
#  ('/organization/edison-ventures', 16),
#  ('/organization/middleland-capital', 16),
#  ('/person/jason-finger', 16),
#  ('/organization/programma-101', 16),
#  ('/person/farzad-nazem', 16),
#  ('/organization/softbank', 16),
#  ('/organization/imperial-innovations', 15),
#  ('/organization/pejman-mar-ventures', 15),
#  ('/organization/costanoa-venture-capital', 15),
#  ('/organization/pfizer-venture-investments', 15),
#  ('/organization/rockstart-acclerator', 15),
#  ('/organization/elevator', 15),
#  ('/organization/rock-health', 15),
#  ('/organization/magma-venture-partners', 15),
#  ('/organization/sierra-maya-ventures', 15),
#  ('/organization/crosscut-ventures', 15),
#  ('/organization/mena-venture-investments', 15),
#  ('/person/max-levchin', 15),
#  ('/organization/nmotion', 15),
#  ('/organization/industry-ventures', 15),
#  ('/organization/silverton-partners', 15),
#  ('/organization/red-sea-venture-partners', 15),
#  ('/organization/quest-venture-partners', 15),
#  ('/organization/holtzbrinck-ventures', 15),
#  ('/organization/cowboy-ventures', 15),
#  ('/organization/brainstoventures', 15),
#  ('/organization/redmile-group', 15),
#  ('/organization/tekton-ventures', 15),
#  ('/organization/jump-capital', 15),
#  ('/organization/caa-ventures', 15),
#  ('/organization/omers-ventures', 15),
#  ('/organization/horizon-technology-finance', 15),
#  ('/organization/caixa-capital', 15),
#  ('/organization/vaizra-investments', 15),
#  ('/organization/yj-capital', 15),
#  ('/organization/m7-tech-partners-llc', 15),
#  ('/organization/upwest-labs', 15),
#  ('/organization/fg-angels', 15),
#  ('/organization/new-schools-venture-fund', 15),
#  ('/organization/archangel', 14),
#  ('/organization/dolby-family-ventures', 14),
#  ('/organization/deerfield-management', 14),
#  ('/organization/meritech-capital-partners', 14),
#  ('/organization/bdc-capital-corporation', 14),
#  ('/organization/tumml', 14),
#  ('/organization/openview-venture-partners', 14),
#  ('/organization/mmc-ventures', 14),
#  ('/organization/vulcan-capital', 14),
#  ('/organization/pelion-venture-partners', 14),
#  ('/organization/jumpstart-ventures', 14),
#  ('/organization/jennison-associates', 14),
#  ('/organization/bluerun-ventures', 14),
#  ('/organization/the-brandery', 14),
#  ('/organization/paladin-capital-group', 14),
#  ('/organization/valor-capital', 14),
#  ('/person/joanne-wilson', 14),
#  ('/organization/accelerate-it-ventures', 14),
#  ('/organization/carthona-capital', 14),
#  ('/organization/seventure-partners', 14),
#  ('/organization/oca-ventures', 14),
#  ('/organization/zhenfund', 14),
#  ('/organization/health-wildcatters', 14),
#  ('/organization/flashstarts', 14),
#  ('/organization/camp-one-ventures', 14),
#  ('/organization/corazon-capital', 14),
#  ('/organization/founder-org', 14),
#  ('/organization/deerfield', 14),
#  ('/organization/rincon-venture-partners', 14),
#  ('/organization/draper-esprit', 14),
#  ('/organization/harmony-partners', 14),
#  ('/organization/cabiedes-partners', 14),
#  ('/organization/corigin-ventures-2', 14),
#  ('/organization/sierra-ventures', 14),
#  ('/organization/recruit-strategic-partners', 14),
#  ('/organization/baird-capital', 14),
#  ('/person/dave-mcclure', 14),
#  ('/organization/google-capital', 14),
#  ('/organization/kickstart-seed-fund', 14),
#  ('/organization/launchcapital', 14),
#  ('/organization/bill-melinda-gates-foundation', 14),
#  ('/organization/mangrove-capital-partners', 14),
#  ('/organization/allos-ventures', 13),
#  ('/organization/voyager-capital', 13),
#  ('/organization/almaz-capital', 13),
#  ('/organization/piton-capital', 13),
#  ('/organization/ceyuan-ventures', 13),
#  ('/organization/translink-capital', 13),
#  ('/organization/knight-foundation', 13),
#  ('/person/yuri-milner', 13),
#  ('/organization/auriga-partners', 13),
#  ('/organization/new-leaf-venture-partners', 13),
#  ('/person/sam-altman', 13),
#  ('/organization/k5launch', 13),
#  ('/organization/foresite-capital', 13),
#  ('/organization/tech-coast-angels', 13),
#  ('/organization/blueprint-health-accelerator', 13),
#  ('/organization/orix-ventures', 13),
#  ('/organization/global-founders-capital', 13),
#  ('/organization/karlin-ventures', 13),
#  ('/organization/betaworks', 13),
#  ('/organization/soma-capital', 13),
#  ('/organization/high-peaks-venture-partners', 13),
#  ('/organization/alta-ventures-mexico', 13),
#  ('/person/naval-ravikant', 13),
#  ('/organization/general-atlantic', 13),
#  ('/organization/muckercapital', 13),
#  ('/organization/bullpen-capital', 13),
#  ('/organization/turn8-seed-accelerator', 13),
#  ('/organization/smbc-venture-capital', 13),
#  ('/organization/recruit-holdings', 13),
#  ('/organization/black-sheep-capital', 13),
#  ('/organization/capital-innovators', 13),
#  ('/organization/matrix-partners-india', 13),
#  ('/organization/susa-ventures', 13),
#  ('/organization/360-capital-partners', 13),
#  ('/organization/hatteras-venture-partners', 13),
#  ('/organization/sk-ventures', 13),
#  ('/organization/legend-capital', 13),
#  ('/organization/jungle-ventures', 13),
#  ('/organization/lighter-capital', 13),
#  ('/organization/incubate-fund', 13),
#  ('/organization/ia-ventures', 13),
#  ('/organization/gener8tor', 13),
#  ('/organization/chattanooga-renaissance-fund', 13),
#  ('/organization/coolidge-corner-investment', 13),
#  ('/organization/freestyle-capital', 13),
#  ('/organization/dena', 13),
#  ('/organization/novo-a-s', 13),
#  ('/organization/boomtown-accelerator-4', 13),
#  ('/organization/ventech-capital', 13),
#  ('/organization/india-quotient', 13),
#  ('/organization/neon-adventures', 12),
#  ('/organization/bam-ventures', 12),
#  ('/organization/gmo-venturepartners', 12),
#  ('/organization/seed-capital', 12),
#  ('/organization/kibo-ventures', 12),
#  ('/organization/mars-investment-accelerator-fund', 12),
#  ('/organization/sv-life-sciences', 12),
#  ('/organization/xg-ventures', 12),
#  ('/organization/riverpark-ventures', 12),
#  ('/organization/ludlow-ventures-llc', 12),
#  ('/organization/sg-vc', 12),
#  ('/organization/perceptive-advisors', 12),
#  ('/organization/boston-seed-capital', 12),
#  ('/organization/venture51', 12),
#  ('/organization/blackrock', 12),
#  ('/organization/pantera-capital', 12),
#  ('/organization/bitcoin-opportunity-fund', 12),
#  ('/organization/scrum-ventures', 12),
#  ('/organization/nextview-ventures', 12),
#  ('/organization/china-growth-capital', 12),
#  ('/organization/neulogy-ventures', 12),
#  ('/organization/new-york-angels', 12),
#  ('/organization/preangel', 12),
#  ('/organization/roche-venture-fund', 12),
#  ('/organization/maxfield-capital', 12),
#  ('/organization/access-industries', 12),
#  ('/organization/coatue-management', 12),
#  ('/organization/raine-ventures', 12),
#  ('/organization/relay-ventures', 12),
#  ('/organization/merck-global-health-innovation-fund', 12),
#  ('/organization/rembrant-venture-partners', 12),
#  ('/organization/granite-ventures', 12),
#  ('/organization/kddi', 12),
#  ('/organization/deep-fork-capital-2', 12),
#  ('/organization/strong-ventures', 12),
#  ('/person/dave-morin', 12),
#  ('/organization/reaktor-polte', 12),
#  ('/organization/mithril-capital-management', 12),
#  ('/organization/sixthirty-fintech-accelerator', 12),
#  ('/organization/learncapital', 12),
#  ('/organization/wefunder', 12),
#  ('/person/gary-vaynerchuk', 12),
#  ('/organization/vertex-venture-capital', 12),
#  ('/organization/adage-capital-management', 12),
#  ('/organization/trident-capital', 12),
#  ('/organization/b-dash-ventures', 12),
#  ('/organization/iconventures', 12),
#  ('/organization/osage-university-partners', 12),
#  ('/organization/social-leverage', 12),
#  ('/organization/asset-management-ventures', 12),
#  ('/organization/mavern-ventures', 12),
#  ('/organization/funding-tree-2', 12),
#  ('/organization/astia-angels', 12),
#  ('/organization/draper-nexus-ventures', 12),
#  ('/organization/inventus-capital-partners', 12),
#  ('/organization/webb-investment-network', 12),
#  ('/organization/startupyard', 12),
#  ('/organization/summit-partners', 12),
#  ('/organization/redalpine-venture-partners', 12),
#  ('/organization/singtel-innov8', 12),
#  ('/organization/green-visor-capital', 12),
#  ('/organization/oxford-capital-partners', 11),
#  ('/organization/hyde-park-angels', 11),
#  ('/organization/ecor1-capital', 11),
#  ('/person/steve-case', 11),
#  ('/organization/sofinnova-partners', 11),
#  ('/organization/invest-nebraska', 11),
#  ('/organization/lightspeed-china-partners', 11),
#  ('/organization/vectr', 11),
#  ('/organization/kaplan-edtech-accelerator', 11),
#  ('/organization/mach37', 11),
#  ('/organization/vertex-venture-holdings', 11),
#  ('/organization/kae-capital', 11),
#  ('/organization/manatt-venture-fund', 11),
#  ('/organization/amazon', 11),
#  ('/organization/project-a-ventures', 11),
#  ('/organization/hummer-winblad-venture-partners', 11),
#  ('/organization/14w', 11),
#  ('/organization/vast-ventures', 11),
#  ('/organization/amadeus-capital-partners', 11),
#  ('/organization/newspring-capital', 11),
#  ('/organization/javelin-venture-partners', 11),
#  ('/organization/acceleprise-ventures', 11),
#  ('/organization/launchub', 11),
#  ('/organization/playfair-capital', 11),
#  ('/organization/rally-ventures', 11),
#  ('/organization/third-point-ventures', 11),
#  ('/organization/wicklow-capital', 11),
#  ('/person/david-tisch', 11),
#  ('/organization/velos-partners', 11),
#  ('/organization/valar-ventures', 11),
#  ('/organization/austin-ventures', 11),
#  ('/organization/rockport-capital-partners', 11),
#  ('/organization/triplepoint-capital', 11),
#  ('/organization/third-rock-ventures', 11),
#  ('/organization/digital-sky-technologies-fo', 11),
#  ('/organization/gsv-capital', 11),
#  ('/organization/kgc-capital', 11),
#  ('/organization/daher-capital', 11),
#  ('/organization/contour-ventures', 11),
#  ('/organization/angel-cofund', 11),
#  ('/organization/flagship-ventures', 11),
#  ('/organization/fidelity-management-research', 11),
#  ('/person/ellen-levy', 11),
#  ('/organization/anthemis-group', 11),
#  ('/organization/mountain-group-capital', 11),
#  ('/organization/frost-data-capital', 11),
#  ('/person/jason-calacanis', 11),
#  ('/organization/march-capital-partners', 11),
#  ('/organization/senahill-partners', 11),
#  ('/organization/mumbai-angels', 11),
#  ('/organization/obvious-ventures', 11),
#  ('/organization/basset-investment-group', 11),
#  ('/organization/innova-memphis', 11),
#  ('/organization/lifeline-ventures', 11),
#  ('/person/richard-branson', 11),
#  ('/organization/zpark-venture', 11),
#  ('/organization/aspiration-growth', 11),
#  ('/organization/cambia-health-solutions', 11),
#  ('/organization/tmt-investments', 11),
#  ('/organization/dingman-center-angels', 11),
#  ('/organization/cherry-ventures', 11),
#  ('/organization/iangels', 11),
#  ('/organization/golden-gate-ventures', 11),
#  ('/organization/riverwood-capital', 11),
#  ('/organization/greenspring-associates', 11),
#  ('/person/david-cohen', 11),
#  ('/organization/base-vc', 11),
#  ('/organization/mitsubishi-ufj-capital', 11),
#  ('/organization/founders-co-op', 11),
#  ('/organization/monroe-capital', 11),
#  ('/organization/initial-capital', 11),
#  ('/person/scott-belsky', 11),
#  ('/person/ben-narasin', 11),
#  ('/organization/renren-inc', 11),
#  ('/organization/cincytech', 11),
#  ('/organization/golden-venture-partners', 11),
#  ('/organization/subtraction-capital', 11),
#  ('/organization/episode', 11),
#  ('/organization/red-swan', 11),
#  ('/organization/launch-angels', 11),
#  ('/organization/silicon-badia', 11),
#  ('/person/justin-kan', 11),
#  ('/organization/citi-ventures', 11),
#  ('/organization/times-internet', 10),
#  ('/organization/woodford-investment-management', 10),
#  ('/organization/tengelmann-ventures', 10),
#  ('/organization/mizuho-capital', 10),
#  ('/organization/mousse-partners', 10),
#  ('/organization/simon-venture-group', 10),
#  ('/organization/innovacorp', 10),
#  ('/person/kunal-bahl', 10),
#  ('/organization/ocean-2', 10),
#  ('/organization/lakewest-venture-partners', 10),
#  ('/organization/life-sciences-partners', 10),
#  ('/organization/morningside-private-investors', 10),
#  ('/organization/forward-partners', 10),
#  ('/organization/h-farm', 10),
#  ('/organization/dcm-ventures', 10),
#  ('/person/xavier-niel', 10),
#  ('/organization/carlyle-group', 10),
#  ('/organization/braemar-energy-ventures', 10),
#  ('/organization/structure-llc', 10),
#  ('/organization/rubicon-venture-capital', 10),
#  ('/organization/service-provider-capital', 10),
#  ('/organization/glynn-capital-management', 10),
#  ('/organization/aisling-capital', 10),
#  ('/organization/united-talent-agency', 10),
#  ('/person/jaan-tallinn', 10),
#  ('/person/aaron-levie', 10),
#  ('/organization/ibb', 10),
#  ('/organization/letsventure', 10),
#  ('/organization/launch-tennessee', 10),
#  ('/organization/ardent-capital', 10),
#  ('/organization/liveoak-venture-partners', 10),
#  ('/organization/xlr8uh', 10),
#  ('/organization/coolhouse-labs', 10),
#  ('/organization/frontline-ventures', 10),
#  ('/organization/the-iron-yard', 10),
#  ('/organization/confluence-capital', 10),
#  ('/organization/white-star-capital', 10),
#  ('/organization/cross-creek-capital', 10),
#  ('/organization/in-q-tel', 10),
#  ('/organization/dfj-growth', 10),
#  ('/organization/romulus-capital', 10),
#  ('/organization/gobi-partners', 10),
#  ('/organization/launchpad-venture-group', 10),
#  ('/organization/fontinalis-partners', 10),
#  ('/person/deborah-quazzo', 10),
#  ('/organization/female-founders-fund', 10),
#  ('/organization/initialized-capital', 10),
#  ('/organization/comerica-bank', 10),
#  ('/organization/morado-ventures-partners', 10),
#  ('/organization/artis', 10),
#  ('/organization/revolution', 10),
#  ('/organization/sparklabs-accelerator', 10),
#  ('/organization/allegis-capital', 10),
#  ('/organization/usaa', 10),
#  ('/organization/travel-startups-incubator', 10),
#  ('/organization/verve-capital-partners', 10),
#  ('/organization/sand-hill-angels', 10),
#  ('/organization/mpm-capital', 10),
#  ('/organization/brabantse-ontwikkelings-maatschappij-bom', 10),
#  ('/organization/lakestar', 10),
#  ('/organization/firestartr-co', 10),
#  ('/organization/ip-group-plc', 10),
#  ('/organization/target-partners', 10),
#  ('/organization/omega-funds', 10),
#  ('/organization/orios-venture-partners', 10),
#  ('/organization/dawn-capital', 10),
#  ('/organization/universal-music-group', 10),
#  ('/organization/novo-ventures', 10),
#  ('/organization/aib-seed-capital-fund', 10),
#  ('/organization/sprint-accelerator', 10),
#  ('/organization/645-angels', 10),
#  ('/organization/lumira-capital', 10),
#  ('/organization/collider', 10),
#  ('/organization/sigma-prime-ventures', 10),
#  ('/organization/questmark', 10),
#  ('/organization/5am-ventures', 10),
#  ('/organization/morgenthaler-ventures', 10),
#  ('/organization/runa-capital', 10),
#  ('/organization/the-startup-factory', 10),
#  ('/organization/nyca', 10),
#  ('/organization/triangle-peak-partners', 10),
#  ('/organization/monashees-capital', 10),
#  ('/organization/cormorant-asset-management', 10),
#  ('/organization/morgan-stanley', 10),
#  ('/person/jared-leto', 10),
#  ('/organization/cisco-investments', 10),
#  ('/organization/new-gen-partners', 10),
#  ('/organization/william-morris-endeavor', 10),
#  ('/organization/fundersguild', 10),
#  ('/organization/indicator-ventures', 9),
#  ('/organization/access-venture-partners', 9),
#  ('/organization/axon-partners-group', 9),
#  ('/organization/arthur-ventures-llc', 9),
#  ('/organization/tristar-technology-ventures', 9),
#  ('/organization/geekdom-fund-l-p', 9),
#  ('/organization/center-electric', 9),
#  ('/organization/investment-ab-kinnevik', 9),
#  ('/person/philippe-suchet', 9),
#  ('/organization/sigma-west', 9),
#  ('/organization/new-atlantic-ventures', 9),
#  ('/person/auren-hoffman', 9),
#  ('/organization/xseed-capital', 9),
#  ('/organization/frazier-healthcare-ventures', 9),
#  ('/organization/india-internet-fund', 9),
#  ('/organization/blackstone-group', 9),
#  ('/person/rohit-bansal', 9),
#  ('/organization/buckhead-investment-partners', 9),
#  ('/organization/wonder-ventures', 9),
#  ('/organization/telstra-ventures', 9),
#  ('/organization/luminari-capital', 9),
#  ('/organization/gsr-ventures-management', 9),
#  ('/person/owen-van-natta', 9),
#  ('/organization/montage-ventures', 9),
#  ('/person/tom-glocer', 9),
#  ('/organization/mb-venture-partners', 9),
#  ('/organization/noro-moseley-partners', 9),
#  ('/organization/biogenerator', 9),
#  ('/organization/sand-hill-east', 9),
#  ('/organization/xiaomi', 9),
#  ('/organization/reach', 9),
#  ('/organization/signia-venture-partners', 9),
#  ('/organization/bowery-capital', 9),
#  ('/organization/aspect-ventures', 9),
#  ('/organization/idealab', 9),
#  ('/organization/highland-capital-partners-europe', 9),
#  ('/organization/qed-investors', 9),
#  ('/organization/bayern-kapital', 9),
#  ('/organization/georgian-partners', 9),
#  ('/organization/cnf-investments', 9),
#  ('/organization/prosiebensat1-accelerator', 9),
#  ('/organization/llr-partners', 9),
#  ('/organization/karlani-capital', 9),
#  ('/organization/quotidian-ventures', 9),
#  ('/organization/origin-ventures', 9),
#  ('/organization/start-co', 9),
#  ('/organization/banyan-capital-partners', 9),
#  ('/organization/lunch-van-fund', 9),
#  ('/organization/victory-park-capital', 9),
#  ('/organization/viola-credit', 9),
#  ('/organization/split-rock-partners', 9),
#  ('/person/dharmesh-shah', 9),
#  ('/organization/idea-fund-partners', 9),
#  ('/organization/launch-fund', 9),
#  ('/organization/sands-capital-ventures', 9),
#  ('/organization/capricorn-investment-group', 9),
#  ('/organization/jd-com', 9),
#  ('/organization/indian-angel-network', 9),
#  ('/organization/elevate-ventures', 9),
#  ('/organization/robin-hood-ventures', 9),
#  ('/organization/bozano-investimentos-2', 9),
#  ('/organization/atlantic-bridge', 9),
#  ('/organization/london-venture-partners', 9),
#  ('/organization/almi-invest', 9),
#  ('/organization/presidio-ventures', 9),
#  ('/organization/la-dodgers-sports---entertainment-accelerator-with-r-ga-2',
#   9),
#  ('/organization/hearst-ventures', 9),
#  ('/person/raymond-tonsing', 9),
#  ('/organization/lumia-capital', 9),
#  ('/organization/hoxton-ventures', 9),
#  ('/organization/demarest', 9),
#  ('/organization/river-cities-capital', 9),
#  ('/organization/lilly-ventures', 9),
#  ('/organization/foxconn-technology-group', 9),
#  ('/organization/visionnaire-ventures', 9),
#  ('/organization/velum-ventures', 9),
#  ('/organization/northern-light-venture-capital', 9),
#  ('/organization/rebright-partners', 9),
#  ('/organization/brand-foundry-ventures', 9),
#  ('/organization/gemini-israel-funds', 9),
#  ('/organization/carma-axlr8r', 9),
#  ('/organization/open-ocean', 9),
#  ('/organization/export-development-canada', 9),
#  ('/organization/elab-accelerator', 9),
#  ('/organization/time-warner-investments', 9),
#  ('/organization/columbia-capital', 9),
#  ('/organization/united-ventures', 9),
#  ('/organization/connect-ventures', 9),
#  ('/organization/tribeca-venture-partners', 9),
#  ('/person/eduardo-saverin', 9),
#  ('/organization/premjiinvest', 9),
#  ('/organization/nazca-ventures-3', 9),
#  ('/organization/felix-capital', 8),
#  ('/organization/liberty-city-ventures', 8),
#  ('/organization/sig', 8),
#  ('/organization/baroda-ventures', 8),
#  ('/organization/north-coast-angel-fund', 8),
#  ('/organization/northstar-ventures', 8),
#  ('/organization/the-westly-group', 8),
#  ('/organization/2b-angels', 8),
#  ('/person/ilya-sukhar', 8),
#  ('/organization/capnamic-ventures', 8),
#  ('/organization/bolt-io', 8),
#  ('/organization/miramar-venture-partners', 8),
#  ('/person/andy-dunn', 8),
#  ('/person/eric-ries', 8),
#  ('/organization/fca-venture-partners', 8),
#  ('/organization/alphalab', 8),
#  ('/organization/north-west-fund', 8),
#  ('/person/ryan-holmes', 8),
#  ('/organization/claremont-creek-ventures', 8),
#  ('/organization/airtree-ventures-2', 8),
#  ('/organization/capital-factory', 8),
#  ('/organization/blu-venture-investors', 8),
#  ('/organization/9mile-labs', 8),
#  ('/organization/onset-ventures', 8),
#  ('/organization/national-capital-fund', 8),
#  ('/organization/dragoneer-investment-group', 8),
#  ('/organization/johnson-johnson-development-corporation', 8),
#  ('/organization/arnold-capital', 8),
#  ('/organization/mergelane', 8),
#  ('/organization/militello-capital', 8),
#  ('/organization/unitus-seed-fund', 8),
#  ('/organization/vostok-nafta-investment', 8),
#  ('/organization/venrex-investment-management', 8),
#  ('/organization/bezos-expeditions', 8),
#  ('/organization/angellab', 8),
#  ('/organization/openfund', 8),
#  ('/organization/sbt-venture-capital', 8),
#  ('/organization/sanomaventures', 8),
#  ('/organization/inveready-technology-investment-group', 8),
#  ('/organization/excel-venture-management', 8),
#  ('/organization/business-development-bank-of-canada', 8),
#  ('/organization/e-bricks-ventures', 8),
#  ('/organization/jafco-asia', 8),
#  ('/organization/blackbird-ventures-australia', 8),
#  ('/organization/techammer', 8),
#  ('/organization/spectrum-equity-investors', 8),
#  ('/organization/active-venture-partners', 8),
#  ('/organization/west-techventures', 8),
#  ('/organization/new-ground-ventures', 8),
#  ('/organization/itochu-technology-ventures', 8),
#  ('/person/william-guttman', 8),
#  ('/organization/core-capital-partners', 8),
#  ('/organization/sigma-partners', 8),
#  ('/organization/altimeter-capital', 8),
#  ('/person/michael-lazerow', 8),
#  ('/organization/city-national-bank', 8),
#  ('/organization/cherrystone-angel-group', 8),
#  ('/organization/huron-river-ventures', 8),
#  ('/organization/longitude-capital', 8),
#  ('/organization/sound-ventures', 8),
#  ('/organization/ntt-docomo-ventures', 8),
#  ('/organization/mhs-capital', 8),
#  ('/person/bill-gates', 8),
#  ('/organization/atomico', 8),
#  ('/organization/entree-capital', 8),
#  ('/person/david-sacks', 8),
#  ('/organization/ucla-venture-capital-fund', 8),
#  ('/person/binny-bansal', 8),
#  ('/organization/columbus-nova-technology-partners', 8),
#  ('/organization/globespan-capital-partners', 8),
#  ('/organization/blue-chip-venture-company', 8),
#  ('/organization/shunwei-china-internet-fund', 8),
#  ('/organization/prototron', 8),
#  ('/organization/high-line-venture-partners', 8),
#  ('/organization/brooklyn-bridge-ventures', 8),
#  ('/organization/elaia-partners', 8),
#  ('/organization/genesis-partners', 8),
#  ('/organization/accel-kkr', 8),
#  ('/organization/catterton-partners', 8),
#  ('/organization/mercia-fund-management', 8),
#  ('/person/mark-pincus', 8),
#  ('/organization/burch-creative-capital', 8),
#  ('/organization/the-martin-companies', 8),
#  ('/person/haroon-mokhtarzada', 8),
#  ('/organization/susquehanna-growth-equity', 8),
#  ('/organization/company-k-partners', 8),
#  ('/organization/tandem-capital-2', 8),
#  ('/organization/rho-ventures', 8),
#  ('/person/nicolas-berggruen', 8),
#  ('/organization/venbio', 8),
#  ('/organization/ally-bridge-group', 8),
#  ('/organization/blue-cloud-ventures', 8),
#  ('/organization/ge-capital', 8),
#  ('/organization/serena-capital', 8),
#  ('/organization/shenzhen-capital-group', 8),
#  ('/organization/sparkbox-ventures', 8),
#  ('/organization/gic', 8),
#  ('/organization/north-east-venture', 8),
#  ('/organization/atlantic-capital-partners', 8),
#  ('/organization/illuminate-ventures', 8),
#  ('/organization/cottonwood-technology-fund', 8),
#  ('/organization/firsttime-venture-capital', 8),
#  ('/organization/birchmere-ventures', 8),
#  ('/organization/national-science-foundation', 8),
#  ('/organization/drive-capital', 8),
#  ('/person/rajesh-sawhney', 8),
#  ('/organization/great-hill-partners', 8),
#  ('/organization/s3-ventures', 8),
#  ('/organization/oregon-angel-fund', 8),
#  ('/organization/sjf-ventures', 8),
#  ('/organization/cbc-capital', 8),
#  ('/organization/ec1-capital-ltd', 8),
#  ('/organization/business-booster', 8),
#  ('/organization/brookside-capital', 8),
#  ('/organization/pv-ventures', 8),
#  ('/organization/trilogy-equity-partnership', 8),
#  ('/organization/entrepreneurs-fund', 8),
#  ('/organization/stripes-group', 8),
#  ('/organization/starvest-partners', 8),
#  ('/person/raj-sandhu', 8),
#  ('/organization/ivycap-ventures', 7),
#  ('/organization/lean-fund', 7),
#  ('/organization/angelhub-ventures', 7),
#  ('/organization/delta-partners', 7),
#  ('/organization/osage-ventures', 7),
#  ('/organization/enertech-capital', 7),
#  ('/organization/altpoint-ventures', 7),
#  ('/organization/plymouth-venture-partners', 7),
#  ('/organization/rising-tide-fund', 7),
#  ('/organization/dunnhumby-ventures', 7),
#  ('/organization/francisco-partners', 7),
#  ('/person/rudy-gadre', 7),
#  ('/organization/usc-viterbi', 7),
#  ('/organization/wellcome-trust', 7),
#  ('/organization/artiman-ventures', 7),
#  ('/organization/italian-angels-for-growth', 7),
#  ('/organization/windham-venture-partners', 7),
#  ('/organization/rhodium', 7),
#  ('/organization/cultivian-sandbox-ventures', 7),
#  ('/organization/middle-bridge-partners', 7),
#  ('/organization/chrysalix-energy', 7),
#  ('/organization/midven', 7),
#  ('/organization/ut-horizon-fund', 7),
#  ('/organization/rethink-education', 7),
#  ('/organization/eqt-holdings', 7),
#  ('/organization/tim-ventures', 7),
#  ('/organization/civeta-investments', 7),
#  ('/organization/signal-peak-ventures', 7),
#  ('/organization/elmspring', 7),
#  ('/organization/deutsche-bank', 7),
#  ('/organization/devonshire-investors', 7),
#  ('/person/tim-ferriss', 7),
#  ('/organization/thayer-ventures', 7),
#  ('/organization/syndicateroom', 7),
#  ('/organization/scottish-equity-partners', 7),
#  ('/person/charlie-songhurst', 7),
#  ('/organization/edmond-de-rothschild-venture-capital', 7),
#  ('/organization/orbimed-2', 7),
#  ('/organization/fidelity-growth-partners-india', 7),
#  ('/organization/peninsula-equity-partners', 7),
#  ('/organization/imj-fenox-pte-ltd', 7),
#  ('/organization/pointguard-ventures', 7),
#  ('/organization/carrick-capital-partners', 7),
#  ('/organization/partner-fund-management-pfm', 7),
#  ('/organization/k9-ventures', 7),
#  ('/organization/arsenal-venture-partners', 7),
#  ('/person/tikhon-bernstam', 7),
#  ('/organization/3ts-capital-partners', 7),
#  ('/organization/ta-associates', 7),
#  ('/organization/shea-ventures', 7),
#  ('/organization/rand-capital', 7),
#  ('/organization/dundee-venture-capital', 7),
#  ('/organization/mobile-internet-capital', 7),
#  ('/person/kal-vepuri', 7),
#  ('/organization/draper-triangle-ventures', 7),
#  ('/organization/highlinevc', 7),
#  ('/organization/jerusalem-venture-partners', 7),
#  ('/organization/day-one-capital', 7),
#  ('/organization/top-tier-capital-partners', 7),
#  ('/organization/advanced-technology-ventures', 7),
#  ('/organization/advantage-capital-partners', 7),
#  ('/organization/t-venture', 7),
#  ('/organization/the-hive', 7),
#  ('/organization/industrifonden', 7),
#  ('/organization/next-world-capital', 7),
#  ('/organization/easton-capital', 7),
#  ('/organization/yaletown-venture-partners', 7),
#  ('/organization/bridge-bank', 7),
#  ('/person/esther-dyson', 7),
#  ('/organization/bertelsmann-asia-investment-fund', 7),
#  ('/organization/growx-venture-management', 7),
#  ('/organization/urban-us', 7),
#  ('/organization/bertelsmann', 7),
#  ('/organization/thetime', 7),
#  ('/organization/k2-ventures', 7),
#  ('/organization/american-express-ventures', 7),
#  ('/person/barry-silbert', 7),
#  ('/organization/ftv-capital', 7),
#  ('/organization/harbert-venture-partners', 7),
#  ...]

# %%
# for investor in new_edges.keys():
#     for company in sorted_degree_list[0:m[investor]]:    
#         if company[0] in new_edges[investor]:
#             print m[investor], investor, company[0]

# %%
a = 0
total_m = 0
for company in new_edges_s.keys():
    total_m += m[company]
    for investor in sorted_investor_degree_list[0:m[company]]:
        if investor[0] in new_edges_s[company]:
            #print m[company], company, investor[0]
            a += 1
a
# Out:
# 678

# %%
new_edges_s
# Out:
# {'/organization/intendime': {'/organization/telecom-italia'},
#  '/organization/loop-commerce': {'/organization/paypal',
#   '/organization/wicklow-capital',
#   '/person/andrew-fine',
#   '/person/chuck-geiger',
#   '/person/dan-rose',
#   '/person/dovi-frances',
#   '/person/ken-seiff',
#   '/person/mark-carges',
#   '/person/michael-scharff',
#   '/person/mohan-gyani',
#   '/person/oren-zeev',
#   '/person/roy-rubin',
#   '/person/silas-chou'},
#  '/organization/drizly': {'/organization/continental-investors',
#   '/organization/fairhaven-capital-partners-2',
#   '/organization/first-beverage-group',
#   '/organization/polaris-partners',
#   '/organization/suffolk-equity-partners',
#   '/organization/vayner-rse'},
#  '/organization/cyrus-biotechnology': {'/organization/the-w-fund',
#   '/organization/wings'},
#  '/organization/iron-io': {'/organization/bain-capital-ventures',
#   '/organization/baseline-ventures',
#   '/organization/divergent-ventures'},
#  '/organization/sinbads-supply-chain': {'/organization/kleiner-perkins-caufield-byers'},
#  '/organization/akippa': {'/organization/dena'},
#  '/organization/qzzr': {'/organization/kickstart-seed-fund',
#   '/organization/pelion-venture-partners',
#   '/organization/peterson-ventures',
#   '/organization/rpm-ventures'},
#  '/organization/framer': {'/organization/foundation-capital',
#   '/organization/greylock'},
#  '/organization/medlanes': {'/organization/german-startups-group',
#   '/organization/rheingau-founders'},
#  '/organization/solar-tower-technologies': {'/organization/german-startups-group'},
#  '/organization/smart-vision-labs': {'/organization/bullet-time-ventures',
#   '/organization/connectivity-capital',
#   '/organization/heritage-group',
#   '/organization/red-sea-venture-partners'},
#  '/organization/tongbanjie': {'/organization/china-growth-capital',
#   '/organization/idg-capital-partners',
#   '/organization/legend-capital'},
#  '/organization/peachme': {'/organization/boomtown-accelerator-4'},
#  '/organization/eatlo': {'/organization/globevestor',
#   '/organization/powai-lake-ventures',
#   '/person/abhishek-goyal'},
#  '/organization/booker-software': {'/organization/first-data-corporation',
#   '/organization/jump-capital',
#   '/organization/medina-capital',
#   '/organization/signal-peak-ventures'},
#  '/organization/form-devices': {'/organization/haxlr8r'},
#  '/organization/qdiscovery': {'/organization/bridge-investments',
#   '/organization/starboard-capital-partners-2'},
#  '/organization/basharsoft': {'/organization/500-startups',
#   '/organization/endure-capital',
#   '/organization/piton-capital',
#   '/organization/vostok-nafta-investment'},
#  '/organization/telefactor-robotics-com': {'/organization/ben-franklin-technology-partners-of-southeastern-pennsylvania'},
#  '/organization/satvacart': {'/organization/palaash-ventures'},
#  '/organization/cape-wind': {'/organization/bank-of-tokyo-mitsubishi-ufj',
#   '/organization/natixis',
#   '/organization/rabobank'},
#  '/organization/avuba': {'/organization/neon-adventures',
#   '/person/teodoro-dambrosio'},
#  '/organization/blackwood-seven': {'/organization/conor-venture-partners',
#   '/organization/sunstone-capital',
#   '/organization/vf-venture'},
#  '/organization/the-vr-company': {'/organization/elementum-ventures',
#   '/organization/rothenberg-ventures'},
#  '/organization/arthesis-covers': {'/organization/eleven'},
#  '/organization/rant-media-network-llc': {'/organization/gannett',
#   '/organization/hudson-bay-capital-management',
#   '/organization/roth-capital-partners',
#   '/organization/southpaw-asset-management',
#   '/person/barry-honig',
#   '/person/craig-a-dubow'},
#  '/organization/prevoty': {'/organization/us-venture-partners',
#   '/person/michael-pierce-8'},
#  '/organization/healthexpense-inc-': {'/organization/brush-street-fund',
#   '/organization/jump-capital',
#   '/organization/spring-bay-ventures',
#   '/person/dan-ross-3',
#   '/person/jerry-wigdortz',
#   '/person/mike-quilty'},
#  '/organization/brainquake': {'/organization/co-lab-2'},
#  '/organization/vetpronto': {'/organization/y-combinator'},
#  '/organization/etaskr': {'/organization/oxygen-ventures'},
#  '/organization/transenterix': {'/organization/oxford-finance-corporation',
#   '/organization/silicon-valley-bank'},
#  '/organization/gigwalk': {'/organization/august-capital',
#   '/organization/harrison-metal',
#   '/organization/nokia-growth-partners',
#   '/organization/randstad-holding-nv',
#   '/organization/randstad-innovation-fund',
#   '/organization/softtech-vc'},
#  '/organization/sokrati': {'/organization/ivycap-ventures'},
#  '/organization/acesobee': {'/organization/cyberport-hong-kong'},
#  '/organization/enterprise-therapeutics': {'/organization/epidarex-capital',
#   '/organization/imperial-innovations'},
#  '/organization/farmnote': {'/organization/gree',
#   '/organization/kanematsu-agritech',
#   '/person/daiji-hirata',
#   '/person/kotaro-chiba'},
#  '/organization/oxie': {'/organization/sprint-accelerator'},
#  '/organization/nanogriptech': {'/organization/innovation-works'},
#  '/organization/i-meter': {'/organization/cyberport-hong-kong'},
#  '/organization/edcast-inc': {'/organization/aarin-capital',
#   '/organization/cervin-ventures',
#   '/organization/co-lab-2',
#   '/organization/kapor-capital',
#   '/organization/menlo-ventures',
#   '/organization/new-schools-venture-fund',
#   '/organization/novel-tmt-ventures',
#   '/organization/softbank-capital',
#   '/organization/startx'},
#  '/organization/digital-specialty-chemicals': {'/organization/intel-capital'},
#  '/organization/r-ve': {'/organization/almi-invest',
#   '/organization/optimizer-invest'},
#  '/organization/freewire-technologies': {'/organization/center-electric'},
#  '/organization/revel-systems': {'/organization/dreamfunded',
#   '/organization/invest-northern-ireland',
#   '/organization/roth-capital-partners',
#   '/organization/welsh-carson-anderson-stowe'},
#  '/organization/picbuy': {'/organization/haxlr8r'},
#  '/organization/kown': {'/organization/eleven'},
#  '/organization/jfrog-ltd': {'/organization/gemini-israel-funds',
#   '/organization/vmware'},
#  '/organization/bica-studios': {'/organization/portugal-ventures'},
#  '/organization/curevac': {'/organization/bill-melinda-gates-foundation'},
#  '/organization/gateway-interactive': {'/organization/microsoft-ventures'},
#  '/organization/partywithme': {'/organization/eleven'},
#  '/organization/cinarra-systems': {'/organization/almaz-capital',
#   '/organization/siguler-guff-company',
#   '/organization/softbank'},
#  '/organization/glucoiq': {'/organization/blueprint-health-accelerator'},
#  '/organization/scup': {'/organization/valor-capital'},
#  '/organization/tespack': {'/organization/startupbootcamp'},
#  '/organization/mulesoft': {'/organization/adage-capital-management',
#   '/organization/bay-partners',
#   '/organization/brookside-capital',
#   '/organization/capital-ventures',
#   '/organization/cisco',
#   '/organization/cisco-investments',
#   '/organization/hummer-winblad-venture-partners',
#   '/organization/lightspeed-venture-partners',
#   '/organization/meritech-capital-partners',
#   '/organization/morgenthaler-ventures',
#   '/organization/new-enterprise-associates',
#   '/organization/salesforce-ventures',
#   '/organization/sands-capital-ventures',
#   '/organization/sapphire-ventures'},
#  '/organization/soundcloud': {'/organization/german-startups-group'},
#  '/organization/tolero-pharmaceuticals': {'/organization/fred-alger-management'},
#  '/organization/opendns': {'/organization/cisco',
#   '/organization/evolution-equity-partners',
#   '/organization/glynn-capital-management',
#   '/organization/greylock',
#   '/organization/lowercase-capital',
#   '/organization/lumia-capital',
#   '/organization/mohr-davidow-ventures',
#   '/organization/northgate-capital',
#   '/organization/sequoia-capital',
#   '/organization/sutter-hill-ventures',
#   '/person/chris-sacca'},
#  '/organization/specless': {'/organization/techstars'},
#  '/organization/gatsby-2': {'/organization/elab-accelerator'},
#  '/organization/vida-3': {'/organization/beehive-holdings',
#   '/organization/google-ventures',
#   '/organization/slow-ventures',
#   '/organization/universal-music-group',
#   '/person/jesse-draper'},
#  '/organization/harvest-exchange': {'/organization/goldentree-asset-management-llc',
#   '/organization/highland-capital-management',
#   '/organization/marketplace-fund-i',
#   '/organization/third-point-ventures'},
#  '/organization/automatic-com': {'/organization/amicus-capital',
#   '/organization/anthemis-group',
#   '/organization/comcast-interactive-capital',
#   '/organization/dealer-services',
#   '/organization/lumia-capital',
#   '/organization/usaa',
#   '/organization/y-combinator',
#   '/person/gary-clayton',
#   '/person/jared-kopf',
#   '/person/mark-goines',
#   '/person/rob-chandhok'},
#  '/organization/happier-inc': {'/organization/resolute-vc',
#   '/organization/venrock'},
#  '/organization/milo-networks': {'/organization/axel-springer-plug-and-play-accelerator'},
#  '/organization/vytmn': {'/organization/first-ascent-associates',
#   '/person/aaron-schiff',
#   '/person/allen-debevoise-2',
#   '/person/carter-reum-la',
#   '/person/courtney-reum-la',
#   '/person/michael-smith-8',
#   '/person/miles-beckett',
#   '/person/scott-adelson',
#   '/person/todd-mackey'},
#  '/organization/endostim': {'/organization/prolog-ventures'},
#  '/organization/bridg-2': {'/organization/500-startups'},
#  '/organization/pull': {'/organization/er-accelerator'},
#  '/organization/onekreate': {'/organization/bertram-capital-management'},
#  '/organization/devilfish-poker-ltd': {'/organization/funding-tree-2'},
#  '/organization/supportpay': {'/organization/aspect-ventures',
#   '/organization/broadway-angels',
#   '/organization/draper-associates-2',
#   '/organization/rpm-ventures',
#   '/organization/salesforce-ventures',
#   '/organization/t5-capital',
#   '/organization/tec-ventures',
#   '/person/bob-bozeman'},
#  '/organization/theatro': {'/organization/khosla-ventures'},
#  '/organization/itineris': {'/organization/gimv',
#   '/organization/pmv-vinnof',
#   '/person/edgard-vermeersch'},
#  '/organization/mersana-therapeutics': {'/organization/fidelity-biosciences',
#   '/organization/new-enterprise-associates',
#   '/organization/pfizer-venture-investments',
#   '/organization/rock-springs-capital',
#   '/person/elliott-sigal'},
#  '/organization/stitch-2': {'/organization/500-startups',
#   '/organization/sierra-maya-ventures'},
#  '/organization/addresshealth': {'/organization/unitus-seed-fund'},
#  '/organization/next-issue-media': {'/organization/kkr'},
#  '/organization/video-blocks': {'/organization/north-atlantic-capital'},
#  '/organization/personal-capital': {'/organization/bbva-ventures',
#   '/organization/corsair-capital',
#   '/organization/crosslink-capital',
#   '/organization/institutional-venture-partners',
#   '/organization/jump-capital',
#   '/organization/usaa',
#   '/organization/venrock'},
#  '/organization/pedius': {'/organization/embed-capital',
#   '/organization/sistema-investimenti',
#   '/organization/tim-ventures'},
#  '/organization/sn-mobile-technology': {'/organization/capstone-partners-korea',
#   '/organization/jafco-asia'},
#  '/organization/magnomics': {'/organization/portugal-ventures'},
#  '/organization/ruiyi': {'/organization/5am-ventures',
#   '/organization/apposite-capital',
#   '/organization/aravis-ventures',
#   '/organization/merck-serono-ventures',
#   '/organization/ms-ventures',
#   '/organization/silicon-valley-bank',
#   '/organization/sr-one',
#   '/organization/versant-ventures'},
#  '/organization/electric-objects': {'/organization/betaworks',
#   '/organization/first-round-capital',
#   '/organization/red-sea-venture-partners',
#   '/organization/rre-ventures',
#   '/organization/sv-angel',
#   '/person/alberto-ibargen',
#   '/person/dennis-crowley',
#   '/person/kal-vepuri',
#   '/person/matthew-witheiler',
#   '/person/nate-westheimer',
#   '/person/rich-greenfield',
#   '/person/scott-belsky',
#   '/person/scott-birnbaum',
#   '/person/strauss-zelnick'},
#  '/organization/capture-educational-consulting-services': {'/organization/north-coast-angel-fund',
#   '/organization/ohio-techangels-fund',
#   '/organization/techcolumbus-2'},
#  '/organization/ekaya-com': {'/organization/88mph-ac',
#   '/person/bill-paladino',
#   '/person/daniel-guasco',
#   '/person/guilherme-steinbruch',
#   '/person/justin-stanford',
#   '/person/sebastian-stoddart',
#   '/person/vinny-lingham',
#   '/person/wayne-gosling'},
#  '/organization/cuelearn': {'/person/alok-mittal'},
#  '/organization/optica': {'/organization/cyberport-hong-kong'},
#  '/organization/tradingview': {'/organization/itech-capital'},
#  '/organization/smartsheet': {'/organization/insight-venture-partners',
#   '/organization/madrona-venture-group',
#   '/organization/sutter-hill-ventures',
#   '/organization/top-tier-capital-partners'},
#  '/organization/campaign-monitor': {'/organization/insight-venture-partners'},
#  '/organization/quieru-com': {'/organization/makingideasbusiness'},
#  '/organization/salespredict': {'/organization/kgc-capital',
#   '/organization/yandex'},
#  '/organization/orchestro': {'/organization/cnf-investments',
#   '/organization/new-markets-venture-partners',
#   '/organization/novak-biddle-venture-partners'},
#  '/organization/agilone': {'/organization/four-rivers-group',
#   '/organization/mayfield-fund',
#   '/organization/next-world-capital',
#   '/organization/sequoia-capital',
#   '/organization/tenaya-capital'},
#  '/organization/women-com': {'/organization/y-combinator'},
#  '/organization/upplication': {'/organization/wayra'},
#  '/organization/invision-2': {'/organization/accel-partners',
#   '/organization/firstmark-capital',
#   '/organization/tiger-global',
#   '/person/jason-finger'},
#  '/organization/context-relevant': {'/organization/bank-of-america-merrill-lynch',
#   '/organization/bloomberg-beta',
#   '/organization/formation8',
#   '/organization/goldman-sachs',
#   '/organization/madrona-venture-group',
#   '/organization/new-york-life-insurance-co',
#   '/organization/rolling-bay-ventures',
#   '/organization/vulcan-capital',
#   '/organization/work-bench'},
#  '/organization/vantage-sports': {'/organization/500-startups',
#   '/organization/blue-startups',
#   '/organization/m7-tech-partners-llc',
#   '/organization/queensbridge-venture-partners',
#   '/organization/social-starts'},
#  '/organization/ebrandvalue': {'/organization/y-combinator',
#   '/person/cuneyd-zapsu'},
#  '/organization/brickx---the-brick-exchange': {'/organization/bridgelane-capital'},
#  '/organization/metamaterial-technologies-inc-': {'/organization/cleantech-partners',
#   '/organization/innovacorp'},
#  '/organization/burning-glass-technologies': {'/organization/providence-equity-partners'},
#  '/organization/electric-imp': {'/organization/foxconn-technology-group',
#   '/organization/pti-ventures',
#   '/organization/rampart-capital-llp',
#   '/person/hugo-fiennes'},
#  '/organization/twindom': {'/organization/dreamfunded'},
#  '/organization/bswift': {'/organization/great-hill-partners'},
#  '/organization/aura-biosciences': {'/organization/advent-life-sciences',
#   '/organization/alexandria-venture',
#   '/organization/chiesi-ventures',
#   '/organization/ysios-capital',
#   '/person/henri-termeer'},
#  '/organization/yetang': {'/organization/dcm',
#   '/organization/idg-capital-partners'},
#  '/organization/farmers-business-network': {'/organization/dbl-investors',
#   '/organization/google-ventures',
#   '/organization/kleiner-perkins-caufield-byers'},
#  '/organization/manthan-systems': {'/organization/norwest-venture-partners'},
#  '/organization/acorns-grow': {'/organization/e-ventures',
#   '/organization/garland-capital-group',
#   '/organization/great-oaks-venture-capital',
#   '/organization/greycroft-partners',
#   '/organization/jacobs-asset-management',
#   '/organization/math-venture-partners',
#   '/organization/sound-ventures'},
#  '/organization/mesh-korea': {'/organization/eg-partners',
#   '/organization/kdb-capital',
#   '/organization/sbi-investment',
#   '/organization/seoul-investment-partners',
#   '/organization/shinhan-capital',
#   '/organization/solborn-investment'},
#  '/organization/hco-servi\xc3\x83\xc2\xa7os-log\xc3\x83\xc2\xadsticos-s-a': {'/organization/bozano-investimentos-2'},
#  '/organization/novelda-as': {'/organization/alliance-venture',
#   '/organization/investinor',
#   '/organization/sparebank-1-smn-invest'},
#  '/organization/rocketclub': {'/organization/cyberport-hong-kong'},
#  '/organization/bex-io': {'/organization/crypto-currency-partners'},
#  '/organization/carreira-beauty': {'/organization/redpoint-eventures'},
#  '/organization/social-code': {'/organization/sprint-accelerator'},
#  '/organization/esolidar': {'/organization/portugal-ventures'},
#  '/organization/clothing-sites': {'/organization/bridges-ventures'},
#  '/organization/nomacorc': {'/organization/triangle-capital-corporation'},
#  '/organization/moneymeets': {'/organization/dvh-ventures'},
#  '/organization/fem': {'/organization/disney-accelerator',
#   '/organization/javelin-venture-partners',
#   '/organization/mesa-ventures',
#   '/organization/techstars'},
#  '/organization/runnit': {'/organization/wayra'},
#  '/organization/avelas-biosciences': {'/organization/avalon-ventures',
#   '/organization/torrey-pines-investment',
#   '/organization/wuxi-pharmatech-cayman'},
#  '/organization/enso': {'/organization/eleven'},
#  '/organization/gigawatt': {'/organization/start-up-chile'},
#  '/organization/3ten8': {'/organization/alchemist-accelerator',
#   '/organization/citrix-startup-accelerator',
#   '/organization/karlin-ventures',
#   '/organization/launchpadla',
#   '/organization/undisclosed-venture-capital-fund',
#   '/person/christian-dahlen',
#   '/person/ken-arnold'},
#  '/organization/prothom-industries': {'/organization/oliphans-capital'},
#  '/organization/trendlee': {'/organization/ta-venture'},
#  '/organization/trucktrack': {'/organization/passion-capital'},
#  '/organization/marketenterprise-co--ltd-': {'/organization/yj-capital'},
#  '/organization/aegea-medical': {'/organization/alloy-ventures',
#   '/organization/biomed-ventures',
#   '/organization/covidien',
#   '/organization/delphi-ventures',
#   '/organization/medtronic',
#   '/organization/solas-bioventures'},
#  '/organization/justfabulous': {'/organization/kec-ventures',
#   '/organization/matrix-partners',
#   '/organization/passport-capital',
#   '/organization/shining-capital',
#   '/organization/technology-crossover-ventures',
#   '/organization/trinity-capital-investment'},
#  '/organization/ziffi': {'/organization/orios-venture-partners'},
#  '/organization/pani-networks': {'/person/bob-pasker'},
#  '/organization/surveysnap': {'/organization/dingman-center-angels'},
#  '/organization/twt-digital': {'/organization/e-bricks-ventures',
#   '/organization/valor-capital'},
#  '/organization/iwopi': {'/organization/sitka-capital'},
#  '/organization/simplus': {'/organization/epic-ventures',
#   '/organization/infinity-home-investments',
#   '/organization/prelude-ventures-llc',
#   '/organization/service-provider-capital',
#   '/organization/silicon-valley-bank',
#   '/person/eric-morgan-3',
#   '/person/godard-abel'},
#  '/organization/coin': {'/organization/k5launch',
#   '/organization/k9-ventures',
#   '/organization/redpoint-ventures',
#   '/organization/sherpa-ventures',
#   '/organization/softtech-vc',
#   '/organization/spark-capital',
#   '/organization/spark-nigeria'},
#  '/organization/hawhire': {'/organization/start-up-chile'},
#  '/organization/niffler': {'/organization/saif-partners'},
#  '/organization/networked-insights': {'/organization/4490-ventures',
#   '/organization/american-family-ventures',
#   '/organization/goldman-sachs'},
#  '/organization/dermira': {'/organization/aisling-capital',
#   '/organization/apple-tree-partners',
#   '/organization/bay-city-capital',
#   '/organization/canaan-partners',
#   '/organization/new-enterprise-associates',
#   '/organization/rock-springs-capital',
#   '/organization/sabby-capital',
#   '/organization/ucb-pharma'},
#  '/organization/adizio': {'/organization/encore-capital',
#   '/organization/kima-ventures',
#   '/organization/playfair-capital',
#   '/organization/sussex-place-ventures'},
#  '/organization/podaris': {'/organization/startupbootcamp'},
#  '/organization/nuubo': {'/organization/caixa-capital',
#   '/organization/caixa-innvierte-biomed-ii',
#   '/organization/crb-inverbo',
#   '/organization/fides-capital'},
#  '/organization/yo': {'/organization/betaworks',
#   '/organization/genesis-angels',
#   '/organization/slow-ventures',
#   '/person/ed-baker',
#   '/person/pete-cashmore',
#   '/person/vic-lee'},
#  '/organization/metricwire': {'/organization/y-combinator'},
#  '/organization/twist-biosciences': {'/organization/arch-venture-partners',
#   '/organization/asset-management-ventures',
#   '/organization/fidelity-management-research',
#   '/organization/foresite-capital',
#   '/organization/illumina',
#   '/organization/paladin-capital-group',
#   '/organization/silicon-valley-bank',
#   '/organization/tao-venture-partners',
#   '/organization/venture-investors',
#   '/person/joby-pritzker',
#   '/person/yuri-milner'},
#  '/organization/marcopolo-learning': {'/organization/seedcamp'},
#  '/organization/systran': {'/organization/softbank-ventures-korea'},
#  '/organization/reh': {'/organization/banks-foundation-for-young-entrepreneurs'},
#  '/organization/carsgen': {'/organization/bvcf'},
#  '/organization/crowdability': {'/organization/social-leverage',
#   '/organization/steadfast-venture-capital'},
#  '/organization/sailplay': {'/organization/flint-capital'},
#  '/organization/arkivum': {'/organization/ip-group-plc',
#   '/organization/oxford-capital-partners',
#   '/organization/parkwalk-advisors'},
#  '/organization/dropoff-inc': {'/organization/atlantic-capital-partners',
#   '/organization/correlation-ventures',
#   '/organization/greycroft-partners',
#   '/organization/wild-basin-investments'},
#  '/organization/pantheon': {'/organization/first-round-capital',
#   '/organization/foundry-group',
#   '/organization/openview-venture-partners',
#   '/person/dev-ittycheria',
#   '/person/rory-odriscoll'},
#  '/organization/visionchina-media-inc': {'/organization/baidu'},
#  '/organization/haochushi': {'/organization/cowin-capital',
#   '/organization/lightspeed-china-partners'},
#  '/organization/stylebee': {'/organization/y-combinator'},
#  '/organization/ditto-labs': {'/organization/griffon-ventures',
#   '/organization/mdc-dream-ventures',
#   '/organization/the-mars-agency',
#   '/person/anthony-k-tjan',
#   '/person/david-william-baum'},
#  '/organization/ycharts': {'/organization/12a',
#   '/organization/amicus-capital',
#   '/organization/hyde-park-angels',
#   '/organization/jumpstart-ventures',
#   '/organization/morningstar',
#   '/organization/reed-elsevier',
#   '/person/barney-harford'},
#  '/organization/fusionops': {'/organization/new-enterprise-associates',
#   '/organization/sierra-ventures'},
#  '/organization/soonjeong-game': {'/organization/altos-ventures'},
#  '/organization/oceana': {'/organization/start-up-chile'},
#  '/organization/lexoo': {'/organization/forward-partners'},
#  '/organization/loungebuddy': {'/organization/concur',
#   '/organization/ff-angel-llc',
#   '/organization/founders-fund',
#   '/organization/maiden-lane-ventures',
#   '/organization/plug-and-play-ventures',
#   '/person/rick-marini',
#   '/person/robert-cohen-3',
#   '/person/stephen-mendel',
#   '/person/tyler-willis'},
#  '/organization/anypresence': {'/organization/citrix-systems',
#   '/organization/cnf-investments',
#   '/organization/grotech-ventures',
#   '/organization/kinetic-ventures'},
#  '/organization/skillsurvey': {'/organization/primus-capital-management',
#   '/organization/primus-capital-partners'},
#  '/organization/weaverlabs': {'/organization/amplify-la',
#   '/organization/social-starts'},
#  '/organization/epona-biotech-2': {'/organization/cyberport-hong-kong'},
#  '/organization/re2': {'/organization/draper-triangle-ventures',
#   '/organization/riverfront-ventures'},
#  '/organization/jivi': {'/organization/2b-angels',
#   '/organization/nxtp-labs',
#   '/organization/rhodium',
#   '/person/ariel-arrieta',
#   '/person/daniel-recanati',
#   '/person/dougles-cohen',
#   '/person/gil-canaani',
#   '/person/jason-dimberg',
#   '/person/nishkaam-mehta',
#   '/person/oded-hermoni',
#   '/person/oded-vardi',
#   '/person/rajesh-sawhney',
#   '/person/yaron-kniajer'},
#  '/organization/quaero-corporation': {'/organization/alphaprime-ventures',
#   '/organization/pereg-ventures',
#   '/organization/rosepaul-investments'},
#  '/organization/navabi': {'/organization/bauer-media',
#   '/organization/bauer-venture-partners-2',
#   '/organization/index-ventures'},
#  '/organization/racoonsoft': {'/organization/capstone-partners-korea',
#   '/organization/mirae-asset-venture-investment'},
#  '/organization/the-credit-junction': {'/organization/gli-finance'},
#  '/organization/enercast': {'/organization/high-tech-gruenderfonds'},
#  '/organization/imvision-software-technologies': {'/organization/iventures-asia-ltd',
#   '/organization/pitango-venture-capital'},
#  '/organization/consortiex': {'/organization/open-prairie',
#   '/organization/wisconsin-economic-development-corporation-wedc'},
#  '/organization/healthprize-technologies': {'/organization/mansa-capital'},
#  '/organization/100health': {'/organization/dreamit-ventures',
#   '/organization/tmcx-accelerator',
#   '/person/mark-bakken'},
#  '/organization/clinipace-worldwide': {'/organization/crestline-investors',
#   '/organization/harbert-venture-partners',
#   '/organization/hatteras-venture-partners',
#   '/organization/mario-family-funds',
#   '/organization/morgan-stanley-expansion-capital-2',
#   '/organization/perella-weinberg-partners',
#   '/organization/virgo-investment-group'},
#  '/organization/agiliance': {'/organization/wellington-financial'},
#  '/organization/examsoft-worldwide': {'/organization/fifth-street-technology-partners',
#   '/organization/spectrum-equity-investors'},
#  '/organization/lendmed': {'/organization/innova-memphis',
#   '/organization/start-co'},
#  '/organization/partender': {'/organization/cito-ventures',
#   '/organization/rubicon-venture-capital',
#   '/organization/winklevoss-capital'},
#  '/organization/deep-identity': {'/organization/get2volume'},
#  '/organization/tumotorizado-com': {'/organization/wayra'},
#  '/organization/pepperdata': {'/organization/ame-cloud-ventures',
#   '/organization/citi-ventures',
#   '/organization/signia-venture-partners',
#   '/organization/silicon-valley-data-capital',
#   '/organization/webb-investment-network',
#   '/organization/wing-venture-capital',
#   '/person/andy-ludwick',
#   '/person/ed-zander',
#   '/person/maynard-webb'},
#  '/organization/taquilla': {'/organization/civeta-investments'},
#  '/organization/seesearch': {'/organization/wayra'},
#  '/organization/zymochem': {'/organization/synbio-axlr8r'},
#  '/organization/proonto': {'/organization/elevator'},
#  '/organization/lovethelook': {'/organization/collider'},
#  '/organization/getat': {'/person/amit-gupta',
#   '/person/ketan-babaria',
#   '/person/robert-stefanski',
#   '/person/scott-crosby',
#   '/person/soham-mazu'},
#  '/organization/moovenda-2': {'/organization/lventures'},
#  '/organization/unflete-com': {'/organization/start-up-chile'},
#  '/organization/completeset': {'/organization/cherub-fund',
#   '/organization/velocity',
#   '/person/doug-cobb'},
#  '/organization/guahao': {'/organization/tencent'},
#  '/organization/kahuna': {'/organization/costanoa-venture-capital',
#   '/organization/felicis-ventures',
#   '/organization/four-rivers-group',
#   '/organization/industry-ventures',
#   '/organization/lumia-capital',
#   '/organization/promus-ventures',
#   '/organization/sequoia-capital',
#   '/organization/softtech-vc',
#   '/organization/tenaya-capital',
#   '/person/matt-wyndowe',
#   '/person/nick-mehta',
#   '/person/tim-kendall'},
#  '/organization/evereve': {'/organization/prairie-management-group',
#   '/organization/winona-capital-management'},
#  '/organization/qpid-health': {'/organization/matrix-partners',
#   '/organization/new-leaf-venture-partners'},
#  '/organization/ktplay': {'/organization/alibaba'},
#  '/organization/droidcloud': {'/organization/green-visor-capital'},
#  '/organization/progreso-financiero': {'/organization/fidelity-management-research',
#   '/organization/institutional-venture-partners'},
#  '/organization/joberate': {'/person/elliot-clark',
#   '/person/kevin-quinn-2',
#   '/person/maciej-noja'},
#  '/organization/payrange': {'/organization/google-ventures',
#   '/organization/matrix-partners',
#   '/organization/nyca',
#   '/person/max-levchin',
#   '/person/osama-bedier',
#   '/person/philip-nadel'},
#  '/organization/kuhcoon': {'/organization/y-combinator'},
#  '/organization/famely': {'/organization/startupyard'},
#  '/organization/that-device-company-ltd': {'/organization/angel-investors-2',
#   '/organization/clearly-social-angels',
#   '/organization/ziegler-linkage-longevity-fund'},
#  '/organization/zarthcode': {'/organization/i2e-immersion'},
#  '/organization/raydiance': {'/organization/blue-swell-capital',
#   '/organization/dfj-growth',
#   '/organization/draper-fisher-jurvetson',
#   '/organization/greenstreet-partners'},
#  '/organization/cloudwear': {'/organization/wayra'},
#  '/organization/splashscore': {'/organization/grandbanks-capital',
#   '/organization/idea-northeasterns-venture-accelerator',
#   '/organization/techstars'},
#  '/organization/nix-hydra-games': {'/organization/foundry-group'},
#  '/organization/reviews42': {'/organization/blume-ventures',
#   '/organization/nirvana-venture-advisors',
#   '/organization/tiger-global'},
#  '/organization/ax\xc3\x83\xc2\xa8gaz': {'/organization/123-venture'},
#  '/organization/eat-club': {'/organization/trinity-ventures'},
#  '/organization/peloton-technology': {'/organization/band-of-angels',
#   '/organization/birchmere-ventures',
#   '/organization/castrol-innoventures',
#   '/organization/denso',
#   '/organization/intel-capital',
#   '/organization/magna-international-inc',
#   '/organization/nokia-growth-partners',
#   '/organization/sand-hill-angels',
#   '/organization/ups-strategic-enterprise-fund',
#   '/organization/volvo-group-venture-capital'},
#  '/organization/orthalign': {'/organization/mutual-capital-partners-funds',
#   '/organization/river-cities-capital'},
#  '/organization/wut': {'/organization/eniac-ventures',
#   '/organization/foundation-capital',
#   '/organization/google-ventures',
#   '/organization/lowercase-capital',
#   '/organization/slow-ventures',
#   '/organization/sv-angel'},
#  '/organization/rsam': {'/organization/jmi-equity'},
#  '/organization/greenmantra-technologies': {'/organization/arctern-ventures',
#   '/organization/cycle-capital'},
#  '/organization/swipe-to': {'/organization/passion-capital',
#   '/organization/playfair-capital'},
#  '/organization/fluvip': {'/organization/velum-ventures',
#   '/organization/wayra'},
#  '/organization/smartkem': {'/organization/basf-venture-capital',
#   '/organization/entrepreneurs-fund',
#   '/organization/octopus-ventures'},
#  '/organization/zhenpu-education': {'/organization/ventech-capital'},
#  '/organization/pepfeed': {'/organization/portugal-ventures'},
#  '/organization/narrativedx': {'/organization/capital-factory',
#   '/organization/dreamit-ventures',
#   '/organization/floodgate',
#   '/organization/liveoak-venture-partners',
#   '/organization/silverton-partners'},
#  '/organization/coventure': {'/organization/gerson-lehrman-group-2',
#   '/organization/great-oaks-venture-capital'},
#  '/organization/blablacar': {'/organization/accel-partners',
#   '/organization/index-ventures',
#   '/organization/isai',
#   '/organization/lead-edge-capital'},
#  '/organization/xceedium': {'/organization/harmony-partners'},
#  '/organization/ghostruck': {'/organization/founders-co-op',
#   '/organization/teec-angel-fund',
#   '/person/grace-stanat',
#   '/person/owen-van-natta'},
#  '/organization/crossbar': {'/organization/artiman-ventures',
#   '/organization/cbc-capital',
#   '/organization/correlation-ventures',
#   '/organization/kleiner-perkins-caufield-byers',
#   '/organization/korea-investment-partners',
#   '/organization/northern-light-venture-capital',
#   '/organization/saif-partners',
#   '/organization/university-of-michigan-ann-arbor'},
#  '/organization/one-animation': {'/organization/dealstreetasia',
#   '/organization/jungle-ventures'},
#  '/organization/capsos-medical': {'/organization/aib-seed-capital-fund'},
#  '/organization/water-to-go-company': {'/organization/crowdcube'},
#  '/organization/guidecity': {'/organization/travel-startups-incubator'},
#  '/organization/avizorex-pharma': {'/organization/inveready-technology-investment-group'},
#  '/organization/yext': {'/organization/insight-venture-partners',
#   '/organization/institutional-venture-partners',
#   '/organization/marker',
#   '/organization/sutter-hill-ventures'},
#  '/organization/raise-marketplace': {'/organization/accel-partners',
#   '/organization/bessemer-venture-partners',
#   '/organization/listen-llc',
#   '/organization/new-enterprise-associates',
#   '/organization/the-pritzker-organization'},
#  '/organization/ifbyphone': {'/organization/apex-venture-partners',
#   '/organization/i2a-fund',
#   '/organization/newspring-capital',
#   '/organization/origin-ventures',
#   '/organization/river-cities-capital',
#   '/organization/spring-mill-venture-partners',
#   '/organization/square-1-bank',
#   '/organization/ssm-partners'},
#  '/organization/vonage': {'/organization/citizens-bank-and-trust-company',
#   '/organization/fifth-third-bancorp',
#   '/organization/jpmorgan-chase-co',
#   '/organization/silicon-valley-bank',
#   '/organization/suntrust-bank'},
#  '/organization/boxed': {'/organization/ame-cloud-ventures',
#   '/organization/basset-investment-group',
#   '/organization/boxgroup',
#   '/organization/digital-sky-technologies-fo',
#   '/organization/eniac-ventures',
#   '/organization/first-round-capital',
#   '/organization/founders-fund',
#   '/organization/ggv-capital',
#   '/organization/greycroft-partners',
#   '/organization/signia-venture-partners',
#   '/organization/social-starts',
#   '/organization/vaizra-investments',
#   '/person/david-ko',
#   '/person/david-ko-2',
#   '/person/fabrice-grinda',
#   '/person/jose-marin-2',
#   '/person/oliver-jung',
#   '/person/owen-van-natta',
#   '/person/yuri-milner',
#   '/person/zaw-thet'},
#  '/organization/adphorus': {'/organization/500-startups'},
#  '/organization/flexus-biosciences': {'/organization/celgene',
#   '/organization/kleiner-perkins-caufield-byers',
#   '/organization/the-column-group'},
#  '/organization/enumeral-biomedical': {'/organization/harris-harris-group',
#   '/organization/montrose-capital-partners'},
#  '/organization/crowdtangle': {'/organization/advancit-capital',
#   '/organization/betaworks',
#   '/organization/boxgroup',
#   '/organization/knight-enterprise-fund',
#   '/organization/lerer-ventures',
#   '/organization/new-media-ventures',
#   '/organization/tsai-ventures',
#   '/person/richard-parsons'},
#  '/organization/himily': {'/organization/chinaccelerator'},
#  '/organization/sequent-medical': {'/organization/delphi-ventures',
#   '/organization/domain-associates',
#   '/organization/us-venture-partners',
#   '/organization/versant-ventures'},
#  '/organization/canara': {'/organization/columbia-capital'},
#  '/organization/genymobile-inc': {'/organization/alven-capital',
#   '/organization/bpifrance',
#   '/person/ryan-cooke'},
#  '/organization/viuing': {'/organization/bankinter',
#   '/organization/bevus-capital',
#   '/organization/gv-capital',
#   '/organization/inveready-capital',
#   '/organization/sitka-capital',
#   '/person/axel-serena-2',
#   '/person/carlos-blanco',
#   '/person/eudald-domnech',
#   '/person/hugo-mardomingo',
#   '/person/marc-fabregat',
#   '/person/oriol-juncosa',
#   '/person/rafael-rodiera',
#   '/person/xavier-verdaguer'},
#  '/organization/grabtaxi': {'/organization/500-startups',
#   '/organization/china-investment-corporation',
#   '/organization/coatue-management',
#   '/organization/ggv-capital',
#   '/organization/hillhouse-capital',
#   '/organization/softbank',
#   '/organization/softbank-capital',
#   '/organization/tiger-global',
#   '/organization/vertex-venture-holdings'},
#  '/organization/mmuze': {'/organization/2b-angels',
#   '/organization/microsoft-ventures',
#   '/organization/plus-ventures'},
#  '/organization/agenda-beleza': {'/organization/valor-capital'},
#  '/organization/odilo': {'/organization/active-venture-partners'},
#  '/organization/irofit': {'/organization/inventure-oy',
#   '/organization/nordic-venture-partners',
#   '/person/rasheed-olaoluwa'},
#  '/organization/genophen': {'/organization/plug-and-play-ventures'},
#  '/organization/gan-systems': {'/organization/bdc-capital-corporation',
#   '/organization/chrysalix-energy',
#   '/organization/cycle-capital',
#   '/organization/rockport-capital-partners',
#   '/organization/tsing-capital'},
#  '/organization/epistates': {'/organization/xlr8uh'},
#  '/organization/canary': {'/organization/cota-capital',
#   '/organization/flextronics-international',
#   '/organization/khosla-ventures',
#   '/organization/signatures-capital',
#   '/organization/two-sigma-ventures',
#   '/organization/walden-riverwood-ventures',
#   '/organization/wti',
#   '/person/bobby-yazdani'},
#  '/organization/best-option-trading': {'/organization/invest-nebraska'},
#  '/organization/krux': {'/organization/accel-partners',
#   '/organization/idg-ventures-usa',
#   '/organization/sapphire-ventures',
#   '/organization/temasek',
#   '/organization/the-entrepreneurs-fund-iii',
#   '/organization/time-warner-investments',
#   '/organization/visionnaire-ventures'},
#  '/organization/delta-id': {'/organization/intel-capital'},
#  '/organization/tuvalabs': {'/organization/ben-franklin-technology-partners-of-southeastern-pennsylvania',
#   '/organization/czar-investments-ltd',
#   '/organization/kaplan-edtech-accelerator',
#   '/organization/new-schools-venture-fund',
#   '/organization/techstars'},
#  '/organization/baofeng-mojing': {'/organization/aisidi',
#   '/organization/green-pine-capital',
#   '/organization/huayi-brothers-media-group',
#   '/organization/tianyin'},
#  '/organization/puteko': {'/organization/sparkbox-ventures'},
#  '/organization/3d-by-flow': {'/organization/startupbootcamp'},
#  '/organization/snapwire': {'/person/safa-rashtchy'},
#  '/organization/storytime-studios': {'/organization/cloud-power-capital',
#   '/organization/federal-street-angels',
#   '/organization/rmr-capital',
#   '/organization/strong-ventures',
#   '/organization/warner-bros'},
#  '/organization/turn': {'/organization/sharespost-investment-management'},
#  '/organization/augumenta': {'/organization/butterfly-ventures'},
#  '/organization/renovatio-it-solutions': {'/organization/health-wildcatters'},
#  '/organization/geenapp-internet': {'/organization/crystal-ventures',
#   '/organization/landiron',
#   '/organization/wayra',
#   '/person/david-cabero-jounou',
#   '/person/josep-moragas'},
#  '/organization/leading-mark': {'/organization/link-and-motivation-inc',
#   '/organization/mizuho-capital',
#   '/organization/nippon-venture-capital',
#   '/organization/smbc-venture-capital'},
#  '/organization/public-insight-corporation': {'/organization/north-coast-angel-fund'},
#  '/organization/flashpoint-partners': {'/organization/bloomberg-beta',
#   '/organization/cisco-investments',
#   '/organization/greycroft-partners',
#   '/organization/techoperators'},
#  '/organization/indooratlas': {'/organization/baidu',
#   '/organization/koppicatch',
#   '/organization/mobility-ventures',
#   '/organization/plug-and-play-ventures'},
#  '/organization/oilproject': {'/organization/tim-ventures'},
#  '/organization/discotech': {'/organization/hive-7'},
#  '/organization/postergully': {'/organization/letsventure',
#   '/person/anuj-chowdhary',
#   '/person/natarajan-iyer',
#   '/person/nish-bhutani',
#   '/person/rajesh-sawhney',
#   '/person/vikram-saxena',
#   '/person/vivek-mulchandani'},
#  '/organization/seed-blooming': {'/organization/cyberport-hong-kong'},
#  '/organization/fuzmo': {'/organization/seedrs'},
#  '/organization/taodangpu': {'/organization/bluerun-ventures',
#   '/organization/heli-capital',
#   '/organization/northern-light-venture-capital'},
#  '/organization/pilottv': {'/organization/intel-capital'},
#  '/organization/wirex-cube-systems': {'/organization/entree-capital',
#   '/organization/magma-venture-partners',
#   '/organization/vertex-venture-capital'},
#  '/organization/solenica': {'/organization/qualcomm',
#   '/organization/techstars'},
#  '/organization/veeqo': {'/organization/seedrs'},
#  '/organization/uguru': {'/organization/500-startups'},
#  '/organization/narrative': {'/organization/creandum',
#   '/organization/khosla-ventures',
#   '/organization/passion-capital',
#   '/organization/true-ventures'},
#  '/organization/orvibo': {'/organization/legendstar',
#   '/organization/saif-partners'},
#  '/organization/patientpay': {'/organization/mosaik-partners'},
#  '/organization/wahanda': {'/organization/fidelity-growth-partners-europe',
#   '/organization/lepe-partners',
#   '/organization/recruit-holdings',
#   '/organization/recruit-strategic-partners',
#   '/person/davor-hebel'},
#  '/organization/iristrace': {'/organization/plug-and-play-spain-accelerator',
#   '/organization/startupbootcamp',
#   '/organization/toubkal-partners',
#   '/person/alfonso-alvarez',
#   '/person/ana-and-nuria-martinez',
#   '/person/ana-vilas',
#   '/person/andr\xc3\x83\xc2\xa9-kingham',
#   '/person/eric-van-der-maten',
#   '/person/ignacio-soto-2',
#   '/person/marek-fodor'},
#  '/organization/shopdeca': {'/organization/polaris-digimedia'},
#  '/organization/videregen': {'/organization/london-business-angels',
#   '/organization/north-west-fund-for-biomedical'},
#  '/organization/fingi': {'/organization/peterson-ventures',
#   '/organization/teec-angel-fund'},
#  '/organization/bayes-impact': {'/organization/y-combinator'},
#  '/organization/standing-ovation': {'/organization/dbj-capital',
#   '/organization/gumi-ventures'},
#  '/organization/experifun': {'/organization/affordable-learning-fund-palf',
#   '/organization/vilcap-investments'},
#  '/organization/ab-tasty': {'/organization/kima-ventures',
#   '/organization/xange-private-equity'},
#  '/organization/jet': {'/organization/accel-partners',
#   '/organization/alibaba',
#   '/organization/bain-capital-ventures',
#   '/organization/citi-ventures',
#   '/organization/coatue-management',
#   '/organization/general-catalyst-partners',
#   '/organization/goldman-sachs',
#   '/organization/google-ventures',
#   '/organization/high-peaks-venture-partners',
#   '/organization/mentortech-ventures',
#   '/organization/new-enterprise-associates',
#   '/organization/norwest-venture-partners',
#   '/organization/silicon-valley-bank',
#   '/organization/temasek',
#   '/organization/thrive-capital',
#   '/organization/western-technology-investment',
#   '/person/david-spector'},
#  '/organization/homelane': {'/organization/aarin-capital',
#   '/organization/sequoia-capital'},
#  '/organization/zeek-2': {'/organization/blumberg-capital',
#   '/organization/qualcomm-ventures',
#   '/person/uri-levine'},
#  '/organization/lob': {'/organization/drummond-road-capital',
#   '/organization/first-round-capital',
#   '/organization/floodgate',
#   '/organization/indicator-ventures',
#   '/organization/polaris-partners'},
#  '/organization/biomonde': {'/organization/finance-wales',
#   '/organization/oxford-capital-partners'},
#  '/organization/pontamedia': {'/organization/jaguar-ventures'},
#  '/organization/scrumpt': {'/organization/tumml'},
#  '/organization/chrome-river-technologies': {'/organization/great-hill-partners'},
#  '/organization/elasticsearch': {'/organization/benchmark',
#   '/organization/index-ventures',
#   '/organization/new-enterprise-associates'},
#  '/organization/equidate': {'/organization/structure-capital',
#   '/person/charlie-cheever',
#   '/person/scott-banister'},
#  '/organization/spayee': {'/organization/tlabs'},
#  '/organization/mapr-technologies': {'/organization/google-capital',
#   '/organization/lightspeed-venture-partners',
#   '/organization/mayfield-fund',
#   '/organization/new-enterprise-associates',
#   '/organization/qualcomm-ventures',
#   '/organization/redpoint-ventures',
#   '/organization/silicon-valley-bank'},
#  '/organization/studytube': {'/organization/henq-invest'},
#  '/organization/alianza': {'/organization/grayhawk-venture-partners',
#   '/organization/peninsula-equity-partners',
#   '/organization/signal-peak-ventures'},
#  '/organization/musement': {'/organization/360-capital-partners',
#   '/organization/francesco-micheli-associati',
#   '/organization/italian-angels-for-growth',
#   '/organization/programma-101'},
#  '/organization/nvdrones': {'/organization/kleiner-perkins-caufield-byers',
#   '/organization/s-cubed-capital',
#   '/organization/usc-viterbi'},
#  '/organization/accupass': {'/organization/dcm',
#   '/organization/qualcomm',
#   '/organization/saif-partners'},
#  '/organization/zirx': {'/organization/bessemer-venture-partners',
#   '/organization/norwest-venture-partners',
#   '/organization/trinity-ventures',
#   '/person/brendan-wallace',
#   '/person/fabrice-grinda',
#   '/person/jose-marin-2'},
#  '/organization/achica': {'/organization/draper-esprit',
#   '/organization/target-ventures'},
#  '/organization/appdynamics': {'/organization/battery-ventures',
#   '/organization/clearbridge-investments',
#   '/organization/greylock',
#   '/organization/institutional-venture-partners',
#   '/organization/kleiner-perkins-caufield-byers',
#   '/organization/lightspeed-venture-partners',
#   '/organization/sands-capital-management',
#   '/organization/sands-capital-ventures',
#   '/organization/silicon-valley-bank'},
#  '/organization/creatorbox': {'/organization/kaplan-edtech-accelerator',
#   '/organization/techstars'},
#  '/organization/the-royalty-exchange': {'/organization/idea-fund-partners'},
#  '/organization/chic-by-choice': {'/organization/edge-group',
#   '/organization/faber-ventures',
#   '/organization/portugal-ventures',
#   '/organization/portuguese-venture-capital-groups'},
#  '/organization/blueline-grid': {'/organization/in-q-tel'},
#  '/organization/juxta-labs': {'/organization/500-startups'},
#  '/organization/kinduct': {'/organization/la-dodgers-sports---entertainment-accelerator-with-r-ga-2'},
#  '/organization/process-street': {'/organization/angelpad'},
#  '/organization/mens-style-lab': {'/organization/gener8tor',
#   '/organization/jeff-rusinow'},
#  '/organization/grandata': {'/organization/nxtp-labs'},
#  '/organization/2mee': {'/organization/angels-den'},
#  '/organization/watchfinder': {'/organization/beringea',
#   '/organization/piton-capital'},
#  '/organization/updater': {'/organization/commerce-ventures',
#   '/organization/ia-ventures',
#   '/organization/second-century-ventures',
#   '/organization/softbank-capital'},
#  '/organization/lomaki': {'/organization/start-up-chile'},
#  '/organization/mitu-2': {'/organization/queensbridge-venture-partners',
#   '/organization/upfront-ventures'},
#  '/organization/astroscale': {'/organization/jafco-asia',
#   '/organization/mistletoe',
#   '/person/kenji-kasahara',
#   '/person/kiyoshi-nishikawa',
#   '/person/kotaro-yamagishi',
#   '/person/shuhei-morofuji'},
#  '/organization/scout-rfp': {'/organization/drummond-road-capital',
#   '/organization/google-ventures',
#   '/organization/new-enterprise-associates',
#   '/organization/techammer',
#   '/organization/zapis-capital-group'},
#  '/organization/smart-ad-2': {'/organization/accelerator-centre'},
#  '/organization/tapgenes': {'/organization/blueprint-health-accelerator'},
#  '/organization/causemo': {'/organization/fractal-sciences',
#   '/organization/furneaux-capital-2',
#   '/organization/park-vale-capital-2',
#   '/organization/real-ventures',
#   '/person/lars-albright',
#   '/person/michael-katz',
#   '/person/mike-weider-2'},
#  '/organization/spikes-inc': {'/organization/benhamou-global-ventures',
#   '/organization/javelin-venture-partners',
#   '/organization/lakewood-company'},
#  '/organization/surf-air': {'/organization/anthem-venture-partners',
#   '/organization/base-vc',
#   '/organization/ff-venture-capital',
#   '/organization/muckercapital',
#   '/organization/plus-capital',
#   '/organization/vegastechfund',
#   '/organization/velos-partners',
#   '/organization/white-oak-global-advisors',
#   '/person/dennis-phelps',
#   '/person/jared-leto',
#   '/person/rick-j-caruso'},
#  '/organization/limestone-labs': {'/organization/blueprint-health-accelerator'},
#  '/organization/carepredict': {'/organization/vectr'},
#  '/organization/myriada-systems': {'/organization/microsoft-ventures'},
#  '/organization/hijup-com': {'/organization/500-startups',
#   '/organization/emtek-group',
#   '/organization/fenox-venture-capital',
#   '/organization/skystar-capital'},
#  '/organization/termine24-gmbh': {'/organization/otto-capital',
#   '/organization/paua-ventures'},
#  '/organization/freshtemp': {'/organization/innovation-works',
#   '/organization/scout-ventures'},
#  '/organization/intigua': {'/organization/bessemer-venture-partners',
#   '/organization/cedar-fund',
# ...
#   '/organization/novo-ventures',
#   '/organization/tpg-biotech'},
#  '/organization/1jiajie': {'/organization/shanda-capital',
#   '/organization/tencent'},
#  '/organization/indico-data-solutions': {'/organization/406-ventures',
#   '/organization/boston-seed-capital',
#   '/organization/general-catalyst-partners',
#   '/organization/hyperplane-venture-capital',
#   '/organization/rough-draft-ventures',
#   '/organization/techstars',
#   '/organization/two-sigma-ventures',
#   '/person/matt-malloy',
#   '/person/michael-mark',
#   '/person/paul-sagan',
#   '/person/simeon-simeonov',
#   '/person/ty-danco',
#   '/person/vivjan-myrto',
#   '/person/walt-winshall',
#   '/person/yuchun-lee'},
#  '/organization/7summits': {'/organization/salesforce-ventures'},
#  '/organization/chouxbox': {'/organization/500-startups'},
#  '/organization/dosesystem': {'/organization/accelerace'},
#  '/organization/gametime': {'/organization/accel-partners',
#   '/organization/mavern-ventures',
#   '/organization/soma-capital',
#   '/person/aaron-levie',
#   '/person/brian-spaly',
#   '/person/casey-wasserman',
#   '/person/david-blitzer',
#   '/person/jared-simon',
#   '/person/jeff-mallett',
#   '/person/john-tucker-3',
#   '/person/sam-shank',
#   '/person/vivek-ranadiv'},
#  '/organization/bithound': {'/organization/bdc-capital-corporation',
#   '/person/michael-wekerle'},
#  '/organization/cermati': {'/organization/beenos-plaza',
#   '/organization/east-ventures'},
#  '/organization/bowery': {'/organization/bloomberg-beta',
#   '/organization/google-ventures',
#   '/organization/rough-draft-ventures',
#   '/organization/sv-angel'},
#  '/organization/wing-ma-am': {'/organization/innovation-works'},
#  '/organization/gaatu': {'/organization/innospring',
#   '/organization/teec-angel-fund'},
#  '/organization/minimally-invasive-devices': {'/organization/canaan-partners',
#   '/organization/radius-ventures'},
#  '/organization/acupera': {'/organization/lightspeed-venture-partners',
#   '/organization/the-whittemore-collection'},
#  '/organization/theresumator': {'/organization/birchmere-ventures',
#   '/organization/blue-cloud-ventures',
#   '/organization/rincon-venture-partners',
#   '/organization/riverfront-ventures',
#   '/organization/volition-capital'},
#  '/organization/retailersaver-com': {'/organization/angels-den'},
#  '/organization/ihealth-lab-inc': {'/organization/xiaomi'},
#  '/organization/viva-labs': {'/organization/investinor',
#   '/organization/startuplab'},
#  '/organization/splitwise': {'/organization/great-oaks-venture-capital',
#   '/organization/idg-ventures-usa',
#   '/organization/rocketship-vc',
#   '/organization/silicon-valley-bank',
#   '/person/scott-banister',
#   '/person/william-guttman'},
#  '/organization/argil-data-corp': {'/organization/innospring'},
#  '/organization/zerto': {'/organization/battery-ventures',
#   '/organization/greylock-partners-israel',
#   '/organization/harmony-partners',
#   '/organization/rtp-ventures',
#   '/organization/us-venture-partners'},
#  '/organization/pack-purchase': {'/organization/cofounders-capital',
#   '/organization/idea-fund-partners'},
#  '/organization/sinode-systems': {'/organization/energy-foundry'},
#  '/organization/picapica': {'/organization/start-up-chile'},
#  '/organization/younow': {'/organization/venrock'},
#  '/organization/ginkgo-bioworks': {'/organization/china-rock-capital',
#   '/organization/data-collective',
#   '/organization/felicis-ventures',
#   '/organization/iglobe-partners',
#   '/organization/os-fund',
#   '/organization/teec-angel-fund',
#   '/organization/vast-ventures',
#   '/organization/viking-global-investors',
#   '/organization/y-combinator',
#   '/person/david-spector',
#   '/person/farzad-nazem',
#   '/person/ken-arnold'},
#  '/organization/trip4real': {'/organization/caixa-capital',
#   '/organization/emprendetur',
#   '/organization/enisa',
#   '/organization/kibo-ventures'},
#  '/organization/kabam': {'/organization/alibaba',
#   '/organization/sharespost-investment-management'},
#  '/organization/monteris-medical': {'/organization/bdc-venture-capital',
#   '/organization/birchview-capital',
#   '/organization/the-vertical-group'},
#  '/organization/vedantu-innovations': {'/organization/accel-partners',
#   '/organization/tiger-global'},
#  '/organization/dagne-dover': {'/organization/2020-ventures',
#   '/organization/kima-ventures',
#   '/person/fabrice-grinda'},
#  '/organization/mitigram': {'/organization/moor'},
#  '/organization/hauteday': {'/organization/y-combinator'},
#  '/organization/rotageek-limited': {'/organization/wayra'},
#  '/organization/pureprint': {'/organization/business-growth-fund'},
#  '/organization/vivit': {'/organization/incubate-fund',
#   '/organization/venture-united'},
#  '/organization/limk': {'/organization/500-startups',
#   '/organization/kima-ventures',
#   '/organization/rockstart-acclerator',
#   '/person/dave-mcclure'},
#  '/organization/x-ai': {'/organization/crunchfund',
#   '/organization/firstmark-capital',
#   '/organization/ia-ventures',
#   '/organization/lerer-ventures',
#   '/organization/pritzker-group-venture-capital',
#   '/organization/softbank-capital',
#   '/person/dennis-r-mortensen',
#   '/person/matt-turck'},
#  '/organization/gamechanger-media': {'/organization/costanoa-venture-capital',
#   '/organization/tenfore-holdings',
#   '/organization/trilogy-equity-partnership'},
#  '/organization/postman': {'/organization/nexus-venture-partners'},
#  '/organization/memorado': {'/organization/cherry-ventures',
#   '/organization/creathor-venture-management',
#   '/organization/global-founders-capital',
#   '/organization/sunstone-capital'},
#  '/organization/qwikcilver-solutions': {'/organization/accel-partners',
#   '/organization/amazon',
#   '/organization/helion-venture-partners'},
#  '/organization/reschedule': {'/organization/y-combinator'},
#  '/organization/fashioncomm': {'/organization/intel-capital'},
#  '/organization/capital-vision-services': {'/organization/altas-partners',
#   '/organization/caisse-de-depot-et-placement-du-quebec'},
#  '/organization/aasaanjobs-com': {'/organization/idg-ventures-india',
#   '/organization/inventus-capital-partners'},
#  '/organization/lahore-university-of-management-sciences': {'/organization/kima-ventures'},
#  '/organization/pollfish': {'/organization/odyssey-investment-partners',
#   '/organization/pj-tech-catalyst',
#   '/organization/woodside-group',
#   '/person/argyris-zymnis',
#   '/person/panagiotis-papadoulos',
#   '/person/thanos-triant'},
#  '/organization/cuiker': {'/organization/start-up-chile',
#   '/organization/wayra'},
#  '/organization/quickplay-media': {'/organization/difference-capital',
#   '/organization/madison-dearborn-partners',
#   '/organization/orix-ventures'},
#  '/organization/tinytap': {'/organization/co-lab-2'},
#  '/organization/creative-gig': {'/organization/wasabi-ventures'},
#  '/organization/airbitz': {'/organization/plug-and-play-ventures',
#   '/person/damian-cutillo',
#   '/person/paul-puey',
#   '/person/rick-henri-chan',
#   '/person/tim-horton',
#   '/person/william-swanson'},
#  '/organization/the-button-corporation': {'/organization/tekes',
#   '/person/jari-ovaskainen'},
#  '/organization/parkey': {'/organization/club-italia-investimenti'},
#  '/organization/99taxis': {'/organization/monashees-capital',
#   '/organization/qualcomm',
#   '/organization/qualcomm-ventures',
#   '/organization/tiger-global'},
#  '/organization/healthify': {'/organization/seedinvest'},
#  '/organization/arcadia-data': {'/organization/blumberg-capital',
#   '/organization/intel-capital',
#   '/organization/mayfield-fund'},
#  '/organization/airtable': {'/organization/boxgroup',
#   '/organization/caffeinated-capital',
#   '/organization/charles-river-ventures',
#   '/organization/crunchfund',
#   '/organization/data-collective',
#   '/organization/founder-collective',
#   '/organization/freestyle-capital',
#   '/organization/hammerstone-capital',
#   '/person/amitt-mahajan',
#   '/person/ashton-kutcher',
#   '/person/ben-ling',
#   '/person/eric-wu-2',
#   '/person/kevin-mahaffey',
#   '/person/michael-birch',
#   '/person/othman-laraki',
#   '/person/raymond-tonsing',
#   '/person/shan-mehta',
#   '/person/villi-iltchev'},
#  '/organization/allgreenup': {'/organization/start-up-chile'},
#  '/organization/inovar-corporation': {'/organization/wayra',
#   '/person/del-tanner',
#   '/person/doug-lichliter',
#   '/person/michael-eleftheriou'},
#  '/organization/adspired-technologies': {'/organization/i5invest'},
#  '/organization/zepo-technologies-pvt-ltd': {'/organization/one97-mobility-fund',
#   '/person/anupam-mittal'},
#  '/organization/blueprint-medicines': {'/organization/cowen-investments',
#   '/organization/partner-fund-management-pfm',
#   '/organization/perceptive-advisors',
#   '/organization/ra-capital-management',
#   '/organization/redmile-group',
#   '/organization/sabby-capital',
#   '/organization/tavistock-life-sciences',
#   '/organization/wellington-management'},
#  '/organization/fondeadora': {'/organization/start-up-chile'},
#  '/organization/sight-sense': {'/organization/angelhub-ventures'},
#  '/organization/powr-of-you': {'/organization/collider',
#   '/organization/seedrs'},
#  '/organization/rubikloud': {'/organization/access-industries',
#   '/organization/tom-group'},
#  '/organization/optio-labs': {'/organization/allied-minds'},
#  '/organization/chishenma': {'/organization/chinaccelerator'},
#  '/organization/caravan': {'/organization/unitus-seed-fund',
#   '/person/bijou-kurien',
#   '/person/narayan-ramachandran'},
#  '/organization/erecruit': {'/organization/north-bridge-venture-partners'},
#  '/organization/videotelling': {'/person/igor-schlumberger'},
#  '/organization/piper': {'/organization/k-street-capital'},
#  '/organization/aventones': {'/organization/nxtp-labs'},
#  '/organization/nexus-ewater': {'/organization/anu-connect-ventures',
#   '/organization/questmark',
#   '/organization/sydney-angels-sidecar-fund',
#   '/person/thomas-reeves-hitchner'},
#  '/organization/toilet-paper-and': {'/organization/startup-next'},
#  '/organization/brad-s-raw-foods': {'/organization/ben-franklin-technology-partners-of-southeastern-pennsylvania',
#   '/organization/corigin-ventures-2',
#   '/organization/pergament-lohas-fund'},
#  '/organization/qll': {'/organization/b-dash-ventures',
#   '/organization/coent-venture-partners',
#   '/organization/incubate-fund',
#   '/organization/pinehurst-advisors',
#   '/organization/viling-venture-partners'},
#  '/organization/devhd': {'/organization/blisce', '/person/alexandre-mars'},
#  '/organization/industrial-generosity': {'/organization/second-avenue-partners',
#   '/person/adrian-hanauer',
#   '/person/greg-slyngstad'},
#  '/organization/beta-o2-technologies': {'/organization/sherpa-partners'},
#  '/organization/red-monster-games': {'/organization/matrix-partners-india'},
#  '/organization/embibe': {'/organization/kalaari-capital',
#   '/organization/lightbox-ventures'},
#  '/organization/neo-technology': {'/organization/conor-venture-partners',
#   '/organization/creandum',
#   '/organization/dawn-capital',
#   '/organization/fidelity-growth-partners-europe',
#   '/organization/sunstone-capital'},
#  '/organization/dronedeploy': {'/organization/angelpad',
#   '/organization/data-collective',
#   '/organization/draper-fisher-jurvetson',
#   '/organization/emergence-capital-partners',
#   '/organization/redpoint-ventures',
#   '/organization/softtech-vc'},
#  '/organization/germin8': {'/organization/kalaari-capital'},
#  '/organization/liveli': {'/organization/streamlined-ventures'},
#  '/organization/envoy': {'/organization/andreessen-horowitz',
#   '/person/adam-d-angelo',
#   '/person/alexis-ohanian',
#   '/person/blake-krikorian',
#   '/person/garry-tan',
#   '/person/harj-taggar',
#   '/person/javier-olivan',
#   '/person/jeremy-stoppelman',
#   '/person/kent-liu',
#   '/person/razmig-hovaghimian',
#   '/person/rob-goodlatte',
#   '/person/semil-shah',
#   '/person/tammy-h-nam',
#   '/person/yishan-wong',
#   '/person/yun-fang-juan'},
#  '/organization/leaddesk': {'/organization/dawn-capital',
#   '/organization/finnish-industry-investment'},
#  '/organization/outset-medical': {'/organization/capital-royalty',
#   '/organization/fidelity-management-research',
#   '/organization/partner-fund-management-pfm',
#   '/organization/perceptive-advisors',
#   '/organization/the-vertical-group',
#   '/organization/warburg-pincus'},
#  '/organization/openfin': {'/organization/bain-capital-ventures',
#   '/organization/nyca',
#   '/organization/pivot-investment-partners',
#   '/person/cris-conde',
#   '/person/tom-glocer'},
#  '/organization/execonline': {'/organization/kaplan-ventures',
#   '/organization/militello-capital',
#   '/organization/new-atlantic-ventures',
#   '/organization/osage-ventures'},
#  '/organization/youyiche-holdings': {'/organization/korea-investment-partners'},
#  '/organization/fleep': {'/organization/estonian',
#   '/organization/rock-spring-ventures',
#   '/person/ahti-heinla',
#   '/person/jaan-tallinn',
#   '/person/jaan-tallinn-2',
#   '/person/priit-kasesalu',
#   '/person/sten-kamkivi'},
#  '/organization/mixgenius': {'/organization/anges-quebec',
#   '/organization/hdgl',
#   '/organization/plus-eight-private-equity',
#   '/organization/real-ventures',
#   '/organization/warner-music-group',
#   '/organization/yul-ventures',
#   '/person/nasir-bin-olu-dara-jones'},
#  '/organization/xiachufang': {'/organization/ceyuan-ventures',
#   '/organization/china-growth-capital',
#   '/organization/jd-com',
#   '/organization/zhixin-capital'},
#  '/organization/syngen': {'/organization/bay-city-capital',
#   '/organization/ge-capital'},
#  '/organization/mycoon': {'/organization/500-startups',
#   '/organization/bonangels-venture-partners',
#   '/organization/idg-ventures-korea'},
#  '/organization/simplereach': {'/organization/atlas-venture',
#   '/organization/high-peaks-venture-partners',
#   '/organization/mk-capital',
#   '/organization/siemer-ventures',
#   '/organization/social-starts',
#   '/organization/village-ventures'},
#  '/organization/wellfount': {'/organization/deerfield'},
#  '/organization/lizhi': {'/organization/matrix-partners-china',
#   '/organization/morningside-private-investors',
#   '/organization/shunwei-china-internet-fund',
#   '/organization/xiaomi'},
#  '/organization/matrixx-software': {'/organization/telstra-ventures'},
#  '/organization/flipboard': {'/organization/jpmorgan-chase-co'},
#  '/organization/tokenone': {'/organization/black-sheep-capital',
#   '/organization/bluechilli',
#   '/organization/mirin-capital',
#   '/organization/singtel-innov8'},
#  '/organization/marklogic': {'/organization/arrowpoint-partners',
#   '/organization/northgate-capital',
#   '/organization/sequoia-capital',
#   '/organization/tenaya-capital',
#   '/organization/wellington-management',
#   '/person/gary-bloom'},
#  '/organization/agilum-healthcare-intelligence': {'/organization/relevance-capital',
#   '/organization/trinity-capital-investment'},
#  '/organization/estate-assist': {'/person/amar-chokhawala-2',
#   '/person/howard-lindzon',
#   '/person/lon-chow',
#   '/person/mahendra-ramsinghani',
#   '/person/naveen-jain',
#   '/person/richard-rick-gordon',
#   '/person/sanjay-subhedar',
#   '/person/sonny-singh-3'},
#  '/organization/ness-clothing': {'/organization/yfm-equity-partners'},
#  '/organization/piq': {'/organization/robolution-capital',
#   '/organization/swisscom'},
#  '/organization/telesense': {'/organization/plug-and-play-ventures'},
#  '/organization/sulekha-com': {'/organization/gic',
#   '/organization/norwest-venture-partners'},
#  '/organization/blue-river-technology': {'/organization/data-collective',
#   '/organization/innovation-endeavors',
#   '/organization/khosla-ventures'},
#  '/organization/duo-security': {'/organization/benchmark',
#   '/organization/google-ventures',
#   '/organization/radar-partners',
#   '/organization/redpoint-ventures',
#   '/organization/true-ventures'},
#  '/organization/navdy': {'/organization/eniac-ventures',
#   '/organization/formation8',
#   '/organization/golden-venture-partners',
#   '/organization/haystack',
#   '/organization/kima-ventures',
#   '/organization/lightbank',
#   '/organization/ludlow-ventures-llc',
#   '/organization/mesa-ventures',
#   '/organization/promus-ventures',
#   '/organization/qualcomm-ventures',
#   '/organization/rubicon-venture-capital',
#   '/organization/upfront-ventures',
#   '/organization/wareness-io',
#   '/person/kevin-ding-2',
#   '/person/semil-shah'},
#  ...}

# %%
def predict(company, new_edges, investors):
    predict = [random.choice(investors) for i in range(0, len(new_edges))]
    return sum(map(lambda x: 1 if x in new_edges else 0, predict))


investors = dict(investor_degree).keys()
i = 0
total_correct = 0
for company in new_edges_s.keys():
    total_correct += predict(company, new_edges_s[company], investors)
    i += 1
    if i % 1000 == 0:
        print i
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000

# %%
total_correct
# Out:
# 6

# %%
len(df)
# Out:
# 34128

# %%
6.0/34128
# Out:
# 0.00017580872011251758

# %%
400.0/34128
# Out:
# 0.011720581340834505

# %%
678.0/34128
# Out:
# 0.019866385372714488

# %%
postG = loadEdgelist("../1_snapshotting/cumulative_snapshots/enddate_20150831.edgelist")

# %%
# Set node attributes. 0 is an investor, 1 is a company.
node_attributes =dict(map(lambda (x,y): (x,1) if y > 0 else (x,0), 
                      postG.in_degree().items()))
nx.set_node_attributes(postG, "bipartite", node_attributes)

# %%
len(filter(lambda (x,y): y == 0, node_attributes.items()))
# Out:
# 20858

# %%
len(filter(lambda (x,y): y == 1, node_attributes.items()))
# Out:
# 34101

# %%
investor_degree = filter(lambda (n, d): node_attributes[n] == 0,
                        postG.out_degree(weight="weight").items())
sorted_investor_degree_list = sorted(investor_degree, 
                            key=operator.itemgetter(1), reverse=True)
sorted_investor_degree_list
# Out:
# [(u'/organization/goldman-sachs', 6351100008.0),
#  (u'/organization/alibaba', 5252092061.0),
#  (u'/organization/sequoia-capital', 4419774196.0),
#  (u'/organization/warburg-pincus', 3853103460.0),
#  (u'/organization/kleiner-perkins-caufield-byers', 3184299724.0),
#  (u'/organization/intel-capital', 3041073120.0),
#  (u'/organization/accel-partners', 3012476080.0),
#  (u'/organization/new-enterprise-associates', 2999719304.0),
#  (u'/organization/u-s-department-of-energy', 2508098333.0),
#  (u'/organization/tiger-global', 2399512480.0),
#  (u'/organization/carlyle-group', 2390931891.0),
#  (u'/organization/temasek', 2378122876.0),
#  (u'/organization/insight-venture-partners', 2364647819.0),
#  (u'/organization/digital-sky-technologies-fo', 2107724023.0),
#  (u'/organization/google', 2101282379.0),
#  (u'/organization/ta-associates', 1999729666.0),
#  (u'/organization/kkr', 1980386480.0),
#  (u'/organization/summit-partners', 1920447459.0),
#  (u'/organization/softbank', 1816094783.0),
#  (u'/organization/technology-crossover-ventures', 1773551486.0),
#  (u'/organization/silicon-valley-bank', 1741674811.0),
#  (u'/organization/andreessen-horowitz', 1690095039.0),
#  (u'/organization/tencent', 1678551303.0),
#  (u'/organization/softbank-capital', 1669535141.0),
#  (u'/organization/idg-capital-partners', 1507952088.0),
#  (u'/organization/index-ventures', 1463655500.0),
#  (u'/organization/microsoft', 1427033530.0),
#  (u'/organization/venrock', 1409154069.0),
#  (u'/organization/silver-lake-partners', 1381591666.0),
#  (u'/organization/bessemer-venture-partners', 1373411634.0),
#  (u'/organization/t-rowe-price', 1361687170.0),
#  (u'/organization/general-atlantic', 1321244629.0),
#  (u'/organization/morgan-stanley', 1307268669.0),
#  (u'/organization/wellington-management', 1288413813.0),
#  (u'/organization/bain-capital-2', 1280941665.0),
#  (u'/organization/draper-fisher-jurvetson', 1269430239.0),
#  (u'/organization/khosla-ventures', 1263674081.0),
#  (u'/organization/lightspeed-venture-partners', 1190381873.0),
#  (u'/organization/oak-investment-partners', 1187845838.0),
#  (u'/organization/saif-partners', 1165717268.0),
#  (u'/organization/fidelity-investments', 1153308668.0),
#  (u'/organization/riverstone-holdings', 1146272727.0),
#  (u'/organization/benchmark', 1133690280.0),
#  (u'/organization/institutional-venture-partners', 1112417609.0),
#  (u'/organization/google-ventures', 1079332545.0),
#  (u'/organization/bain-capital-ventures', 1068127426.0),
#  (u'/organization/ggv-capital', 1062398996.0),
#  (u'/organization/battery-ventures', 1061573286.0),
#  (u'/organization/foundation-capital', 1061485944.0),
#  (u'/organization/ge-capital', 1039229746.0),
#  (u'/organization/matrix-partners', 1032617359.0),
#  (u'/organization/norwest-venture-partners', 1018515690.0),
#  (u'/organization/general-catalyst-partners', 1006069042.0),
#  (u'/organization/redpoint-ventures', 1003476687.0),
#  (u'/organization/hillhouse-capital', 1002714639.0),
#  (u'/organization/3i-group', 997165396.0),
#  (u'/organization/baidu', 992337550.0),
#  (u'/organization/greylock', 981158447.0),
#  (u'/organization/founders-fund', 955742695.0),
#  (u'/organization/north-bridge-venture-partners', 879906116.0),
#  (u'/organization/great-hill-partners', 873312053.0),
#  (u'/organization/wells-fargo-energy-capital', 860008333.0),
#  (u'/organization/orbimed-advisors', 855977678.0),
#  (u'/organization/menlo-ventures', 849031401.0),
#  (u'/organization/spectrum-equity-investors', 830442283.0),
#  (u'/organization/highland-capital-partners', 813014044.0),
#  (u'/organization/cdh-investments', 808680618.0),
#  (u'/organization/blackrock', 792344233.0),
#  (u'/organization/dcm', 790417543.0),
#  (u'/organization/victory-park-capital', 782799999.0),
#  (u'/organization/oak-hill-capital-partners', 782245932.0),
#  (u'/organization/tpg-capital', 777116666.0),
#  (u'/organization/russian-direct-investment-fund', 776833333.0),
#  (u'/organization/polaris-partners', 775893130.0),
#  (u'/organization/j-p-morgan', 775826923.0),
#  (u'/organization/natural-gas-partners', 766564010.0),
#  (u'/organization/coatue-management', 732492060.0),
#  (u'/organization/jpmorgan-chase-co', 723356897.0),
#  (u'/organization/hercules-technology-growth-capital', 691213331.0),
#  (u'/organization/international-finance-corporation', 688542455.0),
#  (u'/organization/softbank-internet-and-media-(simi)', 677000000.0),
#  (u'/organization/shenzhen-capital-group', 668764254.0),
#  (u'/organization/francisco-partners', 666829541.0),
#  (u'/organization/alta-partners', 665722778.0),
#  (u'/organization/canaan-partners', 662710832.0),
#  (u'/organization/austin-ventures', 648334539.0),
#  (u'/organization/deerfield-management', 639008908.0),
#  (u'/organization/qualcomm-ventures', 635298859.0),
#  (u'/organization/us-venture-partners', 630139978.0),
#  (u'/organization/atlas-venture', 626594568.0),
#  (u'/organization/iconiq-capital', 623765472.0),
#  (u'/organization/yf-capital', 612575757.0),
#  (u'/organization/rocket-internet', 601532805.0),
#  (u'/organization/access-industries', 600204169.0),
#  (u'/organization/ekf', 600000000.0),
#  (u'/organization/dag-ventures', 585100382.0),
#  (u'/organization/xiaomi', 576888888.0),
#  (u'/organization/vantagepoint-capital-partners', 576325797.0),
#  (u'/organization/libertymedia', 574416666.0),
#  (u'/organization/deerfield', 571511838.0),
#  (u'/organization/credit-suisse', 570909418.0),
#  (u'/organization/bank-of-america', 570331188.0),
#  (u'/organization/spark-capital', 568865643.0),
#  (u'/organization/inter-atlantic-group', 560891000.0),
#  (u'/organization/qiming-venture-partners', 555866046.0),
#  (u'/organization/mayfield-fund', 555402809.0),
#  (u'/organization/august-capital', 554333394.0),
#  (u'/organization/tpg-growth', 549832318.0),
#  (u'/organization/salesforce-ventures', 549430183.0),
#  (u'/organization/flagship-ventures', 541833383.0),
#  (u'/organization/meritech-capital-partners', 535965063.0),
#  (u'/organization/charles-river-ventures', 528512048.0),
#  (u'/organization/gi-partners', 525000000.0),
#  (u'/organization/first-round-capital', 523147697.0),
#  (u'/organization/bluerun-ventures', 521587937.0),
#  (u'/organization/sofinnova-ventures', 518536462.0),
#  (u'/organization/sv-angel', 514048801.0),
#  (u'/organization/bennett-coleman-and-co-ltd', 506000000.0),
#  (u'/organization/third-rock-ventures', 495784520.0),
#  (u'/organization/morningside-group', 484615286.0),
#  (u'/organization/steadview-capital', 482444444.0),
#  (u'/organization/ignition-partners', 479263038.0),
#  (u'/organization/interwest-partners', 477062472.0),
#  (u'/organization/arch-venture-partners', 466142760.0),
#  (u'/organization/oxford-finance-corporation', 465616592.0),
#  (u'/organization/sherpa-ventures', 465294172.0),
#  (u'/organization/eso-fund', 464225747.0),
#  (u'/organization/business-growth-fund', 460873086.0),
#  (u'/organization/trinity-ventures', 457824320.0),
#  (u'/organization/foxconn-technology-group', 457087499.0),
#  (u'/organization/ra-capital-management', 449238020.0),
#  (u'/organization/adams-street-partners', 446795375.0),
#  (u'/organization/balderton-capital', 445829470.0),
#  (u'/organization/nbcuniversal', 441533333.0),
#  (u'/organization/centerbridge-partners', 441250000.0),
#  (u'/organization/fountainvest-partners', 441000000.0),
#  (u'/organization/deutsche-bank', 439922532.0),
#  (u'/organization/rre-ventures', 436170254.0),
#  (u'/organization/sapphire-ventures', 434948295.0),
#  (u'/organization/matrix-partners-china', 433091570.0),
#  (u'/organization/ctrip', 430000000.0),
#  (u'/organization/mohr-davidow-ventures', 426651738.0),
#  (u'/organization/dfj-growth', 421985212.0),
#  (u'/organization/trident-capital', 420492597.0),
#  (u'/organization/advent-international', 420134240.0),
#  (u'/organization/felicis-ventures', 417129633.0),
#  (u'/organization/abry-partners', 416166666.0),
#  (u'/organization/paladin-capital-group', 415886805.0),
#  (u'/organization/northgate-capital', 414770492.0),
#  (u'/organization/investment-ab-kinnevik', 411773607.0),
#  (u'/organization/kfw-2', 410948097.0),
#  (u'/organization/baillie-gifford', 409179486.0),
#  (u'/organization/artis', 408572256.0),
#  (u'/organization/sutter-hill-ventures', 408256422.0),
#  (u'/organization/llr-partners', 407184819.0),
#  (u'/organization/elevation-partners', 403607142.0),
#  (u'/organization/tiger-fund', 402083333.0),
#  (u'/organization/u-s-bancorp', 399500000.0),
#  (u'/organization/google-capital', 397650790.0),
#  (u'/organization/jmi-equity', 397301701.0),
#  (u'/organization/novo-a-s', 393960551.0),
#  (u'/organization/vulcan-capital', 392023169.0),
#  (u'/organization/monroe-capital', 389972827.0),
#  (u'/organization/abs-capital-partners', 389759999.0),
#  (u'/organization/accelerate-it-ventures', 387270179.0),
#  (u'/organization/eurazeo', 385081000.0),
#  (u'/organization/tencent-industry-win-win-fund', 382289911.0),
#  (u'/organization/baring-private-equity-asia', 381166666.0),
#  (u'/organization/ftv-capital', 378937499.0),
#  (u'/organization/gso-capital-partners', 374734516.0),
#  (u'/organization/kelso-co', 374628835.0),
#  (u'/person/jordan-cohen-2', 374628835.0),
#  (u'/organization/morgenthaler-ventures', 373426189.0),
#  (u'/organization/china-investment-corporation', 373214285.0),
#  (u'/organization/comcast-interactive-capital', 372166277.0),
#  (u'/organization/novartis-venture-fund', 371014647.0),
#  (u'/organization/rho-capital-ventures', 370338166.0),
#  (u'/organization/european-investment-bank', 367337798.0),
#  (u'/organization/times-internet', 366111999.0),
#  (u'/organization/delphi-ventures', 365678725.0),
#  (u'/organization/domain-associates', 365461860.0),
#  (u'/organization/cicc', 363497809.0),
#  (u'/organization/ping-an', 362547618.0),
#  (u'/organization/scale-venture-partners', 361495275.0),
#  (u'/organization/essex-woodlands-health-ventures', 360674857.0),
#  (u'/organization/jefferies-group', 360076923.0),
#  (u'/organization/shasta-ventures', 356851869.0),
#  (u'/organization/valiant-capital-partners', 355887499.0),
#  (u'/organization/hony-capital', 349641288.0),
#  (u'/organization/true-ventures', 347652480.0),
#  (u'/organization/mpm-capital', 344963973.0),
#  (u'/organization/versant-ventures', 344231389.0),
#  (u'/organization/viking-global-investors', 342999479.0),
#  (u'/organization/bdc-venture-capital', 341744089.0),
#  (u'/organization/cross-creek-capital', 338914093.0),
#  (u'/organization/j-p-morgan-securities-inc', 338375184.0),
#  (u'/organization/pharmakon-advisors', 337500000.0),
#  (u'/organization/sigma-partners', 337235240.0),
#  (u'/organization/scottish-equity-partners', 335526766.0),
#  (u'/organization/the-social-capital-partnership', 334884441.0),
#  (u'/organization/new-horizon-capital', 332166666.0),
#  (u'/organization/qatar-investment-authority', 331428571.0),
#  (u'/organization/actis', 327833333.0),
#  (u'/organization/pitango-venture-capital', 327718002.0),
#  (u'/organization/providence-equity-partners', 325000000.0),
#  (u'/organization/fidelity-ventures', 324494096.0),
#  (u'/organization/crosslink-capital', 324072226.0),
#  (u'/organization/tpg', 322961538.0),
#  (u'/organization/northern-light-venture-capital', 322596583.0),
#  (u'/organization/columbia-capital', 322228894.0),
#  (u'/organization/kuwait-investment-authority', 321550000.0),
#  (u'/organization/mithril-capital-management', 321236367.0),
#  (u'/organization/asian-development-bank', 320799327.0),
#  (u'/organization/tenaya-capital', 320365890.0),
#  (u'/organization/thrive-capital', 320065311.0),
#  (u'/organization/johnson-johnson-development-corporation', 318586445.0),
#  (u'/organization/cisco', 318213908.0),
#  (u'/organization/sofinnova-partners', 314275939.0),
#  (u'/organization/square-1-bank', 313639997.0),
#  (u'/organization/wellington-partners', 313394753.0),
#  (u'/organization/quadrangle', 311666666.0),
#  (u'/organization/woodford-investment-management', 310953405.0),
#  (u'/organization/investor-growth-capital', 310764069.0),
#  (u'/organization/atlantic-capital-partners', 308787990.0),
#  (u'/organization/sv-life-sciences', 307213164.0),
#  (u'/organization/wellcome-trust', 306292402.0),
#  (u'/organization/comerica-bank', 306073203.0),
#  (u'/organization/nokia-growth-partners', 302341673.0),
#  (u'/organization/fidelity-biosciences', 302095027.0),
#  (u'/organization/dragoneer-investment-group', 297833570.0),
#  (u'/organization/gsr-ventures-management', 297492282.0),
#  (u'/organization/ardian', 295911423.0),
#  (u'/organization/maverick-capital', 295700905.0),
#  (u'/organization/western-technology-investment', 295178996.0),
#  (u'/organization/gic', 294150694.0),
#  (u'/organization/new-leaf-venture-partners', 292733576.0),
#  (u'/organization/general-electric', 292594229.0),
#  (u'/organization/globespan-capital-partners', 291027093.0),
#  (u'/organization/greycroft-partners', 290091076.0),
#  (u'/organization/capital-royalty', 287166666.0),
#  (u'/organization/ontario-teachers-pension-plan', 286349386.0),
#  (u'/organization/capital-international-private-equity-fund', 285714285.0),
#  (u'/organization/idinvest-partners', 283864820.0),
#  (u'/organization/advanced-technology-ventures', 283801460.0),
#  (u'/organization/vostok-nafta-investment', 283366936.0),
#  (u'/organization/national-institutes-of-health', 283064666.0),
#  (u'/organization/sig-china', 280848903.0),
#  (u'/organization/vista-equity-partners', 280833333.0),
#  (u'/organization/foundry-group', 280600992.0),
#  (u'/organization/legend-capital', 278770054.0),
#  (u'/organization/atomico', 278315224.0),
#  (u'/organization/blackstone-group', 278074284.0),
#  (u'/organization/samsung-ventures', 276952522.0),
#  (u'/organization/intel', 275051624.0),
#  (u'/organization/invesco-perpetual', 275002377.0),
#  (u'/person/peter-thiel', 274786031.0),
#  (u'/organization/greenspring-associates', 274276751.0),
#  (u'/organization/edison-ventures', 273554762.0),
#  (u'/organization/sierra-ventures', 273398613.0),
#  (u'/organization/cabiedes-partners', 271800889.0),
#  (u'/organization/union-square-ventures', 271570220.0),
#  (u'/organization/ge-energy-financial-services', 270724999.0),
#  (u'/organization/wells-fargo-bank', 270110255.0),
#  (u'/organization/qualcomm', 268411417.0),
#  (u'/organization/horizons-ventures', 267745149.0),
#  (u'/organization/emergence-capital-partners', 267411383.0),
#  (u'/organization/lone-pine-capital', 267272727.0),
#  (u'/organization/stone-point-capital', 266700000.0),
#  (u'/organization/cmea-capital', 266275273.0),
#  (u'/organization/fondo-italiano-di-investimento', 266132000.0),
#  (u'/organization/viola-credit', 266045938.0),
#  (u'/organization/crunchfund', 265870902.0),
#  (u'/organization/third-point-ventures', 264877622.0),
#  (u'/organization/valor-equity-partners', 264833333.0),
#  (u'/organization/safeguard-scientifics', 264674747.0),
#  (u'/organization/celgene', 264015738.0),
#  (u'/organization/macquarie-capital-funds', 263903372.0),
#  (u'/organization/cit-group', 259783333.0),
#  (u'/organization/iconventures', 259698854.0),
#  (u'/organization/alloy-ventures', 259563134.0),
#  (u'/organization/invus', 256516930.0),
#  (u'/organization/northzone-ventures', 256495423.0),
#  (u'/organization/naspers', 255750000.0),
#  (u'/organization/peak-capital', 252463637.0),
#  (u'/organization/madrona-venture-group', 252457224.0),
#  (u'/organization/keybank', 251833333.0),
#  (u'/organization/auriga-partners', 251716008.0),
#  (u'/organization/partech-international', 251277077.0),
#  (u'/organization/mitsui-ventures', 250661659.0),
#  (u'/organization/a-e-television-networks', 250000000.0),
#  (u'/organization/pag-asia-capital', 250000000.0),
#  (u'/organization/brighthouse-inc', 250000000.0),
#  (u'/organization/riverwood-capital', 249937644.0),
#  (u'/organization/updata-partners', 249359521.0),
#  (u'/organization/lime-rock-partners', 248875000.0),
#  (u'/organization/bpifrance', 248680530.0),
#  (u'/organization/advanced-equities', 246498570.0),
#  (u'/organization/marker', 245420949.0),
#  (u'/organization/gsv-capital', 245298987.0),
#  (u'/organization/capitalsource', 244333333.0),
#  (u'/organization/in-q-tel', 244264820.0),
#  (u'/organization/golub-capital', 243171428.0),
#  (u'/organization/frontier-capital', 242059675.0),
#  (u'/organization/alibaba-capital-partners', 241211355.0),
#  (u'/organization/glynn-capital-management', 240490160.0),
#  (u'/organization/greylock-partners-israel', 238621026.0),
#  (u'/organization/jd-com', 235633333.0),
#  (u'/organization/clarus-ventures', 235132118.0),
#  (u'/organization/firstmark-capital', 235088664.0),
#  (u'/organization/forest-laboratories', 235000000.0),
#  (u'/organization/flybridge-capital', 233615035.0),
#  (u'/organization/allen-and-company', 233008663.0),
#  (u'/organization/kennet-venture-partners', 230837813.0),
#  (u'/organization/sofina', 230302784.0),
#  (u'/organization/qed-investors', 230279179.0),
#  (u'/organization/aeris-capital', 230035495.0),
#  (u'/organization/triplepoint-capital', 229809774.0),
#  (u'/organization/citic-capital-holdings', 229391304.0),
#  (u'/organization/split-rock-partners', 229274774.0),
#  (u'/organization/pinnacle-ventures', 228690403.0),
#  (u'/organization/frazier-healthcare-ventures', 228262281.0),
#  (u'/organization/brookside-capital', 227667757.0),
#  (u'/organization/helios-investment-partners', 226000000.0),
#  (u'/organization/triangle-peak-partners', 225044719.0),
#  (u'/organization/glaxosmithkline', 224148224.0),
#  (u'/organization/bay-partners', 223135084.0),
#  (u'/organization/abingworth-management', 223044787.0),
#  (u'/organization/altamont-capital-partners', 222000000.0),
#  (u'/organization/government-of-singapore-investment-corporation-gic',
#   221857142.0),
#  (u'/organization/fortress-investment-group', 221130951.0),
#  (u'/organization/danish-pension-fund', 220000000.0),
#  (u'/organization/rbc-capital-markets', 219727822.0),
#  (u'/organization/nexus-venture-partners', 219703438.0),
#  (u'/organization/susquehanna-growth-equity', 217328570.0),
#  (u'/organization/rock-springs-capital', 216013346.0),
#  (u'/organization/catterton-partners', 215749476.0),
#  (u'/organization/rockport-capital-partners', 215509043.0),
#  (u'/organization/malin-corporation', 215166666.0),
#  (u'/organization/aisling-capital', 212997249.0),
#  (u'/organization/lvmh', 210420000.0),
#  (u'/organization/openview-venture-partners', 210126189.0),
#  (u'/organization/sr-one', 210073333.0),
#  (u'/organization/suning', 210000000.0),
#  (u'/organization/bay-city-capital', 207115752.0),
#  (u'/organization/e-ventures', 205695687.0),
#  (u'/organization/yuan-capital', 205500533.0),
#  (u'/organization/overseas-private-investment-corp', 205000000.0),
#  (u'/organization/vertex-venture-capital', 204394659.0),
#  (u'/organization/carmel-ventures', 203553165.0),
#  (u'/organization/octopus-ventures', 202876325.0),
#  (u'/organization/tengelmann-ventures', 202425073.0),
#  (u'/organization/gimv', 202129507.0),
#  (u'/organization/edmond-de-rothschild-venture-capital', 201486189.0),
#  (u'/organization/comcast', 200916666.0),
#  (u'/organization/rustic-canyon-partners', 200220454.0),
#  (u'/organization/allscripts', 200000000.0),
#  (u'/organization/permira', 200000000.0),
#  (u'/organization/foxconn-international-holdings', 200000000.0),
#  (u'/organization/queensbridge-venture-partners', 199877134.0),
#  (u'/organization/cbc-capital', 199655222.0),
#  (u'/organization/yahoo', 199349585.0),
#  (u'/organization/ceyuan-ventures', 199280371.0),
#  (u'/organization/capricorn-investment-group', 199088243.0),
#  (u'/organization/slow-ventures', 198998609.0),
#  (u'/organization/hummer-winblad-venture-partners', 198595456.0),
#  (u'/organization/energy-capital-partners', 198335227.0),
#  (u'/organization/asset-management-ventures', 198273368.0),
#  (u'/organization/idg-ventures-usa', 196577203.0),
#  (u'/organization/highland-capital-partners-europe', 196456989.0),
#  (u'/organization/omidyar-network', 195770060.0),
#  (u'/organization/revolution', 195073801.0),
#  (u'/organization/eagle-river-holdings', 194000000.0),
#  (u'/organization/apax-partners', 193843900.0),
#  (u'/organization/timewarner', 193691666.0),
#  (u'/organization/500-startups', 192965541.0),
#  (u'/organization/innovation-department-2', 192884583.0),
#  (u'/organization/greenoaks-capital-management', 191460973.0),
#  (u'/organization/amadeus-capital-partners', 190227733.0),
#  (u'/organization/renren-inc', 190138888.0),
#  (u'/organization/pritzker-group-venture-capital', 190102149.0),
#  (u'/organization/bezos-expeditions', 189829361.0),
#  (u'/organization/t-venture', 189479523.0),
#  (u'/organization/osage-university-partners', 188359192.0),
#  (u'/organization/kingsoft', 186166666.0),
#  (u'/organization/artiman-ventures', 185404300.0),
#  (u'/organization/arrowpoint-partners', 185285713.0),
#  (u'/organization/birchmere-ventures', 184001332.0),
#  (u'/organization/fidelity-growth-partners-asia', 183586664.0),
#  (u'/organization/stripes-group', 182718332.0),
#  (u'/organization/granite-ventures', 182032935.0),
#  (u'/organization/storm-ventures', 181837037.0),
#  (u'/organization/apex-venture-partners', 180216901.0),
#  (u'/organization/capital-today', 179922700.0),
#  (u'/organization/omnes-capital', 179831690.0),
#  (u'/organization/tvm-capital', 179814410.0),
#  (u'/organization/grotech-ventures', 179687439.0),
#  (u'/organization/siemens-venture-capital', 179674018.0),
#  (u'/organization/texas-pacific-group', 179456740.0),
#  (u'/organization/wi-harper-group', 179412184.0),
#  (u'/organization/american-capital', 178990000.0),
#  (u'/organization/imperial-innovations', 178641668.0),
#  (u'/organization/nelnet', 178083213.0),
#  (u'/organization/lehman-brothers', 178005988.0),
#  (u'/organization/sevin-rosen-funds', 177783774.0),
#  (u'/organization/upfront-ventures', 177742698.0),
#  (u'/organization/floodgate', 177661577.0),
#  (u'/organization/iris-capital', 177316122.0),
#  (u'/organization/formation8', 177055565.0),
#  (u'/organization/suzhou-high-tech-venture-capital-group', 177000000.0),
#  (u'/organization/citic-pe', 176315269.0),
#  (u'/organization/rabobank', 176121621.0),
#  (u'/organization/newspring-capital', 175733103.0),
#  (u'/organization/ventech-capital', 175655109.0),
#  (u'/organization/inovia-capital', 173737287.0),
#  (u'/organization/ge-ventures', 173180484.0),
#  (u'/organization/brown-brothers-harriman', 172408333.0),
#  (u'/organization/ame-cloud-ventures', 171735113.0),
#  (u'/organization/steamboat-ventures', 171049141.0),
#  (u'/organization/intersouth-partners', 170797016.0),
#  (u'/organization/capstone-partners-korea', 170242313.0),
#  (u'/organization/passport-capital', 169852161.0),
#  (u'/organization/jafco-asia', 169313518.0),
#  (u'/organization/european-union', 168918450.0),
#  (u'/organization/shamrock-capital-advisors', 168888888.0),
#  (u'/organization/chrysalix-energy', 167564679.0),
#  (u'/organization/novo-ventures', 167262793.0),
#  (u'/organization/gemini-israel-funds', 165778568.0),
#  (u'/organization/fidelity-management-research', 165314680.0),
#  (u'/organization/hsbc', 165047661.0),
#  (u'/organization/pdl-biopharma', 165000000.0),
#  (u'/organization/azure-capital-partners', 163515203.0),
#  (u'/organization/carrick-capital-partners', 162611333.0),
#  (u'/organization/suntrust-bank', 162454761.0),
#  (u'/organization/pfizer-venture-investments', 161875218.0),
#  (u'/organization/rakuten', 161694998.0),
#  (u'/organization/blackpine-private-equity-partners', 161666666.0),
#  (u'/organization/china-international-capital-corporation-2', 161666666.0),
#  (u'/organization/milestone-capital-china', 161426148.0),
#  (u'/organization/redmile-group', 161072332.0),
#  (u'/organization/helion-venture-partners', 160924388.0),
#  (u'/organization/valhalla-partners', 160841660.0),
#  (u'/organization/walden-international', 160572830.0),
#  (u'/organization/epic-ventures', 160503736.0),
#  (u'/organization/5am-ventures', 160210001.0),
#  (u'/organization/bank-street-group', 160000000.0),
#  (u'/organization/motorola-solutions-venture-capital', 159793613.0),
#  (u'/organization/data-collective', 159757303.0),
#  (u'/organization/prime-technology-ventures', 159302555.0),
#  (u'/organization/proquest-investments', 158735085.0),
#  (u'/organization/maveron', 158596996.0),
#  (u'/organization/lerer-ventures', 158538393.0),
#  (u'/organization/avalon-ventures', 158413912.0),
#  (u'/organization/gilde-healthcare-partners', 158324436.0),
#  (u'/organization/lightspeed-china-partners', 158234998.0),
#  (u'/organization/baird-capital', 157915901.0),
#  (u'/organization/focus-ventures', 157810573.0),
#  (u'/organization/good-energies', 157801232.0),
#  (u'/organization/onset-ventures', 156984608.0),
#  (u'/organization/bill-melinda-gates-foundation', 156253500.0),
#  (u'/organization/time-warner-investments', 155867185.0),
#  (u'/organization/trustbridge-partners', 155783332.0),
#  (u'/organization/advantage-capital-partners', 155122067.0),
#  (u'/organization/ppm-america-capital-partners', 154999999.0),
#  (u'/organization/baseline-ventures', 154284578.0),
#  (u'/organization/york-capital-management', 154033333.0),
#  (u'/organization/rit-capital-partners', 153580627.0),
#  (u'/organization/h-capital', 153333333.0),
#  (u'/organization/horizon-ventures', 153331779.0),
#  (u'/organization/sands-capital-ventures', 153044019.0),
#  (u'/organization/sterling-partners', 152916666.0),
#  (u'/organization/denovo-ventures', 152894060.0),
#  (u'/organization/soros-fund-management', 152791252.0),
#  (u'/organization/lowercase-capital', 152356322.0),
#  (u'/organization/bregal-sagemount', 152166666.0),
#  (u'/organization/pearson', 152126428.0),
#  (u'/organization/hearst-ventures', 152003873.0),
#  (u'/organization/sovereign-wealth-funds', 151350000.0),
#  (u'/organization/high-tech-gruenderfonds', 150620154.0),
#  (u'/person/randal-j-kirk', 150000000.0),
#  (u'/organization/azimuth-opportunity', 150000000.0),
#  (u'/organization/advent-venture-partners', 149804169.0),
#  (u'/organization/draper-esprit', 149452915.0),
#  (u'/organization/kite-ventures', 149430065.0),
#  (u'/organization/ngen-ventures', 148865546.0),
#  (u'/organization/dn-capital', 147577924.0),
#  (u'/organization/healthcare-royalty-partners', 146833333.0),
#  (u'/organization/cerberus-capital-management', 146333333.0),
#  (u'/organization/quantum-strategic-partners', 146000000.0),
#  (u'/organization/healthcare-ventures', 145826634.0),
#  (u'/person/yuri-milner', 145047459.0),
#  (u'/organization/industrifonden', 144867381.0),
#  (u'/organization/technology-partners', 144791828.0),
#  (u'/organization/kodiak-venture-partners', 144088330.0),
#  (u'/organization/prospect-venture-partners', 144087794.0),
#  (u'/organization/premjiinvest', 143814635.0),
#  (u'/organization/wpp', 143743330.0),
#  (u'/organization/foresite-capital', 143493311.0),
#  (u'/organization/ribbit-capital', 143371606.0),
#  (u'/organization/parkwalk-advisors', 142877972.0),
#  (u'/organization/toyota-tsusho', 142700000.0),
#  (u'/organization/banyan-capital-partners', 142520000.0),
#  (u'/organization/thomas-mcnerney-partners', 142348569.0),
#  (u'/organization/harbert-venture-partners', 141996149.0),
#  (u'/organization/pelion-venture-partners', 141778122.0),
#  (u'/organization/ge-capitals-healthcare-financial-services', 141500000.0),
#  (u'/organization/wistron-corporation', 141475000.0),
#  (u'/organization/paulson-co', 141250000.0),
#  (u'/person/jim-donald', 141250000.0),
#  (u'/organization/tiantu-capital', 140436709.0),
#  (u'/organization/pacific-corporate-group', 140289166.0),
#  (u'/organization/lux-capital', 139955851.0),
#  (u'/organization/lead-edge-capital', 139853444.0),
#  (u'/organization/d-e-shaw-co', 139765127.0),
#  (u'/organization/kaiser-permanente-ventures', 139687540.0),
#  (u'/organization/industry-ventures', 139622950.0),
#  (u'/organization/fountain-healthcare-partners', 139280378.0),
#  (u'/organization/americanexpress', 139120830.0),
#  (u'/organization/correlation-ventures', 138910139.0),
#  (u'/organization/morgan-stanley-venture-partners', 138812220.0),
#  (u'/organization/xange-private-equity', 138259831.0),
#  (u'/organization/blumberg-capital', 138191787.0),
#  (u'/organization/citi-ventures', 138186353.0),
#  (u'/organization/bertelsmann-asia-investment-fund', 137999998.0),
#  (u'/organization/earlybird-venture-capital', 137834658.0),
#  (u'/organization/bank-of-america-merrill-lynch', 137700000.0),
#  (u'/organization/trinity-capital-investment', 137050000.0),
#  (u'/organization/hsbc-principal-investments', 136961666.0),
#  (u'/organization/opus-capital', 136693051.0),
#  (u'/organization/m-c-partners', 136299999.0),
#  (u'/organization/tomorrow-ventures', 135497091.0),
#  (u'/organization/harrison-metal', 135285087.0),
#  (u'/organization/ata-ventures', 135259040.0),
#  (u'/organization/sunstone-capital', 135170080.0),
#  (u'/organization/toba-capital', 135164672.0),
#  (u'/organization/pequot-capital', 135133161.0),
#  (u'/organization/jefferies-company', 135053333.0),
#  (u'/organization/canso-investment-counsel', 135000000.0),
#  (u'/organization/great-oaks-venture-capital', 134595438.0),
#  (u'/organization/madrone-capital-partners', 134118570.0),
#  (u'/organization/eli-lilly', 133999999.0),
#  (u'/organization/starvest-partners', 133920211.0),
#  (u'/organization/glade-brook-capital-partners', 133699999.0),
#  (u'/organization/softtech-vc', 133446944.0),
#  (u'/organization/new-york-life-capital-partners', 133333333.0),
#  (u'/organization/bank-of-tokyo-mitsubishi-ufj', 133333333.0),
#  (u'/organization/natixis', 133333333.0),
#  (u'/organization/orix-venture-finance', 133250000.0),
#  (u'/organization/tokyo-electric-power', 133200000.0),
#  (u'/organization/vivo-ventures', 133002850.0),
#  (u'/organization/harbinger-capital-partners', 133000000.0),
#  (u'/organization/life-sciences-partners', 132921457.0),
#  (u'/organization/el-dorado-ventures', 132893428.0),
#  (u'/organization/pappas-ventures', 132723108.0),
#  (u'/organization/spectrum-assets', 132500000.0),
#  (u'/organization/vision-knight-capital', 132300000.0),
#  (u'/organization/jerusalem-venture-partners', 131964699.0),
#  (u'/organization/triangle-capital-corporation', 131683363.0),
#  (u'/organization/jk-b-capital', 131631045.0),
#  (u'/organization/tpg-biotech', 130802069.0),
#  (u'/organization/viola-private-equity', 130642857.0),
#  (u'/organization/hlm-venture-partners', 130546763.0),
#  (u'/organization/aslanoba-capital', 130192829.0),
#  (u'/organization/partners-group', 130166666.0),
#  (u'/organization/marubeni-corporation', 130060000.0),
#  (u'/organization/netmarble', 130000000.0),
#  (u'/organization/oxford-bioscience-partners', 129925932.0),
#  (u'/organization/vertex-venture-holdings', 129535704.0),
#  (u'/organization/dcm-ventures', 129286190.0),
#  (u'/organization/questmark', 129143414.0),
#  (u'/organization/china-broadband-capital', 128884615.0),
#  (u'/organization/infinity', 128816304.0),
#  (u'/organization/forbion-capital-partners', 128488286.0),
#  (u'/organization/hbm-bioventures', 128481718.0),
#  (u'/organization/braemar-energy-ventures', 128462764.0),
#  (u'/organization/seventure-partners', 127674884.0),
#  (u'/person/elon-musk', 127671929.0),
#  (u'/organization/holtzbrinck-ventures', 126840458.0),
#  (u'/organization/novartis', 126554040.0),
#  (u'/organization/haitong-international-securities-group', 126000000.0),
#  (u'/organization/albright-capital-management', 126000000.0),
#  (u'/organization/yorkville-advisors', 125913952.0),
#  (u'/organization/mangrove-capital-partners', 125845971.0),
#  (u'/organization/omers-ventures', 125575016.0),
#  (u'/organization/genesis-partners', 125510707.0),
#  (u'/organization/espirito-santo-ventures', 125245560.0),
#  (u'/organization/equis-capital-partners', 125000000.0),
#  (u'/organization/main-street-capital', 124899999.0),
#  (u'/organization/quaker-bioventures', 124897169.0),
#  (u'/organization/dievini-hopp-biotech-holding', 124401389.0),
#  (u'/organization/adage-capital-management', 124283394.0),
#  (u'/organization/kyowa-hakko-kirin', 124000000.0),
#  (u'/organization/boxgroup', 123647434.0),
#  (u'/organization/jennison-associates', 123505072.0),
#  (u'/organization/rho-ventures', 122504744.0),
#  (u'/organization/parthenon-capital-partners', 122435896.0),
#  (u'/organization/kortschak-investments-l-p', 122327895.0),
#  (u'/organization/comvest-group', 122033333.0),
#  (u'/organization/ovp-venture-partners', 121831883.0),
#  (u'/organization/h-i-g-ventures', 121447819.0),
#  (u'/organization/altpoint-ventures', 120016184.0),
#  (u'/organization/sorenson-capital', 119950000.0),
#  (u'/organization/orchid-asia-group-management', 119756639.0),
#  (u'/organization/river-cities-capital', 118720920.0),
#  (u'/organization/verlinvest', 118282091.0),
#  (u'/organization/eastern-capital', 118108333.0),
#  (u'/organization/three-arch-partners', 118080177.0),
#  (u'/organization/welsh-carson-anderson-stowe', 118033332.0),
#  (u'/organization/bright-capital', 118017758.0),
#  (u'/organization/shunwei-china-internet-fund', 118014356.0),
#  (u'/organization/commonwealth-capital-ventures', 117975114.0),
#  (u'/organization/tallwood-venture-capital', 117870998.0),
#  (u'/organization/medimmune-ventures', 117830197.0),
#  (u'/organization/horizon-technology-finance', 117650000.0),
#  (u'/organization/sierra-maya-ventures', 117362249.0),
#  (u'/organization/innovation-endeavors', 117238221.0),
#  (u'/organization/midcap-financial', 117199999.0),
#  (u'/organization/glg-partners', 117150941.0),
#  (u'/organization/pnc-bank', 117000000.0),
#  (u'/organization/saints-capital', 116938406.0),
#  (u'/organization/mitsui', 116729269.0),
#  (u'/organization/the-westly-group', 116645781.0),
#  (u'/organization/innovacom', 116614292.0),
#  (u'/organization/activant-capital', 116451300.0),
#  (u'/organization/phenomen-ventures-fund', 115951910.0),
#  (u'/organization/atlantic-bridge', 115658699.0),
#  (u'/organization/virgin-group', 115125000.0),
#  (u'/organization/paul-capital-healthcare', 114838800.0),
#  (u'/organization/aequitas-capital', 114527827.0),
#  (u'/organization/element-partners', 114366664.0),
#  (u'/organization/inventages-venture-capital-investment-inc', 114363698.0),
#  (u'/organization/newmargin-growth-fund', 114361447.0),
#  (u'/organization/alaska-permanent-fund', 114250000.0),
#  (u'/organization/lurie-investment-fund', 113677776.0),
#  (u'/organization/beringea', 113605075.0),
#  (u'/organization/st-jude-medical', 113333333.0),
#  (u'/organization/novak-biddle-venture-partners', 113321506.0),
#  (u'/organization/allegis-capital', 113009892.0),
#  (u'/organization/panorama-capital', 112841297.0),
#  (u'/person/steve-case', 112805759.0),
#  (u'/organization/cougar-capital', 112732573.0),
#  (u'/organization/valar-ventures', 112411109.0),
#  (u'/organization/prism-venture-management', 112207011.0),
#  (u'/organization/idg-ventures-india', 112103332.0),
#  (u'/organization/aberdare-ventures', 111957156.0),
#  (u'/organization/legg-mason', 111749999.0),
#  (u'/organization/gobi-partners', 111323192.0),
#  (u'/organization/european-bank-for-reconstruction-and-development-ebrd',
#   111216665.0),
#  (u'/organization/aquiline-capital-partners', 111040000.0),
#  (u'/organization/capital-group', 110384847.0),
#  (u'/organization/harris-harris-group', 110324008.0),
#  (u'/organization/longitude-capital', 110219713.0),
#  (u'/organization/total-energy-ventures-international', 110050626.0),
#  (u'/organization/athyrium-opportunities-fund', 110000000.0),
#  (u'/person/bill-gates', 109538932.0),
#  (u'/organization/barclays-capital', 109524000.0),
#  (u'/organization/mission-ventures', 109504528.0),
#  (u'/organization/relay-ventures', 109300814.0),
#  (u'/organization/obvious-ventures', 109296029.0),
#  (u'/organization/bridge-bank', 109166666.0),
#  (u'/organization/telstra-ventures', 108794557.0),
#  (u'/organization/chevron-technology-ventures', 108440413.0),
#  (u'/organization/roche-venture-fund', 108364425.0),
#  (u'/person/fabrice-grinda', 108347828.0),
#  (u'/organization/alliancebernstein', 108089922.0),
#  (u'/organization/fontinalis-partners', 108047000.0),
#  (u'/organization/406-ventures', 107930235.0),
#  (u'/organization/kddi', 107878738.0),
#  (u'/organization/alven-capital', 107877663.0),
#  (u'/organization/great-point-partners', 107624205.0),
#  (u'/organization/21st-century-fox', 107500000.0),
#  (u'/organization/newscorporation', 107481376.0),
#  (u'/organization/noro-moseley-partners', 107467377.0),
#  (u'/organization/lilly-ventures', 107437304.0),
#  (u'/organization/new-science-ventures', 107075445.0),
#  (u'/organization/doughty-hanson-technology-ventures', 106741892.0),
#  (u'/organization/the-world-bank-group', 106250000.0),
#  (u'/organization/catalyst-investors', 106025000.0),
#  (u'/organization/vy-capital', 105666665.0),
#  (u'/organization/mousse-partners', 105562816.0),
#  (u'/organization/mci-management', 105468124.0),
#  (u'/organization/bertelsmann-digital-media-investments', 105302089.0),
#  (u'/organization/lakestar', 105227585.0),
#  (u'/organization/morningside-private-investors', 105100000.0),
#  (u'/organization/disruptive', 104833333.0),
#  (u'/organization/tennenbaum-capital-partners', 104833333.0),
#  (u'/organization/o-reilly-alphatech-ventures', 104795154.0),
#  (u'/organization/s3-ventures', 104765301.0),
#  (u'/organization/investcorp-gulf-investments', 104746545.0),
#  (u'/organization/investcorp-technology-partners', 104729934.0),
#  (u'/person/li-ka-shing', 104670237.0),
#  (u'/organization/ff-venture-capital', 104056751.0),
#  (u'/organization/idealab', 104013623.0),
#  (u'/organization/innovation-works', 103960446.0),
#  (u'/organization/peacock-equity', 103727330.0),
#  (u'/organization/medtronic', 103602206.0),
#  (u'/organization/china-fintech-fund', 103500000.0),
#  (u'/organization/standard-chartered-bank', 103500000.0),
#  (u'/organization/maryland-venture-fund', 103016355.0),
#  (u'/organization/migdal-insurance-and-financial-holdings-ltd', 102925000.0),
#  (u'/organization/y-combinator', 102903249.0),
#  (u'/organization/rembrant-venture-partners', 102865183.0),
#  (u'/organization/mobius-venture-capital', 102445492.0),
#  (u'/organization/israel-corp', 102285714.0),
#  (u'/organization/tesco', 101925143.0),
#  (u'/organization/piton-capital', 101741812.0),
#  (u'/organization/u-s-navy', 101500000.0),
#  (u'/organization/sina-weibo', 101457251.0),
#  (u'/organization/lundbeckfond-ventures', 101075581.0),
#  (u'/organization/shea-ventures', 101047022.0),
#  (u'/organization/recruit-holdings', 101011436.0),
#  (u'/organization/volition-capital', 100512221.0),
#  (u'/organization/ebay', 100490276.0),
#  (u'/organization/access-bridgegap-ventures', 100048682.0),
#  (u'/organization/israel-discount-bank', 100000000.0),
#  (u'/organization/all-stars-investment', 100000000.0),
#  (u'/organization/united-mizrahi-bank', 100000000.0),
#  (u'/organization/lovell-minnick-partners', 100000000.0),
#  (u'/organization/kunlun-worldwide', 100000000.0),
#  (u'/organization/the-ascott', 100000000.0),
#  (u'/organization/union-bank-of-israel', 100000000.0),
#  (u'/organization/scottish-investment-bank', 99953282.0),
#  (u'/organization/translink-capital', 99478541.0),
#  (u'/organization/sanderling-ventures', 99431285.0),
#  (u'/organization/odey-asset-management', 99241871.0),
#  (u'/organization/zouk-capital', 99227664.0),
#  (u'/organization/fonds-de-solidarit-ftq', 99076010.0),
#  (u'/organization/fifth-street-technology-partners', 99000000.0),
#  (u'/organization/blue-chip-venture-company', 98890661.0),
#  (u'/organization/entrepreneurs-fund', 98856711.0),
#  (u'/organization/giza-venture-capital', 98830912.0),
#  (u'/organization/burrill-co', 98786709.0),
#  (u'/organization/tudor-investments', 98552331.0),
#  (u'/organization/four-rivers-group', 98425001.0),
#  (u'/organization/the-column-group', 98333491.0),
#  (u'/organization/falcon-edge-capital', 98333333.0),
#  (u'/organization/lansdowne-partners', 98164194.0),
#  (u'/organization/almaz-capital', 98149163.0),
#  (u'/organization/creandum', 98041648.0),
#  (u'/organization/the-vertical-group', 97858973.0),
#  (u'/organization/northwater-capital', 97816665.0),
#  (u'/organization/healthcap', 97323267.0),
#  (u'/organization/genentech', 97250000.0),
#  (u'/organization/the-dow-chemical-company', 97146654.0),
#  (u'/organization/kalaari-capital', 96911699.0),
#  (u'/organization/growthworks', 96684431.0),
#  (u'/organization/reed-elsevier', 96471476.0),
#  (u'/organization/vtb-capital', 96384323.0),
#  (u'/organization/draper-nexus-ventures', 96255340.0),
#  (u'/organization/evergreen-venture-partners', 96107140.0),
#  (u'/organization/dawn-capital', 96017826.0),
#  (u'/organization/htc', 96000000.0),
#  (u'/organization/palomar-ventures', 95544469.0),
#  (u'/organization/voyager-capital', 95521452.0),
#  (u'/organization/th-lee-putnam-ventures', 95399473.0),
#  (u'/organization/tl-ventures', 95377614.0),
#  (u'/organization/centennial-ventures', 95209796.0),
#  (u'/organization/kfw', 95048820.0),
#  (u'/organization/tiger-management-corporation', 95000000.0),
#  (u'/organization/crystal-financial', 95000000.0),
#  (u'/organization/eqt-holdings', 94945000.0),
#  (u'/organization/singtel-innov8', 94940460.0),
#  (u'/organization/venbio', 94705807.0),
#  (u'/organization/wellington-financial', 94483333.0),
#  (u'/organization/nea-indous-ventures', 94483331.0),
#  (u'/organization/usaa', 94270344.0),
#  (u'/organization/chengwei-capital', 93606087.0),
#  (u'/organization/daimler', 93393614.0),
#  (u'/organization/thomvest-ventures', 93285524.0),
#  (u'/organization/kreos-capital', 93275091.0),
#  (u'/organization/claremont-creek-ventures', 93264163.0),
#  (u'/organization/altimeter-capital', 93249998.0),
#  (u'/organization/founder-collective', 92936947.0),
#  (u'/organization/sageview-capital', 92591666.0),
#  (u'/organization/skyline-ventures', 92567118.0),
#  (u'/organization/adams-capital-management', 92462499.0),
#  (u'/organization/altos-ventures', 92070402.0),
#  (u'/organization/lighthouse-capital-partners', 91866752.0),
#  (u'/organization/merck-global-health-innovation-fund', 91794045.0),
#  (u'/organization/new-atlantic-ventures', 91551547.0),
#  (u'/organization/itochu-corporation', 91520472.0),
#  (u'/organization/emc', 91505950.0),
#  (u'/organization/integral-capital-partners', 91489481.0),
#  (u'/organization/discovery-capital', 91412758.0),
#  (u'/organization/sprint-nextel', 91305000.0),
#  (u'/organization/baring-vostok-capital-partners', 91250000.0),
#  (u'/organization/easton-capital', 90899309.0),
#  (u'/organization/illuminate-ventures', 90628639.0),
#  (u'/organization/topspin-partners', 90524830.0),
#  (u'/organization/praesidian-capital', 90479338.0),
#  (u'/organization/ut-horizon-fund', 90098060.0),
#  (u'/organization/allied-capital', 90000000.0),
#  (u'/organization/sig', 89983331.0),
#  (u'/organization/javelin-venture-partners', 89795556.0),
#  (u'/organization/wayra', 89775954.0),
#  (u'/organization/montreaux-equity-partners', 89641729.0),
#  (u'/organization/rose-park-advisors', 89574602.0),
#  (u'/organization/black-river', 89416665.0),
#  (u'/organization/janus-capital-group', 89388948.0),
#  (u'/person/gordon-crawford', 89363074.0),
#  (u'/organization/runa-capital', 89108695.0),
#  (u'/organization/ru-net-holdings', 89104332.0),
#  (u'/organization/ia-ventures', 88998480.0),
#  (u'/organization/accel-kkr', 88979995.0),
#  (u'/organization/zhenfund', 88759065.0),
#  (u'/organization/ecor1-capital', 88637515.0),
#  (u'/organization/arboretum-ventures', 88605475.0),
#  (u'/organization/smedvig-capital', 88563386.0),
#  (u'/person/vinod-khosla', 88230262.0),
#  (u'/organization/wing-venture-capital', 88123408.0),
#  (u'/organization/dbl-investors', 87828568.0),
#  (u'/organization/latterell-venture-partners', 87701291.0),
#  (u'/organization/scentan-ventures', 87574545.0),
#  (u'/organization/draper-associates-2', 87505526.0),
#  (u'/organization/amazon', 86797108.0),
#  (u'/organization/deutsche-china-capital', 86666666.0),
#  (u'/organization/cedar-fund', 86633042.0),
#  (u'/organization/apple-tree-partners', 86617061.0),
#  (u'/organization/kayne-partners', 86400000.0),
#  (u'/organization/cathaya-capital', 85769865.0),
#  (u'/organization/gold-hill-capital', 85257418.0),
#  (u'/organization/nauta-capital', 85185531.0),
#  (u'/organization/luxor-capital-group', 85000000.0),
#  (u'/organization/standard-general-llp', 85000000.0),
#  (u'/organization/comventures', 84841664.0),
#  (u'/person/ron-conway', 84775771.0),
#  (u'/organization/wanda-group', 84700000.0),
#  (u'/organization/m7-tech-partners-llc', 84445890.0),
#  (u'/organization/viola-partners', 84385714.0),
#  (u'/organization/olympus-capital-holdings-asia', 84333333.0),
#  (u'/organization/gabriel-venture-partners', 84281242.0),
#  (u'/organization/longworth-venture-partners', 84010811.0),
#  (u'/organization/clearstone-venture-partners', 83977635.0),
#  (u'/organization/abs-ventures', 83972499.0),
#  (u'/organization/oak-hc-ft-partners', 83934972.0),
#  (u'/organization/government-investment-funds', 83850000.0),
#  (u'/organization/harmony-partners', 83837986.0),
#  (u'/organization/serena-capital', 83809080.0),
#  (u'/organization/mk-capital', 83775425.0),
#  (u'/organization/perceptive-advisors', 83611072.0),
#  (u'/organization/nokia', 83558035.0),
#  (u'/organization/village-ventures', 83458886.0),
#  (u'/organization/sjf-ventures', 83181957.0),
#  (u'/organization/webb-investment-network', 83123660.0),
#  (u'/organization/ares-capital-corporation', 82798758.0),
#  (u'/organization/hudson-clean-energy-partners', 82775000.0),
#  (u'/organization/ufg-private-equity', 82507320.0),
#  (u'/organization/maven-capital-partners', 81904851.0),
#  (u'/organization/enterprise-ireland', 81872532.0),
#  (u'/organization/blue-cloud-ventures', 81829914.0),
#  (u'/organization/business-development-bank-of-canada', 81782446.0),
#  (u'/organization/par-capital-management', 81683332.0),
#  (u'/organization/mastercard', 81635739.0),
#  (u'/organization/saev', 81528248.0),
#  (u'/organization/alliance-of-angels', 81495409.0),
#  (u'/organization/yet2ventures', 81450046.0),
#  (u'/person/marc-benioff', 81068704.0),
#  (u'/organization/orix-ventures', 80916721.0),
#  (u'/organization/chrysalis-ventures', 80794795.0),
#  (u'/organization/transcosmos', 80628333.0),
#  (u'/person/ashton-kutcher', 80379550.0),
#  (u'/organization/chl-medical-partners', 80102379.0),
#  (u'/organization/itochu-technology-ventures', 80017848.0),
#  (u'/organization/jinjiang-international', 80000000.0),
#  (u'/person/alwaleed-bin-talal', 80000000.0),
#  (u'/organization/docomo-capital', 79705606.0),
#  (u'/organization/keating-capital', 79579286.0),
#  (u'/organization/wexford-capital', 79541747.0),
#  (u'/organization/kaszek-ventures', 79521108.0),
#  (u'/organization/darby-technology-ventures', 79500000.0),
#  (u'/organization/key-venture-partners', 79450000.0),
#  (u'/organization/rhodium', 79429840.0),
#  (u'/organization/star-ventures', 79427136.0),
#  (u'/organization/one-equity-partners-llc', 79379691.0),
#  (u'/organization/cdc-group', 79363409.0),
#  (u'/organization/georgian-partners', 79337768.0),
#  (u'/organization/kraft-group', 79284151.0),
#  (u'/organization/abbvie-biotech-ventures', 79024384.0),
#  (u'/organization/gx-capital', 79000000.0),
#  (u'/organization/capricorn-venture-partners', 78919045.0),
#  (u'/organization/presidio-ventures', 78909848.0),
#  (u'/organization/basf-venture-capital', 78898109.0),
#  (u'/organization/kingsbridge-capital', 78656030.0),
#  (u'/organization/lemhi-ventures', 78641666.0),
#  (u'/organization/leaf-clean-energy-company', 78600000.0),
#  (u'/organization/venture-investors', 78547023.0),
#  (u'/organization/hatteras-venture-partners', 78423107.0),
#  (u'/organization/craton-equity-partners', 78333329.0),
#  (u'/organization/rusnano', 78108332.0),
#  (u'/organization/alsop-louie-partners', 78081653.0),
#  (u'/organization/allied-minds', 78000000.0),
#  (u'/organization/excel-venture-management', 77965810.0),
#  (u'/organization/ssm-partners', 77894046.0),
#  (u'/organization/rivervest', 77849234.0),
#  (u'/organization/camden-partners', 77808070.0),
#  (u'/organization/square-peg-capital', 77803673.0),
#  (u'/organization/harbourvest-partners', 77752596.0),
#  (u'/organization/kima-ventures', 77700493.0),
#  (u'/organization/enertech-capital', 77679037.0),
#  (u'/organization/east-west-bank', 77666666.0),
#  (u'/organization/lightbank', 77515217.0),
#  (u'/organization/altira-group', 77461617.0),
#  (u'/organization/finnish-industry-investment', 77360184.0),
#  (u'/organization/aig-investments', 77278050.0),
#  (u'/person/brendan-wallace', 76939342.0),
#  (u'/organization/tribeca-venture-partners', 76869107.0),
#  (u'/organization/telefonica-ventures', 76794665.0),
#  (u'/organization/cm-cic-capital-prive', 76739928.0),
#  (u'/organization/community-investment-management--cim-', 76666666.0),
#  (u'/organization/avista-capital-partners', 76666666.0),
#  (u'/organization/new-venture-partners', 76598384.0),
#  (u'/organization/amgen', 76529337.0),
#  (u'/organization/venturetech-alliance', 76497878.0),
#  (u'/organization/ip-group-plc', 76453373.0),
#  (u'/organization/performance-equity-partners', 76256620.0),
#  (u'/organization/astellas-venture-management', 76089926.0),
#  (u'/organization/peakequity', 76000000.0),
#  (u'/organization/wicklow-capital', 75869656.0),
#  (u'/organization/bertelsmann', 75850425.0),
#  (u'/organization/valor-capital', 75685710.0),
#  (u'/organization/msd-capital', 75333333.0),
#  (u'/organization/enterprise-partners', 75236446.0),
#  (u'/organization/orbimed-2', 75039285.0),
#  (u'/organization/ses', 75000000.0),
#  (u'/organization/ace-limited', 75000000.0),
#  (u'/organization/goverment-of-singapore-investment-corporation-gic',
#   75000000.0),
#  (u'/organization/mississippi-development-authority', 75000000.0),
#  (u'/organization/equity-international', 75000000.0),
#  (u'/organization/srs-investment-management', 75000000.0),
#  (u'/organization/intelsat', 75000000.0),
#  (u'/organization/mts', 75000000.0),
#  (u'/organization/sistema', 75000000.0),
#  (u'/organization/icahn-enterprises', 75000000.0),
#  (u'/organization/laurel-crown-partners', 75000000.0),
#  (u'/organization/mercato-partners', 74880231.0),
#  (u'/organization/bridgescale-partners', 74690908.0),
#  (u'/organization/chrys-capital', 74600000.0),
#  (u'/organization/tata-capital', 74472461.0),
#  (u'/organization/eden-ventures', 74323035.0),
#  (u'/organization/desjardins-venture-capital', 74245403.0),
#  (u'/organization/oxford-capital-partners', 74223883.0),
#  (u'/organization/signet-healthcare-partners', 74113548.0),
#  (u'/person/jose-marin-2', 74092622.0),
#  (u'/organization/stanford-university', 74041736.0),
#  (u'/organization/dfj-eplanet-ventures', 73980145.0),
#  (u'/organization/endeavour-vision', 73953498.0),
#  (u'/organization/leapfrog-ventures', 73950146.0),
#  (u'/organization/worldview-technology-partners', 73942021.0),
#  (u'/organization/k2-ventures', 73564467.0),
#  (u'/organization/pentech-ventures', 73470605.0),
#  (u'/organization/celtic-house-venture-partners', 73456418.0),
#  (u'/organization/capital-one', 73342857.0),
#  (u'/organization/alberta-investment-management', 73166666.0),
#  (u'/organization/perseus', 73017617.0),
#  (u'/organization/westsummit-capital-management', 73015474.0),
#  (u'/organization/nexit-ventures', 72915033.0),
#  (u'/organization/gbs-ventures', 72817983.0),
#  (u'/organization/blackrock-private-equity-partners', 72500000.0),
#  (u'/organization/trilogy-equity-partnership', 72424763.0),
#  (u'/organization/tiger-technology-global-management', 72333333.0),
#  (u'/organization/sherpalo-ventures', 72238365.0),
#  (u'/organization/north-atlantic-capital', 72097833.0),
#  (u'/organization/china-media-capital-cmc', 72000000.0),
#  (u'/organization/bullpen-capital', 71978433.0),
#  (u'/organization/zodius-capital', 71800000.0),
#  (u'/organization/afsquare', 71769891.0),
#  (u'/organization/foundation-medical-partners', 71760725.0),
#  (u'/organization/sharespost-investment-management', 71656540.0),
#  (u'/organization/seventysix-capital', 71647264.0),
#  (u'/organization/core-capital-partners', 71385261.0),
#  (u'/person/bobby-yazdani', 71361884.0),
#  (u'/organization/ifc-infraventures', 71359141.0),
#  (u'/organization/asiavest-partners', 71333333.0),
#  (u'/organization/zero2ipo-ventures', 71287038.0),
#  (u'/organization/signia-venture-partners', 71064483.0),
#  (u'/organization/velocity-interactive-group-2', 70952856.0),
#  (u'/organization/esb-novusmodus', 70944314.0),
#  (u'/person/jason-finger', 70919432.0),
#  (u'/organization/cormorant-asset-management', 70918708.0),
#  (u'/person/rene-moos', 70763000.0),
#  (u'/organization/vectr', 70743611.0),
#  (u'/organization/crescendo-ventures', 70601666.0),
#  (u'/organization/fidelity-growth-partners-india', 70419999.0),
#  (u'/organization/media-ventures', 70314495.0),
#  (u'/person/farzad-nazem', 70295011.0),
#  (u'/organization/starfish-ventures', 70150319.0),
#  (u'/organization/biomedpartners', 70131859.0),
#  (u'/organization/acton-capital-partners', 70075210.0),
#  (u'/organization/connecticut-innovations', 70023504.0),
#  (u'/organization/swarth-investments', 70000000.0),
#  (u'/organization/prospect-capital-corporation', 70000000.0),
#  (u'/organization/ashmore-investment-management', 70000000.0),
#  (u'/organization/vi-partners', 69377896.0),
#  (u'/organization/tybourne', 69333332.0),
#  (u'/organization/point-judith-capital', 69146740.0),
#  (u'/organization/the9', 69000000.0),
#  (u'/organization/signatures-capital', 68923831.0),
#  (u'/person/ron-burkle', 68861872.0),
#  (u'/organization/omega-funds', 68770122.0),
#  (u'/organization/jumpstart-ventures', 68743950.0),
#  (u'/organization/world-innovation-lab', 68551657.0),
#  ...]
